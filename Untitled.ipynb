# %%
from scipy import io

mat_file = io.loadmat('./data-20130307T015746Z.mat')

# %%
import pprint

# %%
pprint.pprint(mat_file)
# Out:
# {'__globals__': [],
#  '__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Fri Dec '
#                b'22 16:32:18 2017',
#  '__version__': '1.0',
#  'tach': array([[8.50752000e-03],
#        [2.51555200e-02],
#        [4.18137600e-02],
#        ...,
#        [4.06652832e+01],
#        [4.06818924e+01],
#        [4.06984978e+01]]),
#  'vibration': array([[-0.41461882],
#        [ 0.17249019],
#        [-0.40377742],
#        ...,
#        [ 2.1773119 ],
#        [-1.48106277],
#        [-1.70356369]])}

# %%
mat_file['tach']
# Out:
# array([[8.50752000e-03],
#        [2.51555200e-02],
#        [4.18137600e-02],
#        ...,
#        [4.06652832e+01],
#        [4.06818924e+01],
#        [4.06984978e+01]])

# %%
len(mat_file['tach'])
# Out:
# 2446

# %%
len(mat_file)
# Out:
# 5

# %%
import scipy.io

import csv

import pandas

import sys



filename = './pdmBearingConditionMonitoringData.mat'



mat = scipy.io.loadmat(filename)

for row in mat:

    print (row)

    

test_data = mat['data']

test_defectDepthVec = mat['defectDepthVec']

test_expTime = mat['expTime']



print(test_data)

print(test_defectDepthVec)

print(test_expTime)
# Out:
# __header__
# __version__
# __globals__
# data
# defectDepthVec
# expTime
# [[array([[ 1.00850651e-04],
#        [ 5.34898078e-04],
#        [ 7.51917626e-04],
#        ...,
#        [ 1.15915356e-04],
#        [ 6.39483160e-06],
#        [-8.32848221e-06]])]
#  [array([[-0.00058808],
#        [-0.00036019],
#        [-0.00018445],
#        ...,
#        [-0.0003994 ],
#        [-0.00032335],
#        [-0.00039761]])]
#  [array([[5.18762838e-04],
#        [5.17475549e-04],
#        [3.07680129e-04],
#        ...,
#        [2.01895030e-04],
#        [1.53596793e-04],
#        [1.47740090e-05]])]
#  [array([[ 9.03837840e-05],
#        [ 1.90834810e-04],
#        [ 2.79225659e-04],
#        ...,
#        [ 2.50933108e-04],
#        [-1.87881771e-05],
#        [-2.88092426e-05]])]
#  [array([[-4.38736076e-06],
#        [ 1.53885076e-04],
#        [ 9.86779840e-05],
#        ...,
#        [-3.96029517e-04],
#        [-3.64883864e-04],
#        [-5.24524971e-04]])]
# ...

# %%
test_data=list(test_data)

import csv

with open("output.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(test_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-220d0e86511b> in <module>
#       5 with open("output.csv", "wb") as f:
#       6     writer = csv.writer(f)
# ----> 7     writer.writerows(test_data)
#
# TypeError: a bytes-like object is required, not 'str'

# %%
print(type(test_data[1]))
import numpy as np
import pandas as pd
# Out:
# <class 'numpy.ndarray'>

# %%
df = pd.DataFrame(test_data[1])
 
df.to_csv('sample.csv', index=False)
