# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences#길이 맞춰줌 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
#Onehot이랑 Embedding이랑 비슷하다고 보머ㅕㄴ됨ㄴ다.

# %%
import numpy as np

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
# 문서의 정의
docs = ['glass of orange juice',
       'bottle of mango juice',
       'glass of mango shake',
       'drink bottle of banana shake',
       'I wnat a glass of cold water',
       'The king and the queen',
       'mand and woman']

# %%
vocab_size =10000 #그냥 원핫보다 차원의 축소가 이루어지네 #부정확할순 있어도
#오호. . .

# %% [markdown]
# ### 문제1: 원핫인코딩 연습해보자

# %%
# 원핫인코딩해보자
#############################################
encoded_docs = [one_hot(d,vocab_size)for d in docs]
#for i in docs:
#    encoded_docs.append(tf.keras.preprocessing.text.one_hot(i,n=vocab_size))
#############################################

# %%
print(encoded_docs) #one-hot이랑은 좀 다르게 몇번쨰 단어인지를 호출해줌
# Out:
# [[3162, 715, 6429, 83], [6554, 715, 1960, 83], [3162, 715, 1960, 1557], [8250, 6554, 715, 2856, 1557], [8844, 6053, 9255, 3162, 715, 7523, 9912], [1061, 3626, 2090, 1061, 9632], [5789, 2090, 7105]]

# %% [markdown]
# # 단어 임베딩 (Word Embeddings)

# %%
embedding_length = 5 # 임베딩 길이 (단어 하나를 5개의 유닛으로 표현해보자.)
max_doc_len = 10  # 문장 길이

# %% [markdown]
# ### 문제2: 패딩을 시도해보자

# %%
# 다음의 pad_sequences를 이용해서 10개의 길이가 되도록 패딩 연습해보자. (디폴트인 pre 대신 post를 사용하라) #뒤에 0을 붙이기 // 앞에 붙이기 
# (https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/sequence/pad_sequences)
# tf.keras.preprocessing.sequence.pad_sequences(
#     sequences, maxlen=None, dtype='int32', padding='pre',
#     truncating='pre', value=0.0)

# %%
#############################################

#############################################

# %%
print(encoded_docs)  #(None, 10, 1)
# Out:
# [[8778 6345 7997 7350    0    0    0    0    0    0]
#  [ 157 6345 4023 7350    0    0    0    0    0    0]
#  [8778 6345 4023 9813    0    0    0    0    0    0]
#  [6670  157 6345 9873 9813    0    0    0    0    0]
#  [5411 9152 5617 8778 6345 8012 6260    0    0    0]
#  [9255 1539 1718 9255 4708    0    0    0    0    0]
#  [4405 1718 9914    0    0    0    0    0    0    0]]

# %% [markdown]
# ### 문제3: 5개의 유닛으로 만드는 임베딩 모델을 구축해보자.

# %%
#힌트: Embedding() 찾아보자 (https://www.tensorflow.org/api_docs/python/tf/keras/layers/Embedding)
# tf.keras.layers.Embedding(
#     input_dim, output_dim, embeddings_initializer='uniform',
#     embeddings_regularizer=None, activity_regularizer=None,
#     embeddings_constraint=None, mask_zero=False, input_length=None, **kwargs
# )
# 이중 input_dim, output_dim과 input_length를 정의해보자.

# %%
#############################################


#############################################

model.compile('adam', 'mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 5)             50000
# =================================================================
# Total params: 50,000
# Trainable params: 50,000
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 문제4: encoded_docs를 (배치크기, 문장길이, 임베딩차원)의 모양으로 만들어라.

# %%
# 위에서 만든 모델을 이용해 예측하라.
#############################################



#############################################
# Out:
# (7, 10, 5)
# [[[-0.03500199 -0.02871116  0.04214783  0.00116378  0.04828546]
#   [ 0.03610888  0.01757706 -0.00942087 -0.01343418 -0.03943598]
#   [-0.03095981 -0.01092114 -0.01432449  0.02378725  0.0236946 ]
#   [-0.04882896 -0.04517072  0.03054969 -0.04265317  0.03207726]
#   [ 0.04826966 -0.02451073 -0.00030233 -0.03221074 -0.0343508 ]
#   [ 0.04826966 -0.02451073 -0.00030233 -0.03221074 -0.0343508 ]
#   [ 0.04826966 -0.02451073 -0.00030233 -0.03221074 -0.0343508 ]
#   [ 0.04826966 -0.02451073 -0.00030233 -0.03221074 -0.0343508 ]
#   [ 0.04826966 -0.02451073 -0.00030233 -0.03221074 -0.0343508 ]
#   [ 0.04826966 -0.02451073 -0.00030233 -0.03221074 -0.0343508 ]]
#
#  [
#   -3.16059712e-04 -2.22958872e-04 -1.50341645e-03 -1.00984762e-03
#    2.74292286e-03  2.89824326e-04  2.01232941e-03 -3.69154592e-03
#   -4.74158558e-04  1.95734436e-03  4.97382076e-04  1.18561520e-03
#    1.02786813e-04  2.29055178e-04 -6.12721720e-04  2.79084849e-03
#    3.60464002e-03 -1.00063960e-04 -1.04366231e-03  1.03328307e-03
#    2.51813000e-03  6.18852966e-04  5.04246273e-04  7.50449137e-04
#    1.12775119e-03 -7.44981575e-04  1.36681972e-03 -2.52286647e-03
#   -7.49734521e-04 -2.81009800e-03 -2.66156718e-03 -3.19684925e-03
#   -9.11846000e-04  2.61161779e-03  2.74832593e-03  2.80277361e-03
#    2.47854204e-03  2.15357693e-04 -2.63099978e-03 -5.75518992e-04
#    1.80537777e-03 -3.06369434e-03 -3.13397730e-04 -3.67364101e-03
#    6.69462606e-04 -4.74496715e-04 -5.35182189e-04  8.67952302e-04
#   -4.30636166e-04 -1.05381454e-03 -3.38054262e-04 -1.29128364e-03]
#  [ 1.22499870e-04 -5.78971521e-04  2.93052499e-03 -1.50968658e-03
#   -1.07426895e-03 -2.62162812e-05  1.45181629e-03 -1.65387150e-03
#    4.40433947e-03 -2.36572768e-03 -1.22846814e-03  1.71977154e-03
#   -5.47945558e-04  1.82175601e-04 -1.77319394e-03 -1.48501154e-03
#    3.37413652e-03  3.09096824e-04  1.86121895e-03 -2.93495017e-03
#   -7.83402938e-04  2.82549928e-03  7.84883217e-04  1.15885888e-03
#    3.84756946e-04 -3.04136454e-04 -1.83780605e-04  3.07621178e-03
#    3.38144810e-03 -1.94197200e-04 -1.05586974e-03  1.21309492e-03
#    3.80680640e-03  8.50279350e-04 -7.93177333e-06  1.37346308e-03
#    4.16878785e-04 -8.36639898e-04  9.87098669e-04 -2.90443376e-03
#   -3.82108003e-04 -4.02320316e-03 -3.81905958e-03 -3.25987837e-03
#   -5.84870577e-04  2.47360929e-03  1.51925348e-03  2.39701918e-03
#    2.37423531e-03 -7.33259367e-04 -3.24835093e-03  3.40735452e-04
#    2.39972095e-03 -3.02137365e-03 -2.88782321e-04 -3.92521266e-03
#    8.99160339e-04 -8.01851507e-04 -9.73499264e-04  1.44521962e-03
#   -6.25410525e-04 -1.32359716e-03 -5.54483559e-04 -1.79022946e-03]]

# %% [markdown]
# ### 문제7: 감성분석을 할 수 있도록 LSTM을 이용한 로지스틱 모델 예측 모델을 만들어라.

# %%
# 힌트: 임베딩 -> LSTM -> Dense, 출력의 갯수가 하나이므로 활성함수를 sigmoid로 사용하라.

# %%
#############################################




#############################################

model.compile('adam', 'binary_cross_entropy')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 10, 5)             50000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                17920
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 67,985
# Trainable params: 67,985
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 문제8: 문제 7의 확장된 LSTM 모델의 출력을 확인하라

# %%
# 확장된 LSTM의 출력을 산출하고 이의 차원을 확인하라.

# %%
#############################################



#############################################
# Out:
# (7, 1)
# [[0.50067633]
#  [0.50072825]
#  [0.5006614 ]
#  [0.50072485]
#  [0.5008077 ]
#  [0.5009441 ]
#  [0.500733  ]]
