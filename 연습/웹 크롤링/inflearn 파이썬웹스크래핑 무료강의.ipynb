# %%
import requests

# %%
url = "https://nadocoding.tistory.com"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"}
res = requests.get(url,headers = headers)
#user Agent -> 익스플로어 or 크롬에 따라 다르게 표현
#user Agent string이라고 검색

# %%
res.raise_for_status()

# %%
#res.text

# %%
with open('mygoogle.html', 'w' ,encoding = 'utf-8') as f:
    f.write(res.text)

# %%
'''
import re
p=re.compile("ca.e")
re.compile("^de")
re.compile("ce&")


m = p.match("cafeless") #-> cafe 뒷부분에 다른 말이 와도 매치됨 
#match는 앞에
if m:
    print(m.group())
else:
    print("matchx")
    
# search는 중간에 있어도 ㄱㅊ
'''
# Out:
# cafe

# %%
from bs4 import BeautifulSoup

# %%
url ="https://comic.naver.com/webtoon/weekday.nhn"

# %%
res = requests.get(url)
res.raise_for_status()
soup = BeautifulSoup(res.text, "lxml")

# %%
soup.title.get_text()
# Out:
# '네이버 만화 > 요일별  웹툰 > 전체웹툰'

# %%
soup.a.get_text() #-> a중에 제일빠른애 나옴
# Out:
# '메인 메뉴로 바로가기'

# %%
a=soup.find_all

# %%
rank1=soup.find("li",attrs={"class":"rank01"})

# %%
rank1.get_text()
# Out:
# '\n전지적 독자 시점-031. Ep.07 건물주 (5)\n\n 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n'

# %%
# 형제관계 previous silbing도 가능
# Out:
# 고수-2부 127화
#
#  0

# %%
rank1.find_next_sibling("li").get_text()
# Out:
# '\n고수-2부 127화\n\n 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n'

# %%
rank1.find_next_siblings
# Out:
# <bound method PageElement.find_next_siblings of <li class="rank01">
# <a href="/webtoon/detail.nhn?titleId=747269&amp;no=32" onclick="nclk_v2(event,'rnk*p.cont','747269','1')" title="전지적 독자 시점-031. Ep.07 건물주 (5)">전지적 독자 시점-031. Ep.07 건물주 (5)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>>

# %%
abc=soup.find_all("a", attrs={"class":"title"})

# %%
for i in abc:
    print(i.get_text())
# Out:
# 참교육
# 뷰티풀 군바리
# 소녀의 세계
# 윈드브레이커
# 백수세끼
# 만렙돌파
# 장씨세가 호위무사
# 바이러스X
# 파이게임
# 앵무살수
# 유일무이 로맨스
# 칼가는 소녀
# 요리GO
# 오늘의 순정망화
# 히어로메이커
# 싸이코 리벤지
# 결혼생활 그림일기
# 개밥 먹는 남자
# 아는 여자애
# 리턴 투 플레이어
# 순정말고 순종
# 이것도 친구라고
# 삶이 우리를 속일지라도
# 사장님을 잠금해제
# 왕따협상
# 꿈의 기업
# 침범
# 서브 콤플렉스
# 이탄국의 자청비
# 보살님이 캐리해!
# 피플
# 도플갱어의 게임
# 와이키키 뱀파이어
# 두근두근 네가 좋아서
# 이중첩자
# 정보전사 202
# 원하는 건 너 하나
# 안녕 나의 모모로
# 지구멸망버튼
# 뱀파이어의 꽃
# 하슬라
# 여기 악마가 있어
# 부산스런 웹툰
# 인간의 온도
# 드로잉 레시피
# 블루투스
# 백호랑
# 모락모락 왕세자님
# 헬로맨스
# 평범한 8반
# 결백한 사람은 없다
# 여신강림
# 관계의 종말
# 바른연애 길잡이
# 한림체육관
# 하루만 네가 되고 싶어
# 랜덤채팅의 그녀!
# 사신소년
# 후기
# 호랑이 들어와요
# 중증외상센터 : 골든 아워
# 헬58
# 신도림
# 삼국지톡
# 원주민 공포만화
# 달콤살벌한 부부
# 집이 없어
# 오늘의 순정망화
# 아이레
# 체크포인트
# 성인초딩
# 견우와 선녀
# 윌유메리미
# 용왕님의 셰프가 되었습니다
# 빅맨
# 오피스 누나 이야기
# 플레이, 플리
# 신의 언어
# 정년이
# 별종
# 3cm 헌터
# 그놈은 흑염룡
# 한강예찬
# 올가미
# 은주의 방 2~3부
# 피로만땅
# 연우의 순정
# 오파츠
# 숲속의 담
# 인문학적 감수성
# 완벽한 가족
# 나의 플랏메이트
# 언메이크
# 자판귀
# 조선홍보대행사 조대박
# 도를 아십니까
# 빛빛빛
# 너에게만 보이는
# 그날 죽은 나는
# 필살VS로맨스
# 안식의 밤
# 아이고 아이고
# 저세상 클라스!
# 장단에 맞춰줘!
# 제로게임
# 고수
# 전지적 독자 시점
# 복학왕
# 모죠의 일지
# 하렘의 남자들
# 격기3반
# 튜토리얼 탑의 고인물
# 여주실격!
# 캐슬
# 노곤하개
# 남주의 첫날밤을 가져버렸다
# 원수를 사랑하라
# 연놈
# 사상최강
# 고삼무쌍
# 닥터앤닥터 육아일기
# 일렉시드
# 나쁜사람
# 판타지 여동생!
# 빌드업
# 엔딩 후 서브남을 주웠다
# 각자의 디데이
# 언덕 위의 제임스
# 마녀와 용의 신혼일기
# 귀곡의 문
# 마른 가지에 바람처럼
# 로어 올림푸스
# 정순애 식당
# 아도나이
# 방탈출
# 범이올시다!
# 미래의 골동품 가게
# 나의 우주
# 새벽 두 시의 신데렐라
# 얼굴천재
# 평화선도부
# 이츠마인
# 더 트웰브
# 당신의 향수
# 속보입니다
# 인터셉트
# 시효완성
# 기억흔적
# 스캔들
# 천도
# 수상한 비밀상담부
# 스몰
# 저승사자 출입금지
# FM보이
# 비스타
# 노선도
# 럭키언럭키
# 말하는대로
# 독립일기
# 연애혁명
# 더 복서
# 기기괴괴
# 이두나!
# 노답소녀
# 간 떨어지는 동거
# 나노마신
# 화이트 블러드
# 하드캐리
# 던전 씹어먹는 아티팩트
# 전자오락수호대
# 겟백
# 무사만리행
# 꽃만 키우는데 너무강함
# 오늘의 순정망화
# 병의 기록
# 당신의 과녁
# 자취방 신선들
# 트롤트랩
# 신비
# 쿠베라
# 선의의 경쟁
# 달라 보여도 모두 같은 가족
# 최강전설 강해효
# 헬프미
# 시월드 판타지
# 별을 삼킨 너에게
# 롤랑롤랑
# 셧업앤댄스
# 안개무덤
# 날 가져요
# 로그아웃
# 오일머니
# 집사레인저
# 겟라이프
# 우리는 요정!
# 스크립토리움
# 킬더킹
# 셈하는 사이
# 소녀180
# 카루나
# 미드나잇 체이서
# 보물과 괴물의 도시
# 불릿 6미리
# 스테어스
# 손아귀
# 온새미로
# 깁스맨
# 악령주의보
# 밤하늘에 구름운
# 만물의 영장
# 여성전용헬스장 진달래짐
# 외모지상주의
# 데드퀸
# 갓 오브 하이스쿨
# 관계의 종말
# 재혼 황후
# 1초
# 개를 낳았다
# 삼국지톡
# 살人스타그램
# 뫼신 사냥꾼
# 낙향문사전
# 걸어서 30분
# 난약
# 사냥개들
# 냐한남자
# 더 게이머
# 플레이어
# 복학생 정순이
# 구남친이 내게 반했다
# 옆집친구
# 성경의 역사
# 고래별
# 가슴털 로망스
# 신상 미스터리 극장
# 히트포인트
# 금혼령-조선혼인금지령
# 상남자
# 피와 나비
# 감자마을
# 도무지 그애는
# 소심한 팔레트
# 방과후 선녀
# 낢다른 광화문광장 이야기
# 얌전한 사이
# 닥터 프로스트 시즌 3~4
# 후덜덜덜 남극전자
# 도롱이
# 진짜 정말 맹세코 좋아해
# 백년게임
# 구독금지
# 감히
# 트럼프
# 너의 미소가 함정
# 나쁜 쪽으로
# 몽홀
# 9등급 뒤집기
# 스윗솔티
# 합법해적 파르페
# 매지컬 메디컬
# 구주의 시간
# 나의 첫번째 새벽
# 버그
# 프리드로우
# 호랑이형님
# 모죠의 일지
# 취사병 전설이 되다
# 비질란테
# 힙한남자
# 초인의 시대
# 노곤하개
# 스터디그룹
# 광장
# 왕년엔 용사님
# 청춘 블라썸
# 토끼대왕
# 민간인 통제구역
# 어글리후드
# 나를 바꿔줘
# 아홉수 우리들
# 윌유메리미
# 나이트런
# 단편.zip
# 두번째 생일
# 갓핑크
# 탑코너
# 동트는 로맨스
# 태백 : 튜토리얼 맨
# 먹이
# 남자주인공의 여자사람친구입니다
# 팔려 온 신부
# 공유몽
# 열불 로맨스
# 광해의 연인
# 내게 필요한 NO맨스
# 홍시는 날 좋아해!
# 틴맘
# 압락사스
# 피라미드 게임
# 웰캄투실버라이프
# 저무는 해, 시린 눈
# 동네몬스터
# 아테나 컴플렉스
# 친구의 비밀계정
# 손 잡아 볼래?
# 피노키오 소녀
# 회춘
# 인간졸업
# 도사 가온
# 아침을 지나 밤으로
# 후아유!
# 안녕, 이바다씨
# 꼬리 있는 연애
# 커피도둑
# 함부로 대해줘
# 누군가의 로섬
# 먹지마세요
# 왕세자 입학도
# 독립일기
# 싸움독학
# 열렙전사
# 이번 생도 잘 부탁해
# 맘마미안
# 입학용병
# 소녀재판
# 천하제일인
# 닥터앤닥터 육아일기
# 도망자
# 경비 배두만
# 오로지 너를 이기고 싶어
# 두근두근 연극부
# 곱게 키웠더니, 짐승
# 행성인간
# 합격시켜주세용
# 벚꽃이 흩날릴 무렵
# 인어를 위한 수영교실
# 마법스크롤 상인 지오
# 판사 이한영
# 내일
# 오늘 밤만 재워줘
# AI가 세상을 지배한다면
# 로어 올림푸스
# 구름이 피워낸 꽃
# 라커, 오프너
# 가비지타임
# 다이스(DICE)
# 별이삼샵
# 약한영웅
# 강남도깨비
# 데빌샷
# 학교정벌
# 아르세니아의 마법사
# 라일락 200%
# 스트러글
# 오른눈이 보는 세계
# 평행도시
# 잉여특공대
# 호시탐탐
# 무주의 맹시
# 신이 담긴 아이
# 소녀 해미
# 오늘도 사랑하세요
# Here U Are
# 데이즈
# 위험한 신입사원
# 여름은 뜨겁다
# 불발소년
# 죽여주는 탐정님
# 인싸라이프

# %%
url = "https://comic.naver.com/webtoon/list.nhn?titleId=703846&weekday=tue"
res= requests.get(url)

# %%
soup = BeautifulSoup(res.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>여신강림 :: 네이버 만화</title>
# <meta content="여신강림" property="og:title"/>
# <meta content="https://shared-comic.pstatic.net/thumb/webtoon/703846/thumbnail/thumbnail_IMAG19_225f310e-c16c-4ac3-b164-987d0cec46a7.jpg" property="og:image"/>
# <meta content="네웹 대표 글로벌 인기작! 주경, 수호, 서준. 세 청춘의 두근두근 눈호강 로맨스~♡메이크업으로 여신이 된 주경이는 꿈과 사랑을 이룰 수 있을까?" property="og:description"/>
# <meta content="https://comic.naver.com/webtoon/list.nhn?titleId=703846&amp;weekday=tue" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
# 		document.domain = "naver.com";
# 	</script>
# <link href="/css/comic/comic_20201215100246.css" rel="stylesheet" style="text/css"/>
# <!-- comicArticleListJsFile -->
# <script charset="utf-8" src="/aggregate/javascript/release/comic_article_list_20201215100246.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	// nclick
#
# 	//<![CDATA[
# 	var g_ssc = "decide.me";
# 	var levelName = "WEBTOON";
# 	if(levelName == "BEST_CHALLENGE"){
#         g_ssc = "comic.best_list";
# 	}else if(levelName == "CHALLENGE"){
#         g_ssc = "comic.chal_list";
# 	}else if(levelName == "WEBTOON"){
#         g_ssc = "comic.toon_list";
# 	}
#
# 	var ccsrv = "cc.naver.com";
# 	//]]>
# </script>
# <script type="text/javascript">
# 	var isLogin = false;
# 	var levelName = "webtoon";
#
# 	var artistData = [
#
#           {"artistId" : 316796,
#            "nickname": '야옹이'}
#
#     ];
#
#     var actionRunner;
#
#
#     WebtoonArtistActionRunner = $Class ({
#         $init : function(titleId) {
#             this._titleId = titleId;
# 	    },
#
# 	  	//관심 웹툰 추가
#         addFavoriteWebtoon : function (titleId) {
# 	    	var width = (screen.width / 2) - 800;
# 			var height = (screen.height / 2) - 510;
# 			var favoriteUrl = null;
# 			var addUrl = "https://" + location.hostname + "/mypage/favoriteTitleAdd.nhn?titleId="+titleId;
# 			var removeUrl = "https://" + location.hostname + "/mypage/favoriteTitleRemove.nhn?titleId="+titleId;
# 			if($Element(jindo.$$.getSingle('.book_maker')).hasClass('on')) {
# 				favoriteUrl = removeUrl;
# 			} else {
# 				favoriteUrl = addUrl;
# 			}
#
# 			if(isLogin) {
# 			    var favoritePopup = window.open('', 'addFavorite', 'directories=no,toolbar=no,scrollbars=yes,width=370,height=180,top=' + height + ',left=' + width);
# 			    favoritePopup.location.href = favoriteUrl;
# 			} else {
# 			    location.href = "/common/login.nhn?url=" + encodeURIComponent(location.href);
# 			}
# 	    },
#
# 	    artistForArtistTitle : function(element) {
# 			$Element("author_layer_inner").html("");
# 			$Element("author_layer").css("border", "");
# 			$Element("author_layer_inner").css("border", "1px solid #b6b6b6");
# 	    	if(artistData.length == 0) {
# 	    		var liElement = new $Element("<li>");
#                 var spanElement = new $Element("<span>");
#                 spanElement.html("작가의 다른 작품이 없습니다.");
#                 liElement.append(spanElement);
#                 $Element("author_layer_inner").append(liElement);
# 	        	artistLayer.show(element);
# 	    	} else if(artistData.length == 1) {
# 	    		location.href = "/artistTitle.nhn?artistId=" + artistData[0].artistId;
# 	    	} else {
# 					for (var i = 0; i < artistData.length; i++) {
# 						var liElement = new $Element("<li>");
# 						var aElement = new $Element("<a>");
# 						aElement.attr("href", "/artistTitle.nhn?artistId=" + artistData[i].artistId);
# 						aElement.html("&lt;" + artistData[i].nickname + "&gt;의 다른작품");
# 						liElement.append(aElement);
# 						$Element("author_layer_inner").append(liElement);
# 						if (i==9) {
# 							$Element("author_layer").css("border", "1px solid #b6b6b6");
# 							$Element("author_layer_inner").css("border", "0");
# 						}
# 	              }
# 	        artistLayer.show(element);
# 	    	}
# 	    	return false;
# 	    }
# 	});
#
# 	var bRolling = false;
# 	var oAdBannerFlicking = null;
# 	var adBannerInterval = null;
#
# 	function loadThisWindow () {
# 	    actionRunner = new WebtoonArtistActionRunner("703846");
#
# 		(function(oData) {
# 			window.__oLikeItData = oData;
# 			var s = document.createElement("script");
# 			s.type = "text/javascript";
# 			s.charset = "utf-8";
# 			s.src = oData.domain + "/static/js/likeIt.v2.desktop.init.js?v="+ (new Date()).toDateString().replace(/\s/g,"");
# 			(document.head || document.getElementsByTagName("head")[0]).appendChild(s);
# 		})({
# 			serviceId : "COMIC"
# 			, displayId : "COMIC"
# 			, contentId : "703846"
# 			, domain :"https://comic.like.naver.com"
# 			, lang : "ko"
# 			, viewType : ""
#
# 			, countCallbackYn : "Y"
# 			, rparam : encodeURIComponent("deviceCode=PC")
#
# 		 });
#
# 		if(levelName == "bestChallenge") {
# 			function potenupArea() {
# 				if ($Element("potenupAreaBtn").className() == "btn_potenup") {
# 					$Element("potenupAreaBtn").className($Element("potenupAreaBtn").className() + " on");
# 				} else {
# 					$Element("potenupAreaBtn").className("btn_potenup");
# 				}
#
# 			}
#
# 			$Fn(potenupArea).attach($Element("potenupAreaBtn"), "click");
#
# 			$Fn(potenupArea).attach($Element("potenupAreaCloseBtn"), "click");
# 		}
#
#
# 		if (jQuery("#mflick1")) {
#
# 			var $j = jQuery.noConflict();
#
# 			if ($j("#mflick1").length > 0) {
#
# 				oAdBannerFlicking = new eg.Flicking(jQuery("#mflick1"), {
# 					duration: 300,
# 					circular: true,
# 					defaultIndex: 0
# 				});
# 				jQuery("._adBanner").show();
# 				rollingAdBanner();
#
#
# 				jQuery(window).scroll(function () {
# 					var nExposureControlPosition = jQuery('#mflick1').offset().top + jQuery('#mflick1').height();
# 					if (window.scrollY > nExposureControlPosition) {
# 						window.clearInterval(adBannerInterval);
# 						bRolling = false;
# 					} else {
# 						if (!bRolling) {
# 							rollingAdBanner();
# 						}
# 					}
# 				});
# 			}
# 		}
# 	}
#
# 	function rollingAdBanner() {
# 		if (!bRolling) {
# 			adBannerInterval = setInterval(function () {
# 				var statViewUrl = oAdBannerFlicking.getNextElement().data('url');
# 				callWebAdBannerView(statViewUrl);
# 				oAdBannerFlicking.next();
# 			}, 2000);
# 			bRolling = true;
# 		}
# 	}
#
# 	function callWebAdBannerView(sStatsUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		jQuery.ajax({
# 			type: 'GET',
# 			url: sStatsUrl + '&_dummy='+nTimestamp,
# 			async: false,
# 			timeout : self._nAjaxCallTimeout
# 		});
# 	}
#
# 	function callWebAdBannerClick(sStatsUrl, sTargetUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		jQuery.ajax({
# 			type: 'GET',
# 			url: sStatsUrl + '&_dummy='+nTimestamp,
# 			async: false,
# 			timeout : self._nAjaxCallTimeout,
# 			complete : function() {
# 				window.open(sTargetUrl, '_blank');
# 			}
# 		});
# 	}
#
# 	$Fn(loadThisWindow).attach(window,"load");
#
#     /**
#      * 시리즈로 이동 가능한지 확인해서 이동
#      *
#      * @params nbooksId {String} 북스 상품 ID
#      */
# 	function moveBookstore(nbooksId) {
#         var result;
#
#         $Ajax('https://series.naver.com/isService.jsonp', {
#             type : 'jsonp',
#             method : 'get',
#             callbackname: 'callback',
#             onload : function(oRes) {
#                 result = oRes.json().result;
#             }
#         }).request({
#             'productTypeCode' : 'COMIC',
#             'originalProductId' : nbooksId
#         });
#
#
# 		var oInterval = setInterval(function() {
#             if (result == 'true') {
#                 window.open('https://series.naver.com/comic/detail.nhn?originalProductId=' + nbooksId, '_blank');
#             } else {
#                 alert('시리즈에 상품을 등록 중입니다. 잠시만 기다려주세요.');
#             }
#             clearInterval(oInterval);
#             oInterval = null;
# 		}, 200);
# 	}
# </script>
# <script src="/aggregate/javascript/release/comic_gnb_20201215100246.js" type="text/javascript"></script>
# </head>
# <body onload="">
# <div class="end_page" id="wrap">
# <div id="u_skip">
# <a href="#menu" onclick="document.getElementById('menu').tabIndex=-1;document.getElementById('menu').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header_wrap">
# <div id="header">
# <div id="gnb">
# <script type="text/javascript">
#         var gnb_option = {
#             gnb_service : "comic",
#             gnb_logout :  encodeURIComponent(window.location.href),
#             gnb_login :   encodeURIComponent(window.location.href),
#             gnb_template : "gnb_utf8",
#             gnb_brightness : 1,
#             gnb_item_hide_option: 0
#         };
#     </script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20201215100246" type="text/javascript"></script>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="Ntxt_naver " href="https://www.naver.com" onclick="nclk_v2(event,'STA.naverlogo')" title="NAVER">NAVER</a>
# <a class="Ntxt_comic" href="/index.nhn" onclick="nclk_v2(event,'STA.comic')" title="만화">만화</a>
# <em class="bar">|</em>
# <a class="Ntxt_novel" href="https://novel.naver.com" onclick="nclk_v2(event,'STA.novel')" title="웹소설">웹소설</a>
# </h1>
# <form action="/search.nhn" id="searchForm" method="get" name="search">
# <fieldset>
# <legend>검색</legend>
# <div class="snb_search_box">
# <div class="snb_search_box_sub">
# <!-- [D] 클릭시 label.ph 텍스트 삭제해주세요. -->
# <label class="ph" for="gnb.keyword">제목/작가로 검색할 수 있습니다.</label>
# <input class="snb_search_text" id="gnb.keyword" maxlength="18" name="keyword" title="검색어 입력" type="text" value=""/>
# <button alt="검색" class="btn_search" id="search_bar_button" onclick="nclk_v2(event,'STA.search')" title="검색" type="button"><span class="Nico_search">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# </div>
# <div id="author_layer" style="text-align:left; display:none;">
# <ul id="author_layer_inner"> </ul>
# </div>
# <div class="notice_info">
# <span class="blind">공지사항</span>
# <div class="rolling">
# <div class="notice_rolling">
# <li>
# <a href="https://comic.naver.com/webtoon/list.nhn?titleId=758037" onclick="nclk_v2(event,'STA.txt')" title="부활남 채용택 작가 X 신석기녀 한가람 작가 신작 &lt;참교육&gt;">
# <span class="Nico_notice"></span>
# 										부활남 채용택 작가 X 신석기녀 한가람 작가 신작 &lt;참교육&gt;
# 									</a>
# </li>
# </div>
# </div>
# </div>
# </div>
# <div id="menu">
# <ul class="menu">
# <!-- [D] 선택된 li에 current 클래스 추가 -->
# <li><a href="/index.nhn" onclick="nclk_v2(event,'LNB.home');"><span class="Ntxt_home">웹툰 홈</span></a></li>
# <li class="current"><a href="/webtoon/weekday.nhn" onclick="nclk_v2(event,'LNB.toon');"><span class="Ntxt_webtoon">웹툰</span></a></li>
# <li><a href="/genre/bestChallenge.nhn" onclick="nclk_v2(event,'LNB.best');"><span class="Ntxt_best_challenge">베스트 도전</span></a></li>
# <li><a href="/genre/challenge.nhn" onclick="nclk_v2(event,'LNB.chal');"><span class="Ntxt_challenge_comic">도전만화</span></a></li>
# <li><a href="/mypage/favorite.nhn" onclick="nclk_v2(event,'LNB.my');"><span class="Ntxt_mypage">마이페이지</span></a><span class="bar"></span></li>
# <li><a href="https://series.naver.com/comic/recommendList.nhn" onclick="nclk_v2(event,'LNB.char');" target="_blank"><span class="Ntxt_short_story">단행본 만화</span></a></li>
# <li class="genre_novel"><a href="https://series.naver.com/novel/recommendList.nhn" onclick="nclk_v2(event,'LNB.novel');" target="_blank"><span class="Ntxt_genre_novel">장르소설</span></a></li>
# </ul>
# <h2 class="blind">웹툰</h2>
# </div>
# <!-- //상단 메뉴 /webtoon/list.nhn-->
# <div id="submenu">
# <!--서브메뉴-->
# <ul class="submenu">
# <!-- [D] 선택된 li에 on 클래스 추가 -->
# <li class="on"><a href="/webtoon/weekday.nhn" onclick="nclk_v2(event,'tab.weekday')"><span class="Ntxt_menu_date">요일별</span></a></li>
# <li><a href="/webtoon/genre.nhn" onclick="nclk_v2(event,'tab.genre')"><span class="Ntxt_menu_genre">장르별</span></a></li>
# <li><a href="/webtoon/creation.nhn" onclick="nclk_v2(event,'tab.creation')"><span class="Ntxt_menu_art">작품별</span></a></li>
# <li><a href="/webtoon/artist.nhn" onclick="nclk_v2(event,'tab.artist')"><span class="Ntxt_menu_author">작가별</span></a></li>
# <li><a href="/webtoon/period.nhn" onclick="nclk_v2(event,'tab.period')"><span class="Ntxt_menu_year">연도별</span></a></li>
# <li><a href="/webtoon/theme.nhn" onclick="nclk_v2(event,'tab.theme')"><span class="Ntxt_menu_theme">테마웹툰</span></a></li>
# <li><a href="/webtoon/finish.nhn" onclick="nclk_v2(event,'tab.finish')"><span class="Ntxt_menu_end">완결웹툰</span></a></li>
# </ul>
# <!--//서브메뉴-->
# </div>
# </div>
# <!-- 상단 영역(메인에만 나감.) -->
# <!-- //상단 영역 -->
# <div class="" id="container">
# <div class="webtoon" id="content">
# <ul class="category_tab">
# <li class=""><a href="/webtoon/weekday.nhn" onclick="nclk_v2(event,'dna.all')">요일전체</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=mon" onclick="nclk_v2(event,'dna.monday')">월요웹툰</a></li>
# <li class="on"><a href="/webtoon/weekdayList.nhn?week=tue" onclick="nclk_v2(event,'dna.tuesday')">화요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=wed" onclick="nclk_v2(event,'dna.wednesday')">수요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=thu" onclick="nclk_v2(event,'dna.thursday')">목요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=fri" onclick="nclk_v2(event,'dna.friday')">금요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=sat" onclick="nclk_v2(event,'dna.saturday')">토요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=sun" onclick="nclk_v2(event,'dna.sunday')">일요웹툰</a></li>
# </ul>
# <!-- body -->
# <!-- 상세 정보영역 -->
# <div class="comicinfo" style="">
# <div class="thumb">
# <a href="/webtoon/list.nhn?titleId=703846" onclick="nclk_v2(event,'inf.img')">
# <img alt="여신강림" height="101" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non125_101.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/thumbnail/thumbnail_IMAG06_aa715a18-fe51-4adf-b21b-5fc253ed3f32.jpg" title="여신강림" width="125"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="detail">
# <h2>
# 			        여신강림<span class="wrt_nm">
# 							야옹이</span>
# </h2>
# <p>네웹 대표 글로벌 인기작! 주경, 수호, 서준. 세 청춘의 두근두근 눈호강 로맨스~♡<br/>메이크업으로 여신이 된 주경이는 꿈과 사랑을 이룰 수 있을까?</p>
# <p class="detail_info"><span class="genre">스토리, 로맨스</span><span class="age">12세 이용가</span></p>
# <ul class="btn_group">
# <li><a class="book_maker " href="#" onclick="nclk_v2(event,'inf.zzim');return actionRunner.addFavoriteWebtoon('703846');" title="관심웹툰"><span>관심웹툰</span></a></li>
# <li><a class="first" href="#" onclick="nclk_v2(event,'inf.first');return checkServiceCode('S00','1')" title="첫회보기"><span>첫회보기</span></a></li>
# <li><a class="other" href="#" id="other_content" onclick="nclk_v2(event,'inf.artist');return actionRunner.artistForArtistTitle(this)" title="작가의 다른 작품"><span>작가의 다른 작품</span></a></li>
# <!-- [D] pre_view 클래스에 완결인 경우 end 클래스 추가 및 span에 설명 변경-->
# <li>
# </li>
# <li>
# <div class="u_likeit_module">
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- //상세 정보영역 -->
# <!-- 리스트 -->
# <table cellpadding="0" cellspacing="0" class="viewList">
# <caption><span class="blind">회차별 목록</span></caption>
# <col width="99"/><col width="*"/><col width="141"/><col width="76"/>
# <thead>
# <tr>
# <th scope="col">이미지</th>
# <th scope="col">제목</th>
# <th scope="col">별점</th>
# <th scope="col">등록일</th>
# </tr>
# </thead>
# <tr class="band_banner v2 ">
# <td colspan="4">
# <a href="https://series.naver.com/comic/detail.nhn?originalProductId=309445" onclick="nclk_v2(event,'lst.gostore','703846');" target="_blank">
# <em class="ico_store2">NAVER 만화</em>다음 화를 미리 만나보세요.</a>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=141&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','141')">
# <img alt="136화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/141/thumbnail_202x120_864be28b-ed05-48da-85fa-261f1d0da202.jpg" title="136화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=141&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','141')">136화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:86.29%">평점</em></span>
# <strong>8.63</strong>
# </div>
# </td>
# <td class="num">2020.12.21</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=140&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','140')">
# <img alt="135화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/140/thumbnail_202x120_926d9143-42b9-40b6-a13b-dd7a2ad3a2c7.jpg" title="135화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=140&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','140')">135화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:92.45%">평점</em></span>
# <strong>9.24</strong>
# </div>
# </td>
# <td class="num">2020.12.14</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=139&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','139')">
# <img alt="134화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/139/thumbnail_202x120_a683b9de-b717-4cf1-855e-3431b33405ff.jpg" title="134화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=139&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','139')">134화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:88.69%">평점</em></span>
# <strong>8.87</strong>
# </div>
# </td>
# <td class="num">2020.12.07</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=138&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','138')">
# <img alt="133화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/138/thumbnail_202x120_a3a84986-58f7-4abc-84a2-f8255a101f02.jpg" title="133화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=138&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','138')">133화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:84.47%">평점</em></span>
# <strong>8.45</strong>
# </div>
# </td>
# <td class="num">2020.11.30</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=137&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','137')">
# <img alt="132화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/137/thumbnail_202x120_5fcd9456-c368-4d00-8e5a-e2540276ceba.jpg" title="132화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=137&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','137')">132화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:79.55%">평점</em></span>
# <strong>7.96</strong>
# </div>
# </td>
# <td class="num">2020.11.23</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=136&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','136')">
# <img alt="131화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/136/thumbnail_202x120_f4eb81f4-9f0c-4da2-a4c8-12033c247f01.jpg" title="131화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=136&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','136')">131화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:83.45%">평점</em></span>
# <strong>8.34</strong>
# </div>
# </td>
# <td class="num">2020.11.09</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=135&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','135')">
# <img alt="130화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/135/thumbnail_202x120_2618008e-71c0-4c1a-8a71-d656c6a50a31.jpg" title="130화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=135&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','135')">130화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:89.30%">평점</em></span>
# <strong>8.93</strong>
# </div>
# </td>
# <td class="num">2020.11.02</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=134&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','134')">
# <img alt="129화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/134/thumbnail_202x120_83183c7e-312a-4421-b12b-5026f05677e5.jpg" title="129화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=134&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','134')">129화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:88.72%">평점</em></span>
# <strong>8.87</strong>
# </div>
# </td>
# <td class="num">2020.10.26</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=133&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','133')">
# <img alt="128화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/133/thumbnail_202x120_6d7aaf09-c835-4e14-a6b6-f199208aafc8.jpg" title="128화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=133&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','133')">128화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:89.04%">평점</em></span>
# <strong>8.90</strong>
# </div>
# </td>
# <td class="num">2020.10.19</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=132&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','132')">
# <img alt="127화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/132/thumbnail_202x120_5035d86d-430c-472b-a0fa-fbd2d90efcec.jpg" title="127화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=132&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','132')">127화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:87.12%">평점</em></span>
# <strong>8.71</strong>
# </div>
# </td>
# <td class="num">2020.10.12</td>
# </tr>
# </table>
# <!-- //리스트 -->
# <div class="paginate">
# <div class="page_wrap">
# <strong class="blind">페이지 이동하기</strong>
# <strong class="page"><em class="num_page">1</em><span class="blind"> 현재 페이지</span></strong>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=2"><em class="num_page">2</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=3"><em class="num_page">3</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=4"><em class="num_page">4</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=5"><em class="num_page">5</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=6"><em class="num_page">6</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=7"><em class="num_page">7</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=8"><em class="num_page">8</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=9"><em class="num_page">9</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=10"><em class="num_page">10</em></a>
# <a class="next" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=2" title="다음 페이지 목록으로 이동"><span class="cnt_page">다음</span><span class="blind"> 페이지 목록으로 이동</span><span class="ico_page"></span></a>
# </div>
# </div>
# <script type="text/javascript">
# 		function checkServiceCode(serviceCode, no){
# 			var hrefUrl = "/webtoon/detail.nhn?titleId=703846&no="+no+"&weekday=tue";
#
# 			if("S00" == serviceCode) {
# 			    location.href = hrefUrl;
# 			} else {
# 			    this.alert("게시 보류 중인 콘텐츠 입니다.");
# 			}
# 			return false;
# 		}
# 	</script>
# </div>
# <!-- side menu -->
# <div id="aside">
# <div class="asideButton upload">
# <a class="Nbtn_upload" href="/mypage/myActivity.nhn" onclick="nclk_v2(event,'olk.upload');">웹툰 올리기</a>
# </div>
# <!-- 배너 -->
# <div class="asideAd" data-veta-preview="p_wtoon_end" id="addiv" name="addiv">
# <iframe align="center" border="0" frameborder="0" height="240" id="f240240" marginheight="0" marginwidth="0" name="f240240" scrolling="no" src="https://veta.naver.com/fxshow?su=SU10321" title="광고영역" width="240"></iframe>
# </div>
# <!-- //배너 -->
# <!-- 롤링이미지 -->
# <div class="asideRolling">
# <a href="https://comic-superstring.naver.com/" onclick="nclk_v2(event,'olk.banner')" target="_blank">
# <img alt="드디어! 슈퍼스트링 전용관" height="97" src="https://naverwebtoon-phinf.pstatic.net/20190711_69/15628125217864fItE_JPEG/upload_7786257395998636846.JPEG?type=p100" width="240"/>
# </a>
# </div>
# <!-- 인기급상승만화 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle"><img alt="인기급상승만화" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_best.gif" title="인기급상승만화" width="78"/></h4>
# <div>
# <ul class="asideBoxTab"><!-- 선택된 메뉴에는 choice라는 클래스명을 사용합니다 -->
# <li class="choice" id="realTimeRankChoiceTabFavorite"><a href="#" id="realTimeRankChoiceTabFavoriteClick" onclick="nclk_v2(event,'rnk.rep')"><img alt="인기순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_favor.gif" title="인기순" width="31"/></a></li>
# <li id="realTimeRankChoiceTabUpdate"><a href="#" id="realTimeRankChoiceTabUpdateClick" onclick="nclk_v2(event,'rnk.upd')"><img alt="업데이트순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_update.gif" title="업데이트순" width="52"/></a></li>
# </ul>
# <h3 class="blind" id="realTimeRankBlindName">인기순</h3>
# <ol class="asideBoxRank" id="realTimeRankFavorite">
# <li class="rank01">
# <a href="/webtoon/detail.nhn?titleId=747269&amp;no=32" onclick="nclk_v2(event,'rnk*p.cont','747269','1')" title="전지적 독자 시점-031. Ep.07 건물주 (5)">전지적 독자 시점-031. Ep.07 건물주 (5)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail.nhn?titleId=662774&amp;no=217" onclick="nclk_v2(event,'rnk*p.cont','662774','2')" title="고수-2부 127화">고수-2부 127화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail.nhn?titleId=626907&amp;no=325" onclick="nclk_v2(event,'rnk*p.cont','626907','3')" title="복학왕-323화 청약 대회 3화">복학왕-323화 청약 대회 3화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail.nhn?titleId=738143&amp;no=54" onclick="nclk_v2(event,'rnk*p.cont','738143','4')" title="여주실격!-54화 밖으로 따라 나와">여주실격!-54화 밖으로 따라 나와</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail.nhn?titleId=760001&amp;no=6" onclick="nclk_v2(event,'rnk*p.cont','760001','5')" title="하렘의 남자들-5화">하렘의 남자들-5화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail.nhn?titleId=733079&amp;no=61" onclick="nclk_v2(event,'rnk*p.cont','733079','6')" title="원수를 사랑하라-61화">원수를 사랑하라-61화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail.nhn?titleId=667573&amp;no=254" onclick="nclk_v2(event,'rnk*p.cont','667573','7')" title="연놈-254화. 우리 '오늘'을 '내일'도 가져가자">연놈-254화. 우리 '오늘'을 '내일'도 가져가자</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail.nhn?titleId=749639&amp;no=25" onclick="nclk_v2(event,'rnk*p.cont','749639','8')" title="남주의 첫날밤을 가져버렸다-25화">남주의 첫날밤을 가져버렸다-25화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail.nhn?titleId=738694&amp;no=35" onclick="nclk_v2(event,'rnk*p.cont','738694','9')" title="튜토리얼 탑의 고인물-35화">튜토리얼 탑의 고인물-35화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail.nhn?titleId=750184&amp;no=21" onclick="nclk_v2(event,'rnk*p.cont','750184','10')" title="나쁜사람-21화">나쁜사람-21화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# </ol>
# <ol class="asideBoxRank" id="realTimeRankUpdate" style="display:none;">
# <li class="rank01">
# <a href="/webtoon/detail.nhn?titleId=731939&amp;no=73" onclick="nclk_v2(event,'rnk*u.cont','731939','1')" title="나의 우주-후기">
#
# 					나의 우주-후기
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail.nhn?titleId=736699&amp;no=58" onclick="nclk_v2(event,'rnk*u.cont','736699','2')" title="저승사자 출입금지-58화. 신의 (11) ">
#
# 					저승사자 출입금지-58화. 신의 (11)
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail.nhn?titleId=662774&amp;no=217" onclick="nclk_v2(event,'rnk*u.cont','662774','3')" title="고수-2부 127화">
#
# 					고수-2부 127화
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail.nhn?titleId=701535&amp;no=167" onclick="nclk_v2(event,'rnk*u.cont','701535','4')" title="격기3반-ROUND 86. 채비 (2)">
#
# 					격기3반-ROUND 86. 채비 (2)
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail.nhn?titleId=761498&amp;no=2" onclick="nclk_v2(event,'rnk*u.cont','761498','5')" title="엔딩 후 서브남을 주웠다-2화">
#
# 					엔딩 후 서브남을 주웠다-2화
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail.nhn?titleId=728015&amp;no=172" onclick="nclk_v2(event,'rnk*u.cont','728015','6')" title="모죠의 일지-172화. 12월 블루">
#
# 					모죠의 일지-172화. 12월 블루
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail.nhn?titleId=743026&amp;no=36" onclick="nclk_v2(event,'rnk*u.cont','743026','7')" title="비스타-36화 비수">
#
# 					비스타-36화 비수
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail.nhn?titleId=725829&amp;no=86" onclick="nclk_v2(event,'rnk*u.cont','725829','8')" title="아도나이-85화">
#
# 					아도나이-85화
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail.nhn?titleId=750184&amp;no=21" onclick="nclk_v2(event,'rnk*u.cont','750184','9')" title="나쁜사람-21화">
#
# 					나쁜사람-21화
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail.nhn?titleId=717481&amp;no=117" onclick="nclk_v2(event,'rnk*u.cont','717481','10')" title="일렉시드-117화">
#
# 					일렉시드-117화
# 				</a>
# <span class="timeBox">
#
#
#
# 							2시간전
#
#
#
#
#
# 				</span>
# </li>
# </ol>
# </div>
# </div>
# <!-- //인기급상승만화 -->
# <!-- 추천 웹툰 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle"><img alt="30대 인기만화" height="11" id="recommand_ageImg" src="https://ssl.pstatic.net/static/comic/images/migration/common/h_30.gif" width="107"/>
# <div class="tab_nv">
# <a class="Nico_prv" href="#" id="recommandWebtoonRankLeftTabClick">이전</a><a class="Nico_nxt" href="#" id="recommandWebtoonRankRightTabClick">다음</a>
# </div>
# </h4>
# <div>
# <ul class="asideBoxTab">
# <li class="choice" id="recommandWebtoonRankMTabOver"><a href="#" onclick="return false;"> <img alt="남자" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_m.png" title="남자" width="21"/></a></li>
# <li id="recommandWebtoonRankWTabOver"><a href="#" onclick="return false;"> <img alt="여자" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_w.png" title="여자" width="21"/></a></li>
# </ul>
# <h3 class="blind" id="ageGenderRankBlindName">남자</h3>
# <ol class="asideBoxRank asideBoxRank2" id="recommandWebtoonRank">
# <li class="rank01" id="recommandLi_0">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=747269&amp;no=32" id="recommand_link_0" title="전지적 독자 시점">
# <img alt="전지적 독자 시점" height="33" id="recommand_thumbnail_0" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/747269/thumbnail/thumbnail_IMAG10_55801c29-223f-46a0-a446-2e55d3024e71.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=747269&amp;no=32" id="recommand_titleName_0" title="전지적 독자 시점">전지적 독자 시점</a>
# <em><a href="#" id="recommand_painter_0" onclick="return artistAction.viewArtist('747269', this);" title="UMI / 슬리피-C">UMI / 슬리피-C</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_0" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_0">0</em>
# </span>
# </div>
# </li>
# <li class="rank02" id="recommandLi_1">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=662774&amp;no=217" id="recommand_link_1" title="고수">
# <img alt="고수" height="33" id="recommand_thumbnail_1" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/662774/thumbnail/thumbnail_IMAG10_fddc4c8b-fbe6-422c-9777-590d98f4dc9e.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=662774&amp;no=217" id="recommand_titleName_1" title="고수">고수</a>
# <em><a href="#" id="recommand_painter_1" onclick="return artistAction.viewArtist('662774', this);" title="류기운 / 문정후">류기운 / 문정후</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_1" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_1">0</em>
# </span>
# </div>
# </li>
# <li class="rank03" id="recommandLi_2">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=626907&amp;no=325" id="recommand_link_2" title="복학왕">
# <img alt="복학왕" height="33" id="recommand_thumbnail_2" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/626907/thumbnail/title_thumbnail_20150407141027_t83x90.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=626907&amp;no=325" id="recommand_titleName_2" title="복학왕">복학왕</a>
# <em><a href="#" id="recommand_painter_2" onclick="return artistAction.viewArtist('626907', this);" title="기안84">기안84</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_2" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_2">0</em>
# </span>
# </div>
# </li>
# <li class="rank04" id="recommandLi_3">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=667573&amp;no=254" id="recommand_link_3" title="연놈">
# <img alt="연놈" height="33" id="recommand_thumbnail_3" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/667573/thumbnail/thumbnail_IMAG10_71dd6b56-3beb-4c03-82ce-d77cb470c46e.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=667573&amp;no=254" id="recommand_titleName_3" title="연놈">연놈</a>
# <em><a href="#" id="recommand_painter_3" onclick="return artistAction.viewArtist('667573', this);" title="상하">상하</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_3" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_3">0</em>
# </span>
# </div>
# </li>
# <li class="rank05" id="recommandLi_4">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=738694&amp;no=35" id="recommand_link_4" title="튜토리얼 탑의 고인물">
# <img alt="튜토리얼 탑의 고인물" height="33" id="recommand_thumbnail_4" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/738694/thumbnail/thumbnail_IMAG10_728d40b3-1224-4e00-b7a8-d16d9adbe137.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=738694&amp;no=35" id="recommand_titleName_4" title="튜토리얼 탑의 고인물">튜토리얼 탑의 고인물</a>
# <em><a href="#" id="recommand_painter_4" onclick="return artistAction.viewArtist('738694', this);" title="방구석김씨 / 오마감">방구석김씨 / 오마감</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_4" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_4">0</em>
# </span>
# </div>
# </li>
# </ol>
# </div>
# </div>
# <script>
# new naver.comic.RecommandWebtoonRankLayer(2, "https://shared-comic.pstatic.net/thumb");
# </script>
# <!-- //추천 웹툰 -->
# <!-- 공지사항 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle">
# <img alt="공지사항" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_notice.gif" title="공지사항" width="43"/>
# </h4>
# <ul class="asideBoxNotice">
# <li>
# <a href="/notice/detail.nhn?noticeId=417" onclick="nclk_v2(event,'sna.not','417','1')" title="2020 지상최대공모전 웹툰부문 2기 수상작 발표">
# <strong>
# 					2020 지상최대공모전 웹툰부문 2기 수상작 발표
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=421" onclick="nclk_v2(event,'sna.not','421','2')" title="네이버웹툰 미리보기/완결보기 컨텐츠별 이용가 관련 안내">
# <strong>
# 					네이버웹툰 미리보기/완결보기 컨텐츠별 이용가 관련 안내
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=352" onclick="nclk_v2(event,'sna.not','352','3')" title="[안내] 요일별 웹툰의 인기순 정렬 방식이 추가되었습니다.">
#
# 					[안내] 요일별 웹툰의 인기순 정렬 방식 추가
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=420" onclick="nclk_v2(event,'sna.not','420','4')" title="2020년 11월 베스트 도전만화 승격작 발표">
#
# 					2020년 11월 베스트 도전만화 승격작 발표
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=422" onclick="nclk_v2(event,'sna.not','422','5')" title="2020년 12월 유료화 전환 작품 안내">
#
# 					2020년 12월 유료화 전환 작품 안내
#
# 			</a>
# </li>
# </ul>
# <a class="asideBoxMore" href="/notice/list.nhn" onclick="nclk_v2(event,'sna.more')">
# <span class="blind">공지사항</span> 더보기
# 	</a>
# </div>
# <!-- //공지사항 -->
# <div class="asideBanner">
# <a href="/business/proposalGuide.nhn" onclick="nclk_v2(event,'sna.proposal');">
# <img alt="웹툰, 웹소설 온라인 광고 판권 사업" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_partnership.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://joinus.comic.naver.com" onclick="nclk_v2(event,'sna.writerproposal');">
# <img alt="연재 경력 작가 웹툰 차기작 제안" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_joinus.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://recruit.webtoonscorp.com" onclick="nclk_v2(event,'sna.recruit');">
# <img alt="웹툰 채용공고 CAREERS" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_careers.jpg" width="240"/>
# </a>
# </div>
# <div class="asideButton">
# <a class="btn_faq" href="https://help.naver.com/support/service/main.nhn?serviceNo=799" onclick="nclk_v2(event,'sna.faq')" target="_blank" title="새 창">
# <span class="blind">만화FAQ</span>
# </a>
# </div>
# </div>
# </div>
# <!-- Footer -->
# <!-- FOOTER Start -->
# <div id="footer">
# <div class="naver_corp_info">
# <ul>
# <li><a href="https://www.naver.com/rules/service.html" onclick="nclk_v2(event,'fot.agreement')" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://www.naver.com/rules/privacy.html" onclick="nclk_v2(event,'fot.privacy')" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" onclick="nclk_v2(event,'fot.disclaimer')" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/support/home.nhn?serviceNo=799" onclick="nclk_v2(event,'fot.helpdesk')" target="_blank" title="새 창">고객센터</a></li>
# <li><a href="/business/proposalGuide.nhn#ad" onclick="nclk_v2(event,'fot.proposal')" target="_blank">웹툰 광고 문의</a></li>
# </ul>
# <address><a href="https://www.navercorp.com/" onclick="nclk_v2(event,'fot.navercorp')" target="_blank"><span class="naver_corp_link"><span class="blind">ⓒ NAVER CORP.</span></span></a></address>
# </div>
# <div class="webtoon_corp_info">
# <ul>
# <li><a href="https://member.webtoon.naver.com/policies/terms/" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://member.webtoon.naver.com/policies/privacy/" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://member.webtoon.naver.com/policies/youthpolicy/" target="_blank">청소년보호정책</a></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=799" target="_blank">웹툰 고객센터</a></li>
# <li><a href="/business/proposalGuide.nhn" target="_blank">웹툰 사업 문의</a></li>
# </ul>
# <address><a class="webtoon_corp_link" href="https://webtoonscorp.com" onclick="nclk_v2(event,'fot.wtcorp');" target="_blank"><span class="blind">ⓒ NAVER WEBTOON Limited</span></a></address>
# </div>
# <p class="copyright_law">본 콘텐츠의 저작권은 저자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //FOOTER End -->
# </div>
# <script type="text/javascript">
# 			var agent = navigator.userAgent.toLowerCase();
#
# 			function loadEvent(){
# 				try{
# 					getGNB();
# 				}catch(ex){
#
# 				}
# 				new naver.comic.RealtimeRankLayer();
# 				if ( $("uploadLinkId") ){
# 					$Fn(function(oEvent) {
# 						oEvent.stop();
# 						if ("true" != "false") {
# 							if (!confirm('로그인해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 								return false;
# 							else {
# 								location.href = "https://nid.naver.com/nidlogin.login?mode=form&url="
# 										+ encodeURIComponent("https://" + location.host
# 												+ "/upload/upload.nhn");
# 								return;
# 							}
# 						}
# 						location.href = "/upload/upload.nhn";
# 						return true;
# 					}).attach($("uploadLinkId"),"click");
# 				}
# 				naver.comic.oArtistAction = new naver.comic.Artist();
# 				artistAction = naver.comic.oArtistAction;
# 				naver.comic.oSearchBar = new naver.comic.SearchBarOptionActHandler();
#
# 				// GNB 이벤트 재정의.
# 				$Fn(function(oEvent){
# 					var aWtChild = $Element("gnb" ).child(function (v){return true;});
# 					var wtSrc = $Element(oEvent.element);
# 					var bContain = false;
# 					for (var i = 0 ; i < aWtChild.length ;i++){
# 						if ( aWtChild[i].$value() == wtSrc.$value()){
# 							bContain = true;
# 							break;
# 						}
# 					}
# 					if ( !bContain && gnbAllLayerClose ){
# 						gnbAllLayerClose();
#
# 					}
#
# 				}).attach(document,"click");
# 			}
# 			$Fn(loadEvent).attach(window,'load');
# 		</script>
# <script src="/aggregate/javascript/release/lcslog_20201215100246.js" type="text/javascript"></script>
# <script type="text/javascript">
#     try {
#         var eventType = "onpageshow" in window ? "onpageshow" : "onload";
#         var oldEvent = window[eventType];
#         window[eventType] = function() {
#             if (oldEvent) {
#                 oldEvent();
#             }
#             lcs_do();
#         };
#     } catch(ex) { }
# </script>
# </body>
# </html>

# %%
ads=soup.find_all("td",attrs={"class":"title"})

# %%
for i in ads:
    print(i.a.get_text())
# Out:
# 136화
# 135화
# 134화
# 133화
# 132화
# 131화
# 130화
# 129화
# 128화
# 127화

# %%
#https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=4&backgroundColor=


#get 방식 -> ? 옆에 페이지, 뭐 maxprice 이런것들 입력해서 내가 원하는 값 얻을 수 있음

# %%
url = 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=4&backgroundColor='
import re
import requests
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"}
res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text, 'lxml')

# %%
items=soup.find_all("li",attrs={"class":re.compile("^search-product")})

# %%
items
# Out:
# [<li class="search-product " data-is-rocket="true" data-product-id="2175259737" data-vendor-item-id="71686722420" data-winner-vendor-item-id="71686722420" id="2175259737"><a class="search-product-link" data-is-soldout="" data-item-id="3701435464" data-product-id="2175259737" data-srp-log='{"group":"PRODUCT", "itemId":"3701435464", "productId":"2175259737", "vendorItemId":"71686722420", "page":"2", "listSize":"36", "isCcidEligible":false, "displayCcidBadge":false, "wowOnlyInstantDiscountRate": -1, "snsDiscountRate" : -1 }' data-vendor-item-id="71686722420" href="/vp/products/2175259737?itemId=3701435464&amp;vendorItemId=71686722420" target="_blank"><dl class="search-product-wrap"><dt class="image"> <img alt="MSI 게이밍 노트북 GF75 Thin 9SCSR (i7-9750H 43.94cm GTX 1650 Ti), 미포함, NVMe 512GB, 8GB" class="search-product-wrap-img" data-src="..." height="230" onerror="this.src='//img2a.coupangcdn.com/image/coupang/common/no_img_1000_1000.png'" onload="logTime(this);logImageLoadTime(this);" src="//thumbnail7.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2020/09/21/8/7/e907f6ca-f890-4ce8-af9c-31b4943341c0.jpg" width="230"/> </dt><dd class="descriptions"><div class="descriptions-inner"><div class="badges"> </div><div class="name">MSI 게이밍 노트북 GF75 Thin 9SCSR (i7-9750H 43.94cm GTX 1650 Ti), 미포함, NVMe 512GB, 8GB</div> <div class="price-area"> <div class="price-wrap">
#  <div class="price"> <span class="price-info">
#  <del class="base-price">1,199,000</del> </span> <em class="sale ">
#  <strong class="price-value">1,191,440</strong>원
#          <span class="badge rocket"> <img alt="로켓배송" height="16" src="//image10.coupangcdn.com/image/badges/rocket/rocket_logo.png"/>
#  </span> </em> </div>
#  <div class="delivery"><span class="arrival-info"> <em style="color:#00891A">내일(목) 12/24  </em> <em style="color:#00891A">도착 보장 </em> </span></div>
#  <div class="delivery"> <span class="badge falcon"><img alt="로켓직구" height="16" src="//image8.coupangcdn.com/image/badges/falcon/v1/web/rocketwow-bi-16@2x.png"/> </span> <span class="arrival-info"> <em style="color:#00891A">오늘(수)  </em> <em style="color:#00891A">도착 보장 </em> </span>
#  </div> </div>
#  </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(1)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 50,000원 적립</span></div></div></div></div></dd></dl><div class="mask"></div></a></li>,
#  <li class="search-product " data-is-rocket="true" data-product-id="1749496900" data-vendor-item-id="70967713245" data-winner-vendor-item-id="70967713245" id="1749496900"><a class="search-product-link" data-is-soldout="" data-item-id="2979354702" data-product-id="1749496900" data-srp-log='{"group":"PRODUCT", "itemId":"2979354702", "productId":"1749496900", "vendorItemId":"70967713245", "page":"2", "listSize":"36", "isCcidEligible":true, "displayCcidBadge":true, "wowOnlyInstantDiscountRate": -1, "snsDiscountRate" : -1 }' data-vendor-item-id="
target="_blank"><dl class="search-product-wrap"><dt class="image"> <img alt="에이수스 ZenBook14 UX434FLC-A6267T (i7-10510U 35.56cm WIN10 MX250), 포함, 1TB SSD, 16GB" class="search-product-wrap-img" data-img-src="//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2020/06/16/12/3/72a53d34-8394-47ab-8bce-d2faa3853613.jpg" data-src="..." height="230" onerror="this.src='//img2a.coupangcdn.com/image/coupang/common/no_img_1000_1000.png'" src="//img1a.coupangcdn.com/image/coupang/search/blank1x1.gif" width="230"/> </dt><dd class="descriptions"><div class="descriptions-inner"><div class="badges"> </div><div class="name">에이수스 ZenBook14 UX434FLC-A6267T (i7-10510U 35.56cm WIN10 MX250), 포함, 1TB SSD, 16GB</div> <div class="price-area"> <div class="price-wrap">
#  <div class="price"> <em class="sale ">
#  <strong class="price-value">1,499,000</strong>원
#          <span class="badge rocket"> <img alt="로켓배송" height="16" src="//image10.coupangcdn.com/image/badges/rocket/rocket_logo.png"/>
#  </span> </em> </div>
#  <div class="delivery"><span class="arrival-info"> <em style="color:#00891A">내일(목) 12/24  </em> <em style="color:#00891A">도착 보장 </em> </span></div>
#  <div class="delivery"> <span class="badge falcon"><img alt="로켓직구" height="16" src="//image8.coupangcdn.com/image/badges/falcon/v1/web/rocketwow-bi-16@2x.png"/> </span> <span class="arrival-info"> <em style="color:#00891A">오늘(수)  </em> <em style="color:#00891A">도착 보장 </em> </span>
#  </div> </div>
#  </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(6)</span></div></div><div class="benefit-badges"><div class="ccid-badge"><div class="ccid-badge__inr"><img alt="" class="credit-card-ico" src="//image9.coupangcdn.com/image/badges/ccid/list/web/card_icon@2x.png"/> <span class="ccid-txt">최대 7% 카드 즉시할인</span></div></div> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 50,000원 적립</span></div></div></div></div></dd></dl><div class="mask"></div></a></li>,
#  <li class="search-product " data-is-rocket="true" data-product-id="1383141072" data-vendor-item-id="70411889853" data-winner-vendor-item-id="70411889853" id="1383141072"><a class="search-product-link" data-is-soldout="" data-item-id="2417655164" data-product-id="1383141072" data-srp-log='{"group":"PRODUCT", "itemId":"2417655164", "productId":"1383141072", "vendorItemId":"70411889853", "page":"2", "listSize":"36", "isCcidEligible":false, "displayCcidBadge":false, "wowOnlyInstantDiscountRate": -1, "snsDiscountRate" : -1 }' data-vendor-item-id="70411889853" href="/vp/products/1383141072?itemId=2417655164&amp;vendorItemId=70411889853" target="_blank"><dl class="search-product-wrap"><dt class="image"> <img alt="LG전자 울트라PC 13U50N-GR56K (i5-10210U 33.7cm WIN10 UHD graphics), 포함, SSD 256GB, 8GB" class="search-product-wrap-img" data-img-src="//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2020/03/18/18/3/de1a5b25-9106-48b0-a538-1af8157cf98a.jpg" data-src="..." height="230" onerror="this.src='//img2a.coupangcdn.com/image/coupang/common/no_img_1000_1000.png'" src="//img1a.coupangcdn.com/image/coupang/search/blank1x1.gif" width="230"/> </dt><dd class="descriptions"><div class="descriptions-inner"><div class="badges"> <span class="badge badge-benefit ">추가할인 쿠폰</span> </div><div class="name">LG전자 울트라PC 13U50N-GR56K (i5-10210U 33.7cm WIN10 UHD graphics), 포함, SSD 256GB, 8GB</div> <div class="price-area"> <div class="price-wrap">
#  <div class="price"> <span class="price-info">
#  <span class="instant-discount-price">와우할인가</span>
#  <span class="instant-discount-rate">6%</span>
#  <del class="base-price">998,940</del> </span> <em class="sale ">
#  <strong class="price-value">935,940</strong>원
#          <span class="badge rocket"> <img alt="로켓배송" height="16" src="//image10.coupangcdn.com/image/badges/rocket/rocket_logo.png"/>
#  </span> </em> </div>
#  <div class="delivery"><span class="arrival-info"> <em style="color:#00891A">내일(목) 12/24  </em> <em style="color:#00891A">도착 보장 </em> </span></div>
#  <div class="delivery"> <span class="badge falcon"><img alt="로켓직구" height="16" src="//image8.coupangcdn.com/image/badges/falcon/v1/web/rocketwow-bi-16@2x.png"/> </span> <span class="arrival-info"> <em style="color:#00891A">오늘(수)  </em> <em style="color:#00891A">도착 보장 </em> </span>
#  </div> </div>
#  </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(10)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 46,797원 적립</span></div></div></div></div></dd></dl><div class="mask"></div></a></li>,
#  <li class="search-product " data-is-rocket="" data-product-id="2035153103" data-vendor-item-id="71447085043" data-winner-vendor-item-id="71447085043" id="2035153103"><a class="search-product-link" data-is-soldout="" data-item-id="3460717014" data-product-id="2035153103" data-srp-log='{"group":"PRODUCT", "itemId":"3460717014", "productId":"2035153103", "vendorItemId":"71447085043", "page":"2", "listSize":"36", "isCcidEligible":false, "displayCcidBadge":false, "wowOnlyInstantDiscountRate": -1, "snsDiscountRate" : -1 }' data-vendor-item-id="71447085043" href="/vp/products/2035153103?itemId=3460717014&amp;vendorItemId=71447085043" target="_blank"><dl class="search-product-wrap"><dt class="image"> <img alt="[가성비 끝판왕] Lenovo V15-ADA [Windows10 Pro 포함], 4GB, SSD 128GB, Windows10 Pro" class="search-product-wrap-img" data-img-src="//thumbnail6.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/c820/6125bf7af6e0964be236c0fb47bcaebe7e152bd1dcb514f7a569ff73a204.jpg" data-src="..." height="230" onerror="this.src='//img2a.coupangcdn.com/image/coupang/common/no_img_1000_1000.png'" src="//img1a.coupangcdn.com/image/coupang/search/blank1x1.gif" width="230"/> </dt><dd class="descriptions"><div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery ">무료배송</span> </div><div class="name">[가성비 끝판왕] Lenovo V15-ADA [Windows10 Pro 포함], 4GB, SSD 128GB, Windows10 Pro</div> <div class="price-area"> <div class="price-wrap">
#  <div class="price"> <span class="price-info">
#  <span class="instant-discount-rate">1%</span>
#  <del class="base-price">568,000</del> </span> <em class="sale ">
#  <strong class="price-value">558,000</strong>원    </em> </div>
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">토요일 12/26  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div>
#  </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(9)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 27,900원 적립</span></div></div></div></div></dd></dl><div class="mask"></div></a></li>,
#  <li class="search-product " data-is-rocket="" data-product-id="2239089587" data-vendor-item-id="71809156405" data-winner-vendor-item-id="71809156405" id="2239089587"><a class="search-product-link" data-is-soldout="" data-item-id="3824288421" data-product-id="2239089587" data-srp-log='{"group":"PRODUCT", "itemId":"3824288421", "productId":"2239089587", "vendorItemId":"71809156405", "page":"2", "listSize":"36", "isCcidEligible":false, "displayCcidBadge":false, "wowOnlyInstantDiscountRate": -1, "snsDiscountRate" : -1 }' data-vendor-item-id="71809156405" href="/vp/products/2239089587?itemId=3824288421&amp;vendorItemId=71809156405" target="_blank"><dl class="search-product-wrap"><dt class="image"> <img alt="LG전자 6세대 코어i5 윈10탑재 LG 그램 14Z960 화이트, 4GB, SSD 256GB, 포함" class="search-product-wrap-img" data-img-src="//thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/c9ef/661dfba92179390f931aeeca450554c8b7eec67be17b29783d6ced43b957.jpg" data-src="..." height="230" onerror="this.src='//img2a.coupangcdn.com/image/coupang/common/no_img_1000_1000.png'" src="//img1a.coupangcdn.com/image/coupang/search/blank1x1.gif" width="230"/> </dt><dd class="descriptions"><div class="descriptions-inner"><div class="badges"> <span class="badge badge-delivery ">무료배송</span> </div><div class="name">LG전자 6세대 코어i5 윈10탑재 LG 그램 14Z960 화이트, 4GB, SSD 256GB, 포함</div> <div class="price-area"> <div class="price-wrap">
#  <div class="price"> <span class="price-info">
#  <span class="instant-discount-rate">28%</span>
#  <del class="base-price">1,098,000</del> </span> <em class="sale ">
#  <strong class="price-value">789,000</strong>원    </em> </div>
#  <div class="delivery"><span class="arrival-info"> <em style="color:#111111">화요일 12/29  </em> <em style="color:#111111">도착 예정 </em> </span></div> </div>
#  </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:90%">4.5</em></span> <span class="rating-total-count">(9)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 39,450원 적립</span></div></div></div></div></dd></dl><div class="mask"></div></a></li>,
#  <li class="search-product " data-is-rocket="" data-product-id="1473463084" data-vendor-item-id="70727191718" data-winner-vendor-item-id="70727191718" id="1473463084"><a class="search-product-link" data-is-soldout="" data-item-id="2532514443" data-product-id="1473463084" data-srp-log='{"group":"PRODUCT", "itemId":"2532514443", "productId":"1473463084", "vendorItemId":"70727191718", "page":"2", "listSize":"36", "isCcidEligible":false, "displayCcidBadge":false, "wowOnlyInstantDiscountRate": -1, "snsDiscountRate" : -1 }' data-vendor-item-id="
thumbnail9.coupangcdn.com/thumbnails/remote/230x230ex/image/retail/images/2020/06/05/11/5/584abe9b-2137-4e3a-afa9-ecb6c2ee43a9.jpg" data-src="..." height="230" onerror="this.src='//img2a.coupangcdn.com/image/coupang/common/no_img_1000_1000.png'" src="//img1a.coupangcdn.com/image/coupang/search/blank1x1.gif" width="230"/> </dt><dd class="descriptions"><div class="descriptions-inner"><div class="badges"> </div><div class="name">주연테크 라이트플라이 울트라북 967g 노트북 Cool Gray J7FCW (10세대 i5-10210U WIN10 Home), 8GB, NVMe 256GB, 포함</div> <div class="price-area"> <div class="price-wrap">
#  <div class="price"> <span class="price-info">
#  <span class="instant-discount-rate">10%</span>
#  <del class="base-price">1,008,000</del> </span> <em class="sale ">
#  <strong class="price-value">898,000</strong>원
#          <span class="badge rocket"> <img alt="로켓배송" height="16" src="//image10.coupangcdn.com/image/badges/rocket/rocket_logo.png"/>
#  </span> </em> </div>
#  <div class="delivery"><span class="arrival-info"> <em style="color:#00891A">내일(목) 12/24  </em> <em style="color:#00891A">도착 보장 </em> </span></div>
#  <div class="delivery"> <span class="badge falcon"><img alt="로켓직구" height="16" src="//image8.coupangcdn.com/image/badges/falcon/v1/web/rocketwow-bi-16@2x.png"/> </span> <span class="arrival-info"> <em style="color:#00891A">오늘(수)  </em> <em style="color:#00891A">도착 보장 </em> </span>
#  </div> </div>
#  </div><div class="other-info"><div class="rating-star"><span class="star"><em class="rating" style="width:100%">5.0</em></span> <span class="rating-total-count">(6)</span></div></div><div class="benefit-badges"> <div class="reward-cash-badge"><div class="reward-cash-badge__inr"><img alt="" class="reward-cash-ico" src="//image6.coupangcdn.com/image/badges/cashback/web/list-cash-icon@2x.png"/> <span class="reward-cash-txt">최대 44,900원 적립</span></div></div></div></div></dd></dl><div class="mask"></div></a></li>]

# %%
for i in items:
    ad_badge = i.find("span",attrs={"class":"ad-badge-text"})
    if ad_badge:
        print("광고상품")
        continue
    #continue는 포문 다음으로 넘김 근데 pass는 계속 진행됨 차이 잘 알기
    name = i.find("div",attrs={"class":"name"}).get_text()
    price = i.find("strong",attrs={"class":"price-value"}).get_text()
    rating = i.find("em",attrs={"class":"rating"})
    if rating:
        rating2 = rating.get_text()
    else:
        rating2 ="평점 없음"
    rate_cnt = i.find("span",attrs={"class":"rating-total-count"})
    if rate_cnt:
        rate_cnt2 = rate_cnt.get_text()
    #else:
    #    rate_cnt2 ="평점 없음"
    print("제품명 :{0}, 가격 :{1}, 평점 : {2}, 평점참여자수 :{3}".format(name,price,rating2,rate_cnt2))
# Out:
# 제품명 :MSI 게이밍 노트북 GF75 Thin 9SCSR (i7-9750H 43.94cm GTX 1650 Ti), 미포함, NVMe 512GB, 8GB, 가격 :1,191,440, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :에이수스 VivoBook 노트북 투명 실버 X412FA-EB957(i5-10210U 35.5cm), 미포함, NVMe 256GB, 8GB, 가격 :744,280, 평점 : 5.0, 평점참여자수 :(9)
# 제품명 :레노버 Ideapad Slim3-14IIL 5W 노트북 어비스블루 81WD002LKR (i5-1035G4 35.5cm WIN10 Home), 포함, NVMe 256GB, 4GB, 가격 :699,000, 평점 : 4.5, 평점참여자수 :(4)
# 제품명 :레노버 아이디어패드 노트북 아이스블루 S150-11 PRO (셀러론 N4020 29.5cm), 미포함, NVMe 128GB, 4GB, 가격 :289,000, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :레노버 IdeaPad Duet3 노트북 Graphite Grey 10IGL05-82AT0028KR (셀러론-N4020 26.162cm WIN10 Home S), 포함, eMMC 64GB, 4GB, 가격 :499,000, 평점 : 4.5, 평점참여자수 :(2)
# 제품명 :아이뮤즈 스톰북 15프로 (m3-6y30 39.6cm WIN10 8GB eMMC 64GB), StormBook15 PRO, 로즈골드, 가격 :605,640, 평점 : 4.5, 평점참여자수 :(13)
# 제품명 :LG전자 2020 그램15 노트북 15Z90N-VR56K (i5-1035G7 39.6cm), NVMe 512GB, 8GB, WIN10 Home, 가격 :1,669,700, 평점 : 5.0, 평점참여자수 :(101)
# 제품명 :레노버 ideapad S340-13IML 5D 노트북 81UM003QKR Platinum Grey(i5-10210U 33.7cm WIN미포함), 미포함, SSD 256GB, 8GB, 가격 :644,000, 평점 : 4.5, 평점참여자수 :(28)
# 제품명 :MSI 노트북 Modern 14 B4MW-R7 (라이젠7-4700U 35.5cm), 미포함, NVMe 256GB, 8GB, 가격 :753,120, 평점 : 5.0, 평점참여자수 :(13)
# 제품명 :삼성전자 갤럭시북 S NT767XCM-K58S Mercury Gray (Wi-Fi전용 i5-L16G7 33.7cm Win10 Home), 포함, eUFS 256GB, 8GB, 가격 :1,279,000, 평점 : 5.0, 평점참여자수 :(16)
# 제품명 :Apple 2020 맥북 에어 13, Space gray, 10세대 i3-1.1GHz dual-core, SSD 256GB, 8GB, 가격 :1,241,600, 평점 : 5.0, 평점참여자수 :(913)
# 제품명 :Apple 2020년 맥북 프로 13 (M1 칩셋 8코어 CPU 8코어 GPU), 스페이스 그레이, SSD 256GB, 가격 :1,690,000, 평점 : 3.5, 평점참여자수 :(3)
# 제품명 :에이수스 ZenBook14 UX434FLC-A6267T (i7-10510U 35.56cm WIN10 MX250), 포함, 1TB SSD, 16GB, 가격 :1,499,000, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :LG전자 울트라PC 13U50N-GR56K (i5-10210U 33.7cm WIN10 UHD graphics), 포함, SSD 256GB, 8GB, 가격 :935,940, 평점 : 5.0, 평점참여자수 :(10)
# 제품명 :[가성비 끝판왕] Lenovo V15-ADA [Windows10 Pro 포함], 4GB, SSD 128GB, Windows10 Pro, 가격 :558,000, 평점 : 5.0, 평점참여자수 :(9)
# 제품명 :LG전자 6세대 코어i5 윈10탑재 LG 그램 14Z960 화이트, 4GB, SSD 256GB, 포함, 가격 :789,000, 평점 : 4.5, 평점참여자수 :(9)
# 제품명 :LG LG그램 LG노트북 i3-6세대 8G SSD256G 14인치 WIN10, 8GB, 256GB, 포함, 가격 :699,000, 평점 : 4.0, 평점참여자수 :(62)
# 제품명 :삼성전자 갤럭시북 S NT767XCM-K58 Earth Gold (Wi-Fi전용 i5-L16G7 33.7cm Win10 Home), 포함, eUFS 256GB, 8GB, 가격 :1,298,000, 평점 : 4.5, 평점참여자수 :(14)
# 제품명 :레노버 노트북 L540 리퍼 i5-4200/4G/SSD128G/Win10, 가격 :299,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :에이수스 비보북 노트북 슬레이트 그레이 X509JA-CP002 (i5-1035G1 39.6cm), 미포함, NVMe 512GB, 8GB, 가격 :679,000, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :LG전자 울트라 PC 노트북 15U590-KA70K (i7-8565U 39.6cm MX 150), SSD 256GB, 8GB, WIN10 Home, 가격 :1,298,000, 평점 : 5.0, 평점참여자수 :(22)
# 제품명 :LG전자 2019 울트라 PC 노트북 15UD490-GX76K (라이젠 R7-2700U 39.6cm), SSD 256GB, 8GB, Free DOS, 가격 :879,000, 평점 : 4.5, 평점참여자수 :(12)
# 제품명 :삼성전자 노트북 Pen NT930QBE-K37WD Crush White (i3-8145U 33.7cm Win10 Home), 포함, NVMe 256GB, 8GB, 가격 :1,199,000, 평점 : 4.5, 평점참여자수 :(25)
# 제품명 :LG전자 울트라 PC 노트북 17U70N-GA56K 다크실버 (i5-10210U 43.1cm), NVMe 256GB, 8GB, WIN10 Home, 가격 :1,397,820, 평점 : 5.0, 평점참여자수 :(21)
# 제품명 :레노버 아이디어 패드 노트북 ONIX BLACK S530-13IWL 81J7000KKR (lnitel i5-8265U 33.78cm WIN10 Home Intel UHD Graphics 620), 포함, NVMe 256GB, 8GB, 가격 :799,000, 평점 : 1.0, 평점참여자수 :(1)
# 제품명 :삼성전자 갤럭시북 플렉스 노트북 NT930QCT-A38A 로얄 블루 (i3-1005G1 33.7cm) + 스마트 S펜, 미포함, NVMe 512GB, 8GB, 가격 :1,627,000, 평점 : 4.0, 평점참여자수 :(37)
# 제품명 :에이수스 젠북플립14 라이트 그레이 UM462DA-AI082 (R5-3500U 35.56Cm WIN미포함 라데온 Vega8 Graphics), 미포함, SSD 512GB, 8GB, 가격 :879,000, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :중고노트북 10만원대 삼성 LG HP 등, 단일색상, [A] 레노버EDGE, 가격 :109,000, 평점 : 4.0, 평점참여자수 :(43)
# 제품명 :LG전자 10세대 코어i7 윈10탑재 17형 LG 그램 2020년형 17Z90N-VA76K 그레이 정품키스킨 증정, 16GB, SSD 512GB, 포함, 가격 :1,689,000, 평점 : 4.5, 평점참여자수 :(32)
# 제품명 :Apple 2020 맥북 에어 13, Gold, 10세대 i3-1.1GHz dual-core, SSD 256GB, 8GB, 가격 :1,254,000, 평점 : 5.0, 평점참여자수 :(913)
# 제품명 :레노버 Flex 5 노트북 14ARE R7 W10 (라이젠7-4700U 35.5cm WIN10 Home Radeon Graphics), 포함, NVMe 256GB, 8GB, 가격 :999,000, 평점 : 4.5, 평점참여자수 :(16)
# 제품명 :LG전자 울트라PC 17U790-GA76K (i7-8565U 43.1cm) + 무선마우스 + 키스킨 + 마우스 패드 + HDMI 케이블, NVMe 256GB, 8GB, WIN10 Home, 가격 :1,286,780, 평점 : 5.0, 평점참여자수 :(4)
# 제품명 :한성컴퓨터 노트북 올데이롱 블랙 TFX255S (i5-10210U 39.62cm WIN미포함), 미포함, SSD 500GB, 8GB, 가격 :799,000, 평점 : 5.0, 평점참여자수 :(74)
# 제품명 :LG전자 2020 그램 2in1 노트북 14TD90N-VX30K (i3-10110U 35.5cm), NVMe 256GB, 8GB, Free DOS, 가격 :1,319,000, 평점 : 4.5, 평점참여자수 :(31)
# 제품명 :[가성비 끝판왕] Lenovo V15-ADA [Windows10 Pro 포함], 12GB, SSD 512GB, Windows10 Pro, 가격 :653,000, 평점 : 5.0, 평점참여자수 :(9)
# 제품명 :주연테크 라이트플라이 울트라북 967g 노트북 Cool Gray J7FCW (10세대 i5-10210U WIN10 Home), 8GB, NVMe 256GB, 포함, 가격 :898,000, 평점 : 5.0, 평점참여자수 :(6)
