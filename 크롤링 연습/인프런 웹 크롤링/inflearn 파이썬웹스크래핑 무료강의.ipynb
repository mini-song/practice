# %%
import requests

# %%
url = "https://nadocoding.tistory.com"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"}
res = requests.get(url,headers = headers)
#user Agent -> 익스플로어 or 크롬에 따라 다르게 표현
#user Agent string이라고 검색

# %%
res.raise_for_status()

# %%
#res.text

# %%
with open('mygoogle.html', 'w' ,encoding = 'utf-8') as f:
    f.write(res.text)

# %%
'''
import re
p=re.compile("ca.e")
re.compile("^de")
re.compile("ce&")


m = p.match("cafeless") #-> cafe 뒷부분에 다른 말이 와도 매치됨 
#match는 앞에
if m:
    print(m.group())
else:
    print("matchx")
    
# search는 중간에 있어도 ㄱㅊ
'''
# Out:
# '\nimport re\np=re.compile("ca.e")\nre.compile("^de")\nre.compile("ce&")\n\n\nm = p.match("cafeless") #-> cafe 뒷부분에 다른 말이 와도 매치됨 \n#match는 앞에\nif m:\n    print(m.group())\nelse:\n    print("matchx")\n    \n# search는 중간에 있어도 ㄱㅊ\n'

# %%
from bs4 import BeautifulSoup

# %%
url ="https://comic.naver.com/webtoon/weekday.nhn"

# %%
res = requests.get(url)
res.raise_for_status()
soup = BeautifulSoup(res.text, "lxml")

# %%
soup.title.get_text()
# Out:
# '네이버 만화 > 요일별  웹툰 > 전체웹툰'

# %%
soup.a.get_text() #-> a중에 제일빠른애 나옴
# Out:
# '메인 메뉴로 바로가기'

# %%
a=soup.find_all

# %%
rank1=soup.find("li",attrs={"class":"rank01"})

# %%
rank1.get_text()
# Out:
# '\n전지적 독자 시점-033. Ep.08 긴급 방어전 (1)\n\n 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n'

# %% [markdown]
# 형제관계 previous silbing도 가능

# %%
rank1.find_next_sibling("li").get_text()
# Out:
# '\n고수-2부 129화\n\n 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n'

# %%
rank1.find_next_siblings
# Out:
# <bound method PageElement.find_next_siblings of <li class="rank01">
# <a href="/webtoon/detail.nhn?titleId=747269&amp;no=34" onclick="nclk_v2(event,'rnk*p.cont','747269','1')" title="전지적 독자 시점-033. Ep.08 긴급 방어전 (1)">전지적 독자 시점-033. Ep.08 긴급 방어전 (1)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>>

# %%
abc=soup.find_all("a", attrs={"class":"title"})

# %%
for i in abc:
    print(i.get_text())
# Out:
# 참교육
# 뷰티풀 군바리
# 백수세끼
# 윈드브레이커
# 소녀의 세계
# 장씨세가 호위무사
# 만렙돌파
# 파이게임
# 앵무살수
# 바이러스X
# 유일무이 로맨스
# 칼가는 소녀
# 요리GO
# 오늘의 순정망화
# 히어로메이커
# 순정말고 순종
# 결혼생활 그림일기
# 싸이코 리벤지
# 이탄국의 자청비
# 리턴 투 플레이어
# 개밥 먹는 남자
# 이것도 친구라고
# 라서드
# 아는 여자애
# 삶이 우리를 속일지라도
# 사장님을 잠금해제
# 꿈의 기업
# 왕따협상
# 서브 콤플렉스
# 침범
# 선배, 그 립스틱 바르지마요
# 피플
# 와이키키 뱀파이어
# 도플갱어의 게임
# 두근두근 네가 좋아서
# 보살님이 캐리해!
# 이중첩자
# 뱀파이어의 꽃
# 정보전사 202
# 안녕 나의 모모로
# 원하는 건 너 하나
# 지구멸망버튼
# 인간의 온도
# 하슬라
# 여기 악마가 있어
# 드로잉 레시피
# 백호랑
# 모락모락 왕세자님
# 블루투스
# 헬로맨스
# 평범한 8반
# 여신강림
# 관계의 종말
# 한림체육관
# 바른연애 길잡이
# 하루만 네가 되고 싶어
# 랜덤채팅의 그녀!
# 사신소년
# 후기
# 중증외상센터 : 골든 아워
# 호랑이 들어와요
# 헬58
# 신도림
# 삼국지톡
# 원주민 공포만화
# 달콤살벌한 부부
# 집이 없어
# 아이레
# 오늘의 순정망화
# 견우와 선녀
# 윌유메리미
# 체크포인트
# 성인초딩
# 용왕님의 셰프가 되었습니다
# 플레이, 플리
# 신의 언어
# 빅맨
# 오피스 누나 이야기
# 정년이
# 3cm 헌터
# 별종
# 피로만땅
# 그놈은 흑염룡
# 열녀박씨 계약결혼뎐
# 제로게임
# 올가미
# 한강예찬
# 은주의 방 2~3부
# 나의 플랏메이트
# 연우의 순정
# 오파츠
# 숲속의 담
# 인문학적 감수성
# 빛빛빛
# 조선홍보대행사 조대박
# 완벽한 가족
# 그날 죽은 나는
# 도를 아십니까
# 자판귀
# 언메이크
# 너에게만 보이는
# 안식의 밤
# 필살VS로맨스
# 아이고 아이고
# 저세상 클라스!
# 장단에 맞춰줘!
# 고수
# 전지적 독자 시점
# 복학왕
# 모죠의 일지
# 하렘의 남자들
# 격기3반
# 튜토리얼 탑의 고인물
# 노곤하개
# 캐슬
# 여주실격!
# 남주의 첫날밤을 가져버렸다
# 엔딩 후 서브남을 주웠다
# 연놈
# 원수를 사랑하라
# 고삼무쌍
# 일렉시드
# 닥터앤닥터 육아일기
# 나쁜사람
# 사상최강
# 판타지 여동생!
# 말하는대로
# 빌드업
# 세상은 돈과 권력
# 마녀와 용의 신혼일기
# 각자의 디데이
# 귀곡의 문
# 언덕 위의 제임스
# 마른 가지에 바람처럼
# 정순애 식당
# 방탈출
# 로어 올림푸스
# 미래의 골동품 가게
# 아도나이
# 범이올시다!
# 새벽 두 시의 신데렐라
# 얼굴천재
# 더 트웰브
# 속보입니다
# 당신의 향수
# 평화선도부
# 럭키언럭키
# 이츠마인
# 인터셉트
# 기억흔적
# 스캔들
# 천도
# 시효완성
# 수상한 비밀상담부
# 스몰
# 저승사자 출입금지
# FM보이
# 비스타
# 노선도
# 뱀은 꽃을 먹는가
# 해귀
# 독립일기
# 연애혁명
# 더 복서
# 기기괴괴
# 이두나!
# 노답소녀
# 간 떨어지는 동거
# 나노마신
# 화이트 블러드
# 하드캐리
# 전자오락수호대
# 던전 씹어먹는 아티팩트
# 무사만리행
# 겟백
# 꽃만 키우는데 너무강함
# 병의 기록
# 오늘의 순정망화
# 당신의 과녁
# 쿠베라
# 트롤트랩
# 신비
# 선의의 경쟁
# 자취방 신선들
# 달의 요람
# 정글쥬스
# 시월드 판타지
# 최강전설 강해효
# 롤랑롤랑
# 별을 삼킨 너에게
# 셧업앤댄스
# 바른탕진 프로젝트
# 날 가져요
# 성스러운 아이돌
# 헬프미
# 로그아웃
# 오일머니
# 킬더킹
# 집사레인저
# 겟라이프
# 우리는 요정!
# 셈하는 사이
# 소녀180
# 안개무덤
# 미드나잇 체이서
# 보물과 괴물의 도시
# 손아귀
# 불릿 6미리
# 카루나
# 스테어스
# 온새미로
# 깁스맨
# 악령주의보
# 밤하늘에 구름운
# 외모지상주의
# 여성전용헬스장 진달래짐
# 갓 오브 하이스쿨
# 관계의 종말
# 데드퀸
# 재혼 황후
# 1초
# 개를 낳았다
# 삼국지톡
# 살人스타그램
# 낙향문사전
# 뫼신 사냥꾼
# 더 게이머
# 걸어서 30분
# 세기말 풋사과 보습학원
# 난약
# 감자마을
# 냐한남자
# 플레이어
# 복학생 정순이
# 구남친이 내게 반했다
# 방과후 선녀
# 성경의 역사
# 가슴털 로망스
# 히트포인트
# 고래별
# 신상 미스터리 극장
# 상남자
# 스포
# 금혼령-조선혼인금지령
# 낢다른 광화문광장 이야기
# 피와 나비
# 도무지 그애는
# 소심한 팔레트
# 닥터 프로스트 시즌 3~4
# 도롱이
# 얌전한 사이
# 후덜덜덜 남극전자
# 강림전기 개정기
# 진짜 정말 맹세코 좋아해
# 백년게임
# 구독금지
# 트럼프
# 나쁜 쪽으로
# 감히
# 몽홀
# 9등급 뒤집기
# 스윗솔티
# 너의 미소가 함정
# 합법해적 파르페
# 매지컬 메디컬
# 구주의 시간
# 프리드로우
# 호랑이형님
# 모죠의 일지
# 취사병 전설이 되다
# 비질란테
# 힙한남자
# 초인의 시대
# 노곤하개
# 스터디그룹
# 광장
# 욕망일기
# 청춘 블라썸
# 토끼대왕
# 민간인 통제구역
# 왕년엔 용사님
# 어글리후드
# 나이트런
# 아홉수 우리들
# 나를 바꿔줘
# 윌유메리미
# 지옥급식
# 두번째 생일
# 갓핑크
# 탑코너
# 동트는 로맨스
# 단편.zip
# 먹이
# 태백 : 튜토리얼 맨
# 남자주인공의 여자사람친구입니다
# 공유몽
# 광해의 연인
# 홍시는 날 좋아해!
# 틴맘
# 내게 필요한 NO맨스
# 팔려 온 신부
# 피라미드 게임
# 오늘부터 천생연분
# 웰캄투실버라이프
# 압락사스
# 친구의 비밀계정
# 군주
# 저무는 해, 시린 눈
# 동네몬스터
# 언플래시레슨
# 피노키오 소녀
# 아테나 컴플렉스
# 아침을 지나 밤으로
# 후아유!
# 손 잡아 볼래?
# 인간졸업
# 도사 가온
# 회춘
# 안녕, 이바다씨
# 꼬리 있는 연애
# 누군가의 로섬
# 커피도둑
# 함부로 대해줘
# 먹지마세요
# 왕세자 입학도
# 독립일기
# 싸움독학
# 열렙전사
# 이번 생도 잘 부탁해
# 입학용병
# 맘마미안
# 테러대부활
# 소녀재판
# 천하제일인
# 곱게 키웠더니, 짐승
# 닥터앤닥터 육아일기
# 도망자
# 두근두근 연극부
# 오로지 너를 이기고 싶어
# 경비 배두만
# 행성인간
# 합격시켜주세용
# 마법스크롤 상인 지오
# 인어를 위한 수영교실
# 판사 이한영
# 라커, 오프너
# 내일
# 구름이 피워낸 꽃
# 벚꽃이 흩날릴 무렵
# 로어 올림푸스
# 결혼까지 망상했어!
# AI가 세상을 지배한다면
# 가비지타임
# 다이스(DICE)
# 별이삼샵
# 오늘 밤만 재워줘
# 강남도깨비
# 데빌샷
# 학교정벌
# 약한영웅
# 아르세니아의 마법사
# 라일락 200%
# 오른눈이 보는 세계
# 평행도시
# 잉여특공대
# 무주의 맹시
# 스트러글
# 신이 담긴 아이
# 오늘도 사랑하세요
# 소녀 해미
# Here U Are
# 호시탐탐
# 샤인 스타
# 불발소년
# 데이즈
# 위험한 신입사원
# 여름은 뜨겁다
# 죽여주는 탐정님
# 인싸라이프

# %%
url = "https://comic.naver.com/webtoon/list.nhn?titleId=703846&weekday=tue"
res= requests.get(url)

# %%
soup = BeautifulSoup(res.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>여신강림 :: 네이버 만화</title>
# <meta content="여신강림" property="og:title"/>
# <meta content="https://shared-comic.pstatic.net/thumb/webtoon/703846/thumbnail/thumbnail_IMAG19_225f310e-c16c-4ac3-b164-987d0cec46a7.jpg" property="og:image"/>
# <meta content="네웹 대표 글로벌 인기작! 주경, 수호, 서준. 세 청춘의 두근두근 눈호강 로맨스~♡메이크업으로 여신이 된 주경이는 꿈과 사랑을 이룰 수 있을까?" property="og:description"/>
# <meta content="https://comic.naver.com/webtoon/list.nhn?titleId=703846&amp;weekday=tue" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
# 		document.domain = "naver.com";
# 	</script>
# <link href="/css/comic/comic_20210105150622.css" rel="stylesheet" style="text/css"/>
# <!-- comicArticleListJsFile -->
# <script charset="utf-8" src="/aggregate/javascript/release/comic_article_list_20210105150622.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	// nclick
#
# 	//<![CDATA[
# 	var g_ssc = "decide.me";
# 	var levelName = "WEBTOON";
# 	if(levelName == "BEST_CHALLENGE"){
#         g_ssc = "comic.best_list";
# 	}else if(levelName == "CHALLENGE"){
#         g_ssc = "comic.chal_list";
# 	}else if(levelName == "WEBTOON"){
#         g_ssc = "comic.toon_list";
# 	}
#
# 	var ccsrv = "cc.naver.com";
# 	//]]>
# </script>
# <script type="text/javascript">
# 	var isLogin = false;
# 	var levelName = "webtoon";
#
# 	var artistData = [
#
#           {"artistId" : 316796,
#            "nickname": '야옹이'}
#
#     ];
#
#     var actionRunner;
#
#
#     WebtoonArtistActionRunner = $Class ({
#         $init : function(titleId) {
#             this._titleId = titleId;
# 	    },
#
# 	  	//관심 웹툰 추가
#         addFavoriteWebtoon : function (titleId) {
# 	    	var width = (screen.width / 2) - 800;
# 			var height = (screen.height / 2) - 510;
# 			var favoriteUrl = null;
# 			var addUrl = "https://" + location.hostname + "/mypage/favoriteTitleAdd.nhn?titleId="+titleId;
# 			var removeUrl = "https://" + location.hostname + "/mypage/favoriteTitleRemove.nhn?titleId="+titleId;
# 			if($Element(jindo.$$.getSingle('.book_maker')).hasClass('on')) {
# 				favoriteUrl = removeUrl;
# 			} else {
# 				favoriteUrl = addUrl;
# 			}
#
# 			if(isLogin) {
# 			    var favoritePopup = window.open('', 'addFavorite', 'directories=no,toolbar=no,scrollbars=yes,width=370,height=180,top=' + height + ',left=' + width);
# 			    favoritePopup.location.href = favoriteUrl;
# 			} else {
# 			    location.href = "/common/login.nhn?url=" + encodeURIComponent(location.href);
# 			}
# 	    },
#
# 	    artistForArtistTitle : function(element) {
# 			$Element("author_layer_inner").html("");
# 			$Element("author_layer").css("border", "");
# 			$Element("author_layer_inner").css("border", "1px solid #b6b6b6");
# 	    	if(artistData.length == 0) {
# 	    		var liElement = new $Element("<li>");
#                 var spanElement = new $Element("<span>");
#                 spanElement.html("작가의 다른 작품이 없습니다.");
#                 liElement.append(spanElement);
#                 $Element("author_layer_inner").append(liElement);
# 	        	artistLayer.show(element);
# 	    	} else if(artistData.length == 1) {
# 	    		location.href = "/artistTitle.nhn?artistId=" + artistData[0].artistId;
# 	    	} else {
# 					for (var i = 0; i < artistData.length; i++) {
# 						var liElement = new $Element("<li>");
# 						var aElement = new $Element("<a>");
# 						aElement.attr("href", "/artistTitle.nhn?artistId=" + artistData[i].artistId);
# 						aElement.html("&lt;" + artistData[i].nickname + "&gt;의 다른작품");
# 						liElement.append(aElement);
# 						$Element("author_layer_inner").append(liElement);
# 						if (i==9) {
# 							$Element("author_layer").css("border", "1px solid #b6b6b6");
# 							$Element("author_layer_inner").css("border", "0");
# 						}
# 	              }
# 	        artistLayer.show(element);
# 	    	}
# 	    	return false;
# 	    }
# 	});
#
# 	var bRolling = false;
# 	var oAdBannerFlicking = null;
# 	var adBannerInterval = null;
#
# 	function loadThisWindow () {
# 	    actionRunner = new WebtoonArtistActionRunner("703846");
#
# 		(function(oData) {
# 			window.__oLikeItData = oData;
# 			var s = document.createElement("script");
# 			s.type = "text/javascript";
# 			s.charset = "utf-8";
# 			s.src = oData.domain + "/static/js/likeIt.v2.desktop.init.js?v="+ (new Date()).toDateString().replace(/\s/g,"");
# 			(document.head || document.getElementsByTagName("head")[0]).appendChild(s);
# 		})({
# 			serviceId : "COMIC"
# 			, displayId : "COMIC"
# 			, contentId : "703846"
# 			, domain :"https://comic.like.naver.com"
# 			, lang : "ko"
# 			, viewType : ""
#
# 			, countCallbackYn : "Y"
# 			, rparam : encodeURIComponent("deviceCode=PC")
#
# 		 });
#
# 		if(levelName == "bestChallenge") {
# 			function potenupArea() {
# 				if ($Element("potenupAreaBtn").className() == "btn_potenup") {
# 					$Element("potenupAreaBtn").className($Element("potenupAreaBtn").className() + " on");
# 				} else {
# 					$Element("potenupAreaBtn").className("btn_potenup");
# 				}
#
# 			}
#
# 			$Fn(potenupArea).attach($Element("potenupAreaBtn"), "click");
#
# 			$Fn(potenupArea).attach($Element("potenupAreaCloseBtn"), "click");
# 		}
#
#
# 		if (jQuery("#mflick1")) {
#
# 			var $j = jQuery.noConflict();
#
# 			if ($j("#mflick1").length > 0) {
#
# 				oAdBannerFlicking = new eg.Flicking(jQuery("#mflick1"), {
# 					duration: 300,
# 					circular: true,
# 					defaultIndex: 0
# 				});
# 				jQuery("._adBanner").show();
# 				rollingAdBanner();
#
#
# 				jQuery(window).scroll(function () {
# 					var nExposureControlPosition = jQuery('#mflick1').offset().top + jQuery('#mflick1').height();
# 					if (window.scrollY > nExposureControlPosition) {
# 						window.clearInterval(adBannerInterval);
# 						bRolling = false;
# 					} else {
# 						if (!bRolling) {
# 							rollingAdBanner();
# 						}
# 					}
# 				});
# 			}
# 		}
# 	}
#
# 	function rollingAdBanner() {
# 		if (!bRolling) {
# 			adBannerInterval = setInterval(function () {
# 				var statViewUrl = oAdBannerFlicking.getNextElement().data('url');
# 				callWebAdBannerView(statViewUrl);
# 				oAdBannerFlicking.next();
# 			}, 2000);
# 			bRolling = true;
# 		}
# 	}
#
# 	function callWebAdBannerView(sStatsUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		jQuery.ajax({
# 			type: 'GET',
# 			url: sStatsUrl + '&_dummy='+nTimestamp,
# 			async: false,
# 			timeout : self._nAjaxCallTimeout
# 		});
# 	}
#
# 	function callWebAdBannerClick(sStatsUrl, sTargetUrl) {
# 		var self = this;
# 		var nTimestamp = new Date().getTime();
#
# 		jQuery.ajax({
# 			type: 'GET',
# 			url: sStatsUrl + '&_dummy='+nTimestamp,
# 			async: false,
# 			timeout : self._nAjaxCallTimeout,
# 			complete : function() {
# 				window.open(sTargetUrl, '_blank');
# 			}
# 		});
# 	}
#
# 	$Fn(loadThisWindow).attach(window,"load");
#
#     /**
#      * 시리즈로 이동 가능한지 확인해서 이동
#      *
#      * @params nbooksId {String} 북스 상품 ID
#      */
# 	function moveBookstore(nbooksId) {
#         var result;
#
#         $Ajax('https://series.naver.com/isService.jsonp', {
#             type : 'jsonp',
#             method : 'get',
#             callbackname: 'callback',
#             onload : function(oRes) {
#                 result = oRes.json().result;
#             }
#         }).request({
#             'productTypeCode' : 'COMIC',
#             'originalProductId' : nbooksId
#         });
#
#
# 		var oInterval = setInterval(function() {
#             if (result == 'true') {
#                 window.open('https://series.naver.com/comic/detail.nhn?originalProductId=' + nbooksId, '_blank');
#             } else {
#                 alert('시리즈에 상품을 등록 중입니다. 잠시만 기다려주세요.');
#             }
#             clearInterval(oInterval);
#             oInterval = null;
# 		}, 200);
# 	}
# </script>
# <script src="/aggregate/javascript/release/comic_gnb_20210105150622.js" type="text/javascript"></script>
# </head>
# <body onload="">
# <div class="end_page" id="wrap">
# <div id="u_skip">
# <a href="#menu" onclick="document.getElementById('menu').tabIndex=-1;document.getElementById('menu').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header_wrap">
# <div id="header">
# <div id="gnb">
# <script type="text/javascript">
#         var gnb_option = {
#             gnb_service : "comic",
#             gnb_logout :  encodeURIComponent(window.location.href),
#             gnb_login :   encodeURIComponent(window.location.href),
#             gnb_template : "gnb_utf8",
#             gnb_brightness : 1,
#             gnb_item_hide_option: 0
#         };
#     </script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20210105150622" type="text/javascript"></script>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="Ntxt_naver" href="https://www.naver.com" onclick="nclk_v2(event,'STA.naverlogo')" title="NAVER">NAVER</a>
# <a class="Ntxt_comic" href="/index.nhn" onclick="nclk_v2(event,'STA.comic')" title="만화">만화</a>
# <em class="bar">|</em>
# <a class="Ntxt_novel" href="https://novel.naver.com" onclick="nclk_v2(event,'STA.novel')" title="웹소설">웹소설</a>
# </h1>
# <form action="/search.nhn" id="searchForm" method="get" name="search">
# <fieldset>
# <legend>검색</legend>
# <div class="snb_search_box">
# <div class="snb_search_box_sub">
# <!-- [D] 클릭시 label.ph 텍스트 삭제해주세요. -->
# <label class="ph" for="gnb.keyword">제목/작가로 검색할 수 있습니다.</label>
# <input class="snb_search_text" id="gnb.keyword" maxlength="18" name="keyword" title="검색어 입력" type="text" value=""/>
# <button alt="검색" class="btn_search" id="search_bar_button" onclick="nclk_v2(event,'STA.search')" title="검색" type="button"><span class="Nico_search">검색</span></button>
# </div>
# </div>
# </fieldset>
# </form>
# </div>
# <div id="author_layer" style="text-align:left; display:none;">
# <ul id="author_layer_inner"> </ul>
# </div>
# <div class="notice_info">
# <span class="blind">공지사항</span>
# <div class="rolling">
# <div class="notice_rolling">
# <li>
# <a href="https://comic.naver.com/webtoon/list.nhn?titleId=756140" onclick="nclk_v2(event,'STA.txt')" title="정통판타지액션 &lt;라서드&gt;">
# <span class="Nico_notice"></span>
# 										정통판타지액션 &lt;라서드&gt;
# 									</a>
# </li>
# </div>
# </div>
# </div>
# </div>
# <div id="menu">
# <ul class="menu">
# <!-- [D] 선택된 li에 current 클래스 추가 -->
# <li><a href="/index.nhn" onclick="nclk_v2(event,'LNB.home');"><span class="Ntxt_home">웹툰 홈</span></a></li>
# <li class="current"><a href="/webtoon/weekday.nhn" onclick="nclk_v2(event,'LNB.toon');"><span class="Ntxt_webtoon">웹툰</span></a></li>
# <li><a href="/genre/bestChallenge.nhn" onclick="nclk_v2(event,'LNB.best');"><span class="Ntxt_best_challenge">베스트 도전</span></a></li>
# <li><a href="/genre/challenge.nhn" onclick="nclk_v2(event,'LNB.chal');"><span class="Ntxt_challenge_comic">도전만화</span></a></li>
# <li><a href="/mypage/favorite.nhn" onclick="nclk_v2(event,'LNB.my');"><span class="Ntxt_mypage">마이페이지</span></a><span class="bar"></span></li>
# <li><a href="https://series.naver.com/comic/recommendList.nhn" onclick="nclk_v2(event,'LNB.char');" target="_blank"><span class="Ntxt_short_story">단행본 만화</span></a></li>
# <li class="genre_novel"><a href="https://series.naver.com/novel/recommendList.nhn" onclick="nclk_v2(event,'LNB.novel');" target="_blank"><span class="Ntxt_genre_novel">장르소설</span></a></li>
# </ul>
# <h2 class="blind">웹툰</h2>
# </div>
# <!-- //상단 메뉴 /webtoon/list.nhn-->
# <div id="submenu">
# <!--서브메뉴-->
# <ul class="submenu">
# <!-- [D] 선택된 li에 on 클래스 추가 -->
# <li class="on"><a href="/webtoon/weekday.nhn" onclick="nclk_v2(event,'tab.weekday')"><span class="Ntxt_menu_date">요일별</span></a></li>
# <li><a href="/webtoon/genre.nhn" onclick="nclk_v2(event,'tab.genre')"><span class="Ntxt_menu_genre">장르별</span></a></li>
# <li><a href="/webtoon/creation.nhn" onclick="nclk_v2(event,'tab.creation')"><span class="Ntxt_menu_art">작품별</span></a></li>
# <li><a href="/webtoon/artist.nhn" onclick="nclk_v2(event,'tab.artist')"><span class="Ntxt_menu_author">작가별</span></a></li>
# <li><a href="/webtoon/period.nhn" onclick="nclk_v2(event,'tab.period')"><span class="Ntxt_menu_year">연도별</span></a></li>
# <li><a href="/webtoon/theme.nhn" onclick="nclk_v2(event,'tab.theme')"><span class="Ntxt_menu_theme">테마웹툰</span></a></li>
# <li><a href="/webtoon/finish.nhn" onclick="nclk_v2(event,'tab.finish')"><span class="Ntxt_menu_end">완결웹툰</span></a></li>
# </ul>
# <!--//서브메뉴-->
# </div>
# </div>
# <!-- 상단 영역(메인에만 나감.) -->
# <!-- //상단 영역 -->
# <div class="" id="container">
# <div class="webtoon" id="content">
# <ul class="category_tab">
# <li class=""><a href="/webtoon/weekday.nhn" onclick="nclk_v2(event,'dna.all')">요일전체</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=mon" onclick="nclk_v2(event,'dna.monday')">월요웹툰</a></li>
# <li class="on"><a href="/webtoon/weekdayList.nhn?week=tue" onclick="nclk_v2(event,'dna.tuesday')">화요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=wed" onclick="nclk_v2(event,'dna.wednesday')">수요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=thu" onclick="nclk_v2(event,'dna.thursday')">목요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=fri" onclick="nclk_v2(event,'dna.friday')">금요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=sat" onclick="nclk_v2(event,'dna.saturday')">토요웹툰</a></li>
# <li class=""><a href="/webtoon/weekdayList.nhn?week=sun" onclick="nclk_v2(event,'dna.sunday')">일요웹툰</a></li>
# </ul>
# <!-- body -->
# <!-- 상세 정보영역 -->
# <div class="comicinfo" style="">
# <div class="thumb">
# <a href="/webtoon/list.nhn?titleId=703846" onclick="nclk_v2(event,'inf.img')">
# <img alt="여신강림" height="101" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non125_101.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/thumbnail/thumbnail_IMAG06_aa715a18-fe51-4adf-b21b-5fc253ed3f32.jpg" title="여신강림" width="125"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="detail">
# <h2>
# 			        여신강림<span class="wrt_nm">
# 							야옹이</span>
# </h2>
# <p>네웹 대표 글로벌 인기작! 주경, 수호, 서준. 세 청춘의 두근두근 눈호강 로맨스~♡<br/>메이크업으로 여신이 된 주경이는 꿈과 사랑을 이룰 수 있을까?</p>
# <p class="detail_info"><span class="genre">스토리, 로맨스</span><span class="age">12세 이용가</span></p>
# <ul class="btn_group">
# <li><a class="book_maker" href="#" onclick="nclk_v2(event,'inf.zzim');return actionRunner.addFavoriteWebtoon('703846');" title="관심웹툰"><span>관심웹툰</span></a></li>
# <li><a class="first" href="#" onclick="nclk_v2(event,'inf.first');return checkServiceCode('S00','1')" title="첫회보기"><span>첫회보기</span></a></li>
# <li><a class="other" href="#" id="other_content" onclick="nclk_v2(event,'inf.artist');return actionRunner.artistForArtistTitle(this)" title="작가의 다른 작품"><span>작가의 다른 작품</span></a></li>
# <!-- [D] pre_view 클래스에 완결인 경우 end 클래스 추가 및 span에 설명 변경-->
# <li>
# </li>
# <li>
# <div class="u_likeit_module">
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- //상세 정보영역 -->
# <!-- 리스트 -->
# <table cellpadding="0" cellspacing="0" class="viewList">
# <caption><span class="blind">회차별 목록</span></caption>
# <col width="99"/><col width="*"/><col width="141"/><col width="76"/>
# <thead>
# <tr>
# <th scope="col">이미지</th>
# <th scope="col">제목</th>
# <th scope="col">별점</th>
# <th scope="col">등록일</th>
# </tr>
# </thead>
# <tr class="band_banner v2">
# <td colspan="4">
# <a href="https://series.naver.com/comic/detail.nhn?originalProductId=309445" onclick="nclk_v2(event,'lst.gostore','703846');" target="_blank">
# <em class="ico_store2">NAVER 만화</em>다음 화를 미리 만나보세요.</a>
# </td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=143&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','143')">
# <img alt="138화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/143/thumbnail_202x120_7f77a5ba-fd66-4144-8838-d97f339adad4.jpg" title="138화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=143&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','143')">138화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:93.85%">평점</em></span>
# <strong>9.38</strong>
# </div>
# </td>
# <td class="num">2021.01.04</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=142&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','142')">
# <img alt="137화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/142/thumbnail_202x120_aac6e90a-a701-4e33-837c-00eb9c8b1c85.jpg" title="137화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=142&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','142')">137화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:88.01%">평점</em></span>
# <strong>8.80</strong>
# </div>
# </td>
# <td class="num">2020.12.28</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=141&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','141')">
# <img alt="136화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/141/thumbnail_202x120_864be28b-ed05-48da-85fa-261f1d0da202.jpg" title="136화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=141&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','141')">136화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:86.72%">평점</em></span>
# <strong>8.67</strong>
# </div>
# </td>
# <td class="num">2020.12.21</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=140&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','140')">
# <img alt="135화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/140/thumbnail_202x120_926d9143-42b9-40b6-a13b-dd7a2ad3a2c7.jpg" title="135화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=140&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','140')">135화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:92.38%">평점</em></span>
# <strong>9.24</strong>
# </div>
# </td>
# <td class="num">2020.12.14</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=139&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','139')">
# <img alt="134화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/139/thumbnail_202x120_a683b9de-b717-4cf1-855e-3431b33405ff.jpg" title="134화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=139&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','139')">134화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:88.84%">평점</em></span>
# <strong>8.88</strong>
# </div>
# </td>
# <td class="num">2020.12.07</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=138&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','138')">
# <img alt="133화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/138/thumbnail_202x120_a3a84986-58f7-4abc-84a2-f8255a101f02.jpg" title="133화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=138&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','138')">133화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:84.67%">평점</em></span>
# <strong>8.47</strong>
# </div>
# </td>
# <td class="num">2020.11.30</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=137&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','137')">
# <img alt="132화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/137/thumbnail_202x120_5fcd9456-c368-4d00-8e5a-e2540276ceba.jpg" title="132화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=137&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','137')">132화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:79.69%">평점</em></span>
# <strong>7.97</strong>
# </div>
# </td>
# <td class="num">2020.11.23</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=136&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','136')">
# <img alt="131화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/136/thumbnail_202x120_f4eb81f4-9f0c-4da2-a4c8-12033c247f01.jpg" title="131화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=136&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','136')">131화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:83.61%">평점</em></span>
# <strong>8.36</strong>
# </div>
# </td>
# <td class="num">2020.11.09</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=135&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','135')">
# <img alt="130화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/135/thumbnail_202x120_2618008e-71c0-4c1a-8a71-d656c6a50a31.jpg" title="130화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=135&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','135')">130화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:89.37%">평점</em></span>
# <strong>8.94</strong>
# </div>
# </td>
# <td class="num">2020.11.02</td>
# </tr>
# <tr>
# <td>
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=134&amp;weekday=tue" onclick="nclk_v2(event,'lst.img','703846','134')">
# <img alt="129화" height="41" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non71_41.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/703846/134/thumbnail_202x120_83183c7e-312a-4421-b12b-5026f05677e5.jpg" title="129화" width="71"/>
# <span class="mask"></span>
# </a>
# </td>
# <td class="title">
# <a href="/webtoon/detail.nhn?titleId=703846&amp;no=134&amp;weekday=tue" onclick="nclk_v2(event,'lst.title','703846','134')">129화</a>
# </td>
# <td>
# <div class="rating_type">
# <span class="star"><em style="width:88.82%">평점</em></span>
# <strong>8.88</strong>
# </div>
# </td>
# <td class="num">2020.10.26</td>
# </tr>
# </table>
# <!-- //리스트 -->
# <div class="paginate">
# <div class="page_wrap">
# <strong class="blind">페이지 이동하기</strong>
# <strong class="page"><em class="num_page">1</em><span class="blind"> 현재 페이지</span></strong>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=2"><em class="num_page">2</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=3"><em class="num_page">3</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=4"><em class="num_page">4</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=5"><em class="num_page">5</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=6"><em class="num_page">6</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=7"><em class="num_page">7</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=8"><em class="num_page">8</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=9"><em class="num_page">9</em></a>
# <a class="page" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=10"><em class="num_page">10</em></a>
# <a class="next" href="/webtoon/list.nhn?titleId=703846&amp;weekday=tue&amp;page=2" title="다음 페이지 목록으로 이동"><span class="cnt_page">다음</span><span class="blind"> 페이지 목록으로 이동</span><span class="ico_page"></span></a>
# </div>
# </div>
# <script type="text/javascript">
# 		function checkServiceCode(serviceCode, no){
# 			var hrefUrl = "/webtoon/detail.nhn?titleId=703846&no="+no+"&weekday=tue";
#
# 			if("S00" == serviceCode) {
# 			    location.href = hrefUrl;
# 			} else {
# 			    this.alert("게시 보류 중인 콘텐츠 입니다.");
# 			}
# 			return false;
# 		}
# 	</script>
# </div>
# <!-- side menu -->
# <div id="aside">
# <div class="asideButton upload">
# <a class="Nbtn_upload" href="/mypage/myActivity.nhn" onclick="nclk_v2(event,'olk.upload');">웹툰 올리기</a>
# </div>
# <!-- 배너 -->
# <div class="asideAd" data-veta-preview="p_wtoon_end" id="addiv" name="addiv">
# <iframe align="center" border="0" frameborder="0" height="240" id="f240240" marginheight="0" marginwidth="0" name="f240240" scrolling="no" src="https://veta.naver.com/fxshow?su=SU10321" title="광고영역" width="240"></iframe>
# </div>
# <!-- //배너 -->
# <!-- 롤링이미지 -->
# <div class="asideRolling">
# <a href="https://comic.naver.com/webtoon/list.nhn?titleId=762279" onclick="nclk_v2(event,'olk.banner')">
# <img alt="&lt;정글쥬스&gt; 곤충인간이 되어버렸다" height="97" src="https://naverwebtoon-phinf.pstatic.net/20210104_248/1609739430942tFFXn_JPEG/upload_3418542914276039751.JPEG?type=p100" width="240"/>
# </a>
# </div>
# <!-- 인기급상승만화 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle"><img alt="인기급상승만화" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_best.gif" title="인기급상승만화" width="78"/></h4>
# <div>
# <ul class="asideBoxTab"><!-- 선택된 메뉴에는 choice라는 클래스명을 사용합니다 -->
# <li class="choice" id="realTimeRankChoiceTabFavorite"><a href="#" id="realTimeRankChoiceTabFavoriteClick" onclick="nclk_v2(event,'rnk.rep')"><img alt="인기순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_favor.gif" title="인기순" width="31"/></a></li>
# <li id="realTimeRankChoiceTabUpdate"><a href="#" id="realTimeRankChoiceTabUpdateClick" onclick="nclk_v2(event,'rnk.upd')"><img alt="업데이트순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_update.gif" title="업데이트순" width="52"/></a></li>
# </ul>
# <h3 class="blind" id="realTimeRankBlindName">인기순</h3>
# <ol class="asideBoxRank" id="realTimeRankFavorite">
# <li class="rank01">
# <a href="/webtoon/detail.nhn?titleId=747269&amp;no=34" onclick="nclk_v2(event,'rnk*p.cont','747269','1')" title="전지적 독자 시점-033. Ep.08 긴급 방어전 (1)">전지적 독자 시점-033. Ep.08 긴급 방어전 (1)</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail.nhn?titleId=662774&amp;no=219" onclick="nclk_v2(event,'rnk*p.cont','662774','2')" title="고수-2부 129화">고수-2부 129화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail.nhn?titleId=738143&amp;no=56" onclick="nclk_v2(event,'rnk*p.cont','738143','3')" title="여주실격!-56화 천리사를 이기는 법 (2)">여주실격!-56화 천리사를 이기는 법 (2)</a>
# <span class="rankBox">
# <img alt="순위상승" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승" width="7"/>1
#
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail.nhn?titleId=626907&amp;no=327" onclick="nclk_v2(event,'rnk*p.cont','626907','4')" title="복학왕-325화 청약 대회 5화">복학왕-325화 청약 대회 5화</a>
# <span class="rankBox">
# <img alt="순위하락" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락" width="7"/>1
#
#
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail.nhn?titleId=760001&amp;no=8" onclick="nclk_v2(event,'rnk*p.cont','760001','5')" title="하렘의 남자들-7화">하렘의 남자들-7화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail.nhn?titleId=733079&amp;no=63" onclick="nclk_v2(event,'rnk*p.cont','733079','6')" title="원수를 사랑하라-63화">원수를 사랑하라-63화</a>
# <span class="rankBox">
# <img alt="순위상승" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승" width="7"/>1
#
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail.nhn?titleId=749639&amp;no=27" onclick="nclk_v2(event,'rnk*p.cont','749639','7')" title="남주의 첫날밤을 가져버렸다-27화">남주의 첫날밤을 가져버렸다-27화</a>
# <span class="rankBox">
# <img alt="순위하락" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락" width="7"/>1
#
#
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail.nhn?titleId=738694&amp;no=37" onclick="nclk_v2(event,'rnk*p.cont','738694','8')" title="튜토리얼 탑의 고인물-37화">튜토리얼 탑의 고인물-37화</a>
# <span class="rankBox">
# <img alt="순위상승" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승" width="7"/>1
#
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail.nhn?titleId=667573&amp;no=256" onclick="nclk_v2(event,'rnk*p.cont','667573','9')" title="연놈-256화. 눈을 뜨고도 보지 못하는 건">연놈-256화. 눈을 뜨고도 보지 못하는 건</a>
# <span class="rankBox">
# <img alt="순위하락" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락" width="7"/>1
#
#
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail.nhn?titleId=710747&amp;no=108" onclick="nclk_v2(event,'rnk*p.cont','710747','10')" title="세상은 돈과 권력-시즌2 1화">세상은 돈과 권력-시즌2 1화</a>
# <span class="rankBox">
# <img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0
#
#
# 				</span>
# </li>
# </ol>
# <ol class="asideBoxRank" id="realTimeRankUpdate" style="display:none;">
# <li class="rank01">
# <a href="/webtoon/detail.nhn?titleId=701535&amp;no=169" onclick="nclk_v2(event,'rnk*u.cont','701535','1')" title="격기3반-ROUND 87. 파이트클럽 (2)">
#
# 					격기3반-ROUND 87. 파이트클럽 (2)
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank02">
# <a href="/webtoon/detail.nhn?titleId=736699&amp;no=60" onclick="nclk_v2(event,'rnk*u.cont','736699','2')" title="저승사자 출입금지-60화. 이해 (1)">
#
# 					저승사자 출입금지-60화. 이해 (1)
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank03">
# <a href="/webtoon/detail.nhn?titleId=710747&amp;no=108" onclick="nclk_v2(event,'rnk*u.cont','710747','3')" title="세상은 돈과 권력-시즌2 1화">
#
# 					세상은 돈과 권력-시즌2 1화
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank04">
# <a href="/webtoon/detail.nhn?titleId=736281&amp;no=54" onclick="nclk_v2(event,'rnk*u.cont','736281','4')" title="럭키언럭키-시즌2 2화. 믿을 놈 하나 없다">
#
# 					럭키언럭키-시즌2 2화. 믿을 놈 하나 없다
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank05">
# <a href="/webtoon/detail.nhn?titleId=728015&amp;no=176" onclick="nclk_v2(event,'rnk*u.cont','728015','5')" title="모죠의 일지-176화. 2020 연말 어워드">
#
# 					모죠의 일지-176화. 2020 연말 어워드
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank06">
# <a href="/webtoon/detail.nhn?titleId=761596&amp;no=3" onclick="nclk_v2(event,'rnk*u.cont','761596','6')" title="말하는대로-3화">
#
# 					말하는대로-3화
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank07">
# <a href="/webtoon/detail.nhn?titleId=662774&amp;no=219" onclick="nclk_v2(event,'rnk*u.cont','662774','7')" title="고수-2부 129화">
#
# 					고수-2부 129화
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank08">
# <a href="/webtoon/detail.nhn?titleId=725829&amp;no=88" onclick="nclk_v2(event,'rnk*u.cont','725829','8')" title="아도나이-87화">
#
# 					아도나이-87화
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank09">
# <a href="/webtoon/detail.nhn?titleId=718020&amp;no=117" onclick="nclk_v2(event,'rnk*u.cont','718020','9')" title="귀곡의 문-117화 현실">
#
# 					귀곡의 문-117화 현실
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# <li class="rank10">
# <a href="/webtoon/detail.nhn?titleId=743026&amp;no=38" onclick="nclk_v2(event,'rnk*u.cont','743026','10')" title="비스타-38화 죄의 고통">
#
# 					비스타-38화 죄의 고통
# 				</a>
# <span class="timeBox">
#
#
#
# 							11시간전
#
#
#
#
#
# 				</span>
# </li>
# </ol>
# </div>
# </div>
# <!-- //인기급상승만화 -->
# <!-- 추천 웹툰 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle"><img alt="30대 인기만화" height="11" id="recommand_ageImg" src="https://ssl.pstatic.net/static/comic/images/migration/common/h_30.gif" width="107"/>
# <div class="tab_nv">
# <a class="Nico_prv" href="#" id="recommandWebtoonRankLeftTabClick">이전</a><a class="Nico_nxt" href="#" id="recommandWebtoonRankRightTabClick">다음</a>
# </div>
# </h4>
# <div>
# <ul class="asideBoxTab">
# <li class="choice" id="recommandWebtoonRankMTabOver"><a href="#" onclick="return false;"> <img alt="남자" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_m.png" title="남자" width="21"/></a></li>
# <li id="recommandWebtoonRankWTabOver"><a href="#" onclick="return false;"> <img alt="여자" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_w.png" title="여자" width="21"/></a></li>
# </ul>
# <h3 class="blind" id="ageGenderRankBlindName">남자</h3>
# <ol class="asideBoxRank asideBoxRank2" id="recommandWebtoonRank">
# <li class="rank01" id="recommandLi_0">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=747269&amp;no=34" id="recommand_link_0" title="전지적 독자 시점">
# <img alt="전지적 독자 시점" height="33" id="recommand_thumbnail_0" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/747269/thumbnail/thumbnail_IMAG10_55801c29-223f-46a0-a446-2e55d3024e71.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=747269&amp;no=34" id="recommand_titleName_0" title="전지적 독자 시점">전지적 독자 시점</a>
# <em><a href="#" id="recommand_painter_0" onclick="return artistAction.viewArtist('747269', this);" title="UMI / 슬리피-C">UMI / 슬리피-C</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_0" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_0">0</em>
# </span>
# </div>
# </li>
# <li class="rank02" id="recommandLi_1">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=626907&amp;no=327" id="recommand_link_1" title="복학왕">
# <img alt="복학왕" height="33" id="recommand_thumbnail_1" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/626907/thumbnail/title_thumbnail_20150407141027_t83x90.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=626907&amp;no=327" id="recommand_titleName_1" title="복학왕">복학왕</a>
# <em><a href="#" id="recommand_painter_1" onclick="return artistAction.viewArtist('626907', this);" title="기안84">기안84</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_1" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_1">0</em>
# </span>
# </div>
# </li>
# <li class="rank03" id="recommandLi_2">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=738694&amp;no=37" id="recommand_link_2" title="튜토리얼 탑의 고인물">
# <img alt="튜토리얼 탑의 고인물" height="33" id="recommand_thumbnail_2" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/738694/thumbnail/thumbnail_IMAG10_728d40b3-1224-4e00-b7a8-d16d9adbe137.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=738694&amp;no=37" id="recommand_titleName_2" title="튜토리얼 탑의 고인물">튜토리얼 탑의 고인물</a>
# <em><a href="#" id="recommand_painter_2" onclick="return artistAction.viewArtist('738694', this);" title="방구석김씨 / 오마감">방구석김씨 / 오마감</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_2" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_2">0</em>
# </span>
# </div>
# </li>
# <li class="rank04" id="recommandLi_3">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=710747&amp;no=108" id="recommand_link_3" title="세상은 돈과 권력">
# <img alt="세상은 돈과 권력" height="33" id="recommand_thumbnail_3" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/710747/thumbnail/thumbnail_IMAG10_62a436dc-7b3e-405a-b143-a7ecf2cd0485.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=710747&amp;no=108" id="recommand_titleName_3" title="세상은 돈과 권력">세상은 돈과 권력</a>
# <em><a href="#" id="recommand_painter_3" onclick="return artistAction.viewArtist('710747', this);" title="한동우 / 이도희">한동우 / 이도희</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_3" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_3">0</em>
# </span>
# </div>
# </li>
# <li class="rank05" id="recommandLi_4">
# <div class="thumb6">
# <a href="/webtoon/detail.nhn?titleId=750184&amp;no=23" id="recommand_link_4" title="나쁜사람">
# <img alt="나쁜사람" height="33" id="recommand_thumbnail_4" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/750184/thumbnail/thumbnail_IMAG10_113cf716-dc7d-4f97-b6a9-a904b55c0ff4.jpg" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# <div class="rc_info">
# <a class="tit" href="/webtoon/detail.nhn?titleId=750184&amp;no=23" id="recommand_titleName_4" title="나쁜사람">나쁜사람</a>
# <em><a href="#" id="recommand_painter_4" onclick="return artistAction.viewArtist('750184', this);" title="둠스">둠스</a></em>
# <span class="rankBox2">
# <img alt="변동없음" id="recommand_img_4" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음"/><em id="recommand_rank_4">0</em>
# </span>
# </div>
# </li>
# </ol>
# </div>
# </div>
# <script>
# new naver.comic.RecommandWebtoonRankLayer(0, "https://shared-comic.pstatic.net/thumb");
# </script>
# <!-- //추천 웹툰 -->
# <!-- 공지사항 -->
# <div class="asideBox">
# <h4 class="asideBoxTitle">
# <img alt="공지사항" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_notice.gif" title="공지사항" width="43"/>
# </h4>
# <ul class="asideBoxNotice">
# <li>
# <a href="/notice/detail.nhn?noticeId=417" onclick="nclk_v2(event,'sna.not','417','1')" title="2020 지상최대공모전 웹툰부문 2기 수상작 발표">
# <strong>
# 					2020 지상최대공모전 웹툰부문 2기 수상작 발표
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=421" onclick="nclk_v2(event,'sna.not','421','2')" title="네이버웹툰 미리보기/완결보기 컨텐츠별 이용가 관련 안내">
# <strong>
# 					네이버웹툰 미리보기/완결보기 컨텐츠별 이용가 관련 안내
# 				</strong>
# </a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=352" onclick="nclk_v2(event,'sna.not','352','3')" title="[안내] 요일별 웹툰의 인기순 정렬 방식이 추가되었습니다.">
#
# 					[안내] 요일별 웹툰의 인기순 정렬 방식 추가
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=422" onclick="nclk_v2(event,'sna.not','422','4')" title="2020년 12월 유료화 전환 작품 안내">
#
# 					2020년 12월 유료화 전환 작품 안내
#
# 			</a>
# </li>
# <li>
# <a href="/notice/detail.nhn?noticeId=427" onclick="nclk_v2(event,'sna.not','427','5')" title="2020년 12월 베스트 도전만화 승격작 발표">
#
# 					2020년 12월 베스트 도전만화 승격작 발표
#
# 			</a>
# </li>
# </ul>
# <a class="asideBoxMore" href="/notice/list.nhn" onclick="nclk_v2(event,'sna.more')">
# <span class="blind">공지사항</span> 더보기
# 	</a>
# </div>
# <!-- //공지사항 -->
# <div class="asideBanner">
# <a href="/business/proposalGuide.nhn" onclick="nclk_v2(event,'sna.proposal');">
# <img alt="웹툰, 웹소설 온라인 광고 판권 사업" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_partnership.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://joinus.comic.naver.com" onclick="nclk_v2(event,'sna.writerproposal');">
# <img alt="연재 경력 작가 웹툰 차기작 제안" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_joinus.jpg" width="240"/>
# </a>
# </div>
# <div class="asideBanner">
# <a href="https://recruit.webtoonscorp.com" onclick="nclk_v2(event,'sna.recruit');">
# <img alt="웹툰 채용공고 CAREERS" height="86" src="https://ssl.pstatic.net/static/comic/images/bnr_careers.jpg" width="240"/>
# </a>
# </div>
# <div class="asideButton">
# <a class="btn_faq" href="https://help.naver.com/support/service/main.nhn?serviceNo=799" onclick="nclk_v2(event,'sna.faq')" target="_blank" title="새 창">
# <span class="blind">만화FAQ</span>
# </a>
# </div>
# </div>
# </div>
# <!-- Footer -->
# <!-- FOOTER Start -->
# <div id="footer">
# <div class="naver_corp_info">
# <ul>
# <li><a href="https://www.naver.com/rules/service.html" onclick="nclk_v2(event,'fot.agreement')" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://www.naver.com/rules/privacy.html" onclick="nclk_v2(event,'fot.privacy')" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://www.naver.com/rules/disclaimer.html" onclick="nclk_v2(event,'fot.disclaimer')" target="_blank">책임의 한계와 법적고지</a></li>
# <li><a href="https://help.naver.com/support/home.nhn?serviceNo=799" onclick="nclk_v2(event,'fot.helpdesk')" target="_blank" title="새 창">고객센터</a></li>
# <li><a href="/business/proposalGuide.nhn#ad" onclick="nclk_v2(event,'fot.proposal')" target="_blank">웹툰 광고 문의</a></li>
# </ul>
# <address><a href="https://www.navercorp.com/" onclick="nclk_v2(event,'fot.navercorp')" target="_blank"><span class="naver_corp_link"><span class="blind">ⓒ NAVER CORP.</span></span></a></address>
# </div>
# <div class="webtoon_corp_info">
# <ul>
# <li><a href="https://member.webtoon.naver.com/policies/terms/" target="_blank">이용약관</a></li>
# <li><a class="privacy" href="https://member.webtoon.naver.com/policies/privacy/" target="_blank">개인정보처리방침</a></li>
# <li><a href="https://member.webtoon.naver.com/policies/youthpolicy/" target="_blank">청소년보호정책</a></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=799" target="_blank">웹툰 고객센터</a></li>
# <li><a href="/business/proposalGuide.nhn" target="_blank">웹툰 사업 문의</a></li>
# </ul>
# <address><a class="webtoon_corp_link" href="https://webtoonscorp.com" onclick="nclk_v2(event,'fot.wtcorp');" target="_blank"><span class="blind">ⓒ NAVER WEBTOON Limited</span></a></address>
# </div>
# <p class="copyright_law">본 콘텐츠의 저작권은 저자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //FOOTER End -->
# </div>
# <script type="text/javascript">
# 			var agent = navigator.userAgent.toLowerCase();
#
# 			function loadEvent(){
# 				try{
# 					getGNB();
# 				}catch(ex){
#
# 				}
# 				new naver.comic.RealtimeRankLayer();
# 				if ( $("uploadLinkId") ){
# 					$Fn(function(oEvent) {
# 						oEvent.stop();
# 						if ("true" != "false") {
# 							if (!confirm('로그인해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 								return false;
# 							else {
# 								location.href = "https://nid.naver.com/nidlogin.login?mode=form&url="
# 										+ encodeURIComponent("https://" + location.host
# 												+ "/upload/upload.nhn");
# 								return;
# 							}
# 						}
# 						location.href = "/upload/upload.nhn";
# 						return true;
# 					}).attach($("uploadLinkId"),"click");
# 				}
# 				naver.comic.oArtistAction = new naver.comic.Artist();
# 				artistAction = naver.comic.oArtistAction;
# 				naver.comic.oSearchBar = new naver.comic.SearchBarOptionActHandler();
#
# 				// GNB 이벤트 재정의.
# 				$Fn(function(oEvent){
# 					var aWtChild = $Element("gnb" ).child(function (v){return true;});
# 					var wtSrc = $Element(oEvent.element);
# 					var bContain = false;
# 					for (var i = 0 ; i < aWtChild.length ;i++){
# 						if ( aWtChild[i].$value() == wtSrc.$value()){
# 							bContain = true;
# 							break;
# 						}
# 					}
# 					if ( !bContain && gnbAllLayerClose ){
# 						gnbAllLayerClose();
#
# 					}
#
# 				}).attach(document,"click");
# 			}
# 			$Fn(loadEvent).attach(window,'load');
# 		</script>
# <script src="/aggregate/javascript/release/lcslog_20210105150622.js" type="text/javascript"></script>
# <script type="text/javascript">
#     try {
#         var eventType = "onpageshow" in window ? "onpageshow" : "onload";
#         var oldEvent = window[eventType];
#         window[eventType] = function() {
#             if (oldEvent) {
#                 oldEvent();
#             }
#             lcs_do();
#         };
#     } catch(ex) { }
# </script>
# </body>
# </html>

# %%
ads=soup.find_all("td",attrs={"class":"title"})

# %%
for i in ads:
    print(i.a.get_text())
# Out:
# 138화
# 137화
# 136화
# 135화
# 134화
# 133화
# 132화
# 131화
# 130화
# 129화

# %%
#https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page=2&rocketAll=false&searchIndexingToken=1=4&backgroundColor=


#get 방식 -> ? 옆에 페이지, 뭐 maxprice 이런것들 입력해서 내가 원하는 값 얻을 수 있음

# %%
for i in range(1,6):
    
    url = 'https://www.coupang.com/np/search?q=%EB%85%B8%ED%8A%B8%EB%B6%81&channel=user&component=&eventCategory=SRP&trcid=&traid=&sorter=scoreDesc&minPrice=&maxPrice=&priceRange=&filterType=&listSize=36&filter=&isPriceRange=false&brand=&offerCondition=&rating=0&page={0}&rocketAll=false&searchIndexingToken=1=4&backgroundColor='.format(i)
    import re
    import requests
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36"}
    res = requests.get(url,headers=headers)
    soup = BeautifulSoup(res.text, 'lxml')
    items=soup.find_all("li",attrs={"class":re.compile("^search-product")})
    for i in items:
        ad_badge = i.find("span",attrs={"class":"ad-badge-text"})
        if ad_badge:
            print("광고상품")
            continue
        #continue는 포문 다음으로 넘김 근데 pass는 계속 진행됨 차이 잘 알기
        name = i.find("div",attrs={"class":"name"}).get_text()
        price = i.find("strong",attrs={"class":"price-value"}).get_text()
        rating = i.find("em",attrs={"class":"rating"})
        if rating:
            rating2 = rating.get_text()
        else:
            rating2 ="평점 없음"
        rate_cnt = i.find("span",attrs={"class":"rating-total-count"})
        if rate_cnt:
            rate_cnt2 = rate_cnt.get_text()
        #else:
        #    rate_cnt2 ="평점 없음"
        print("제품명 :{0}, 가격 :{1}, 평점 : {2}, 평점참여자수 :{3}".format(name,price,rating2,rate_cnt2))
# Out:
# 광고상품
# 제품명 :삼성전자 노트북9 METAL NT901X5L 가볍고 슬림한 1.29kg 코어i5 SSD256GB 윈10 탑재, 8GB, SSD 256GB, 포함, 가격 :699,000, 평점 : 4.5, 평점참여자수 :(54)
# 제품명 :디클 클릭북 노트북 D11 (Atom x5-Z8350 29.5cm eMMC32G), 화이트, WIN10, 가격 :219,000, 평점 : 4.0, 평점참여자수 :(695)
# 제품명 :아이뮤즈 노트북 로즈골드 Stormbook14 APOLLO (아폴로 레이크 N3350 35.8cm WIN10 Home), 윈도우 포함, 64GB, 4GB, 가격 :339,000, 평점 : 4.0, 평점참여자수 :(24)
# 광고상품
# 광고상품
# 제품명 :LG전자 2019 그램15 노트북 15ZD990-LX10K (팬티엄 5405U 39.6cm), 128GB, 4GB, Free DOS, 가격 :949,000, 평점 : 5.0, 평점참여자수 :(24)
# 제품명 :HP 노트북 화이트 14s-cf2055TU (펜티엄 골드 6405U 35.56cm), 가격 :399,000, 평점 : 평점 없음, 평점참여자수 :(24)
# 광고상품
# 제품명 :레노버 아이디어패드 노트북 Ice Blue S150-11 81VT (Intel Celeron N4020 29.5cm WIN10 Home S), 윈도우 포함, 64GB, 4GB, 가격 :279,000, 평점 : 4.5, 평점참여자수 :(26)
# 제품명 :Apple 2020 맥북 에어 13, Silver, 10세대 i3-1.1GHz dual-core, SSD 256GB, 8GB, 가격 :1,262,960, 평점 : 5.0, 평점참여자수 :(954)
# 제품명 :델 Inspiron 15 5505 노트북 플래티넘 실버 DN5505-WH01KR (라이젠5-4500U 39.6cm WIN10 Home), 윈도우 포함, 256GB, 8GB, 가격 :729,000, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :LG전자 2019 울트라 PC 노트북 15UD490-GX76K (라이젠 R7-2700U 39.6cm), 256GB, 8GB, Free DOS, 가격 :879,000, 평점 : 4.5, 평점참여자수 :(13)
# 제품명 :레노버 노트북 Gaming 3i-15IMH I5 LEGEND PRO DOS (i5-10300H 39.6cm WIN미포함 GTX 1650Ti), 윈도우 미포함, 256GB, 8GB, 가격 :879,660, 평점 : 4.5, 평점참여자수 :(27)
# 제품명 :삼성전자 플러스2 노트북 퓨어화이트 NT550XDA-K78AW (i7-1165G7 39.6cm WIN10 Home), 포함, NVMe 256GB, 16GB, 가격 :1,379,000, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :에이수스 VivoBook 노트북 투명 실버 X412FA-EB957(i5-10210U 35.5cm), 윈도우 미포함, 256GB, 8GB, 가격 :753,480, 평점 : 5.0, 평점참여자수 :(12)
# 제품명 :삼성전자 노트북7 Force NT760XBV-G58A (i5-8265U 39.6cm GTX1650), 256GB, 8GB, Linux, 가격 :1,179,000, 평점 : 5.0, 평점참여자수 :(155)
# 제품명 :삼성전자 시리즈3 NT351U2B 코어i3 4G SSD Win10, i3 4G SSD128 Win10, 가격 :249,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :레노버 아이디어패드 노트북 아이스블루 S150-11 PRO (셀러론 N4020 29.5cm), 윈도우 미포함, 128GB, 4GB, 가격 :289,000, 평점 : 5.0, 평점참여자수 :(4)
# 제품명 :아이뮤즈 스톰북14 노트북 로즈골드 APOLLO (듀얼코어 N3350 35.8cm WIN10 Home) + MS오피스 + 충전기 MX30PD + 키스킨, 윈도우 포함, 64GB, 4GB, 가격 :361,900, 평점 : 4.5, 평점참여자수 :(8)
# 제품명 :[윈도우10프로]주연테크 캐리북e 슬림노트북 J3GW (Intel Gemini lake Dual Core N4000 WIN10 Pro UHD Graphics 600), 4GB, eMMC 64GB(기본), Win10 Pro(포함), 가격 :279,000, 평점 : 5.0, 평점참여자수 :(4)
# 제품명 :한성컴퓨터 아방가르드 노트북 TFG276XGW (i7-10875H 43.94cm WIN10 Home RTX 2060), 윈도우 포함, 500GB, 16GB, 가격 :1,779,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :한성컴퓨터 노트북 올데이롱 TFX5470H (라이젠7-4800H 39.62cm), 윈도우 미포함, 500GB, 16GB, 가격 :938,370, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :한성컴퓨터 노트북 올데이롱 블랙 TFX255S (i5-10210U 39.62cm WIN미포함), 윈도우 미포함, 500GB, 8GB, 가격 :781,800, 평점 : 5.0, 평점참여자수 :(80)
# 제품명 :한성컴퓨터 노트북 블랙 언더케이지 TFX245S (i5-10210U 35.56cm WIN미포함), 윈도우 미포함, 500GB, 8GB, 가격 :749,000, 평점 : 5.0, 평점참여자수 :(82)
# 제품명 :삼성전자 갤럭시북 플렉스 알파 노트북 NT750QCR-A38A (i3-10110U 39.6cm WIN10 Home), 윈도우 포함, 256GB, 8GB, 가격 :1,549,000, 평점 : 5.0, 평점참여자수 :(104)
# 제품명 :레노버 노트북 PLATINUM GREY Ideapad Slim3-15IIL 5D 81WE00GUKR (i5-1035G4 39.6cm), 윈도우 미포함, 256GB, 4GB, 가격 :579,000, 평점 : 4.0, 평점참여자수 :(1)
# 제품명 :LG전자 그램 15 노트북 15ZD990-VX56K (i5-8265U 39.6cm), 윈도우 미포함, 256GB, 8GB, 가격 :1,368,020, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :LG LG노트북 i5-4세대 8G SSD256G 14인치 WIN10, SSD 240GB, 포함, 8GB, 가격 :435,000, 평점 : 4.5, 평점참여자수 :(5)
# 제품명 :레노버 YOGA 노트북 C740-14IML Vibe i7 81TC (i7-10510U 35.5cm WIN10 RAM16GB SSD 512GB Intel UHD Graphics 터치스크린), Mica, 가격 :1,199,000, 평점 : 4.5, 평점참여자수 :(7)
# 제품명 :LG 울트라PC 14U390-ME1TK 재택근무 원격수업 가성비 노트북 추천, 가격 :449,000, 평점 : 평점 없음, 평점참여자수 :(7)
# 제품명 :LG 울트라PC 15U560 6세대 i5 HD520 15.6인치 윈도우10, 8GB, SSD 256GB + HDD 500GB, 포함, 가격 :585,000, 평점 : 4.0, 평점참여자수 :(4)
# 제품명 :한성컴퓨터 언더케이지 노트북 블랙 TFX245SW (i5-10210U 35.56cm WIN10 MX250 2GB), 윈도우 포함, 500GB, 8GB, 가격 :860,090, 평점 : 5.0, 평점참여자수 :(21)
# 제품명 :레노버 노트북 Gaming 3i-15IMH I5 LEGEND PRO W10 (i5-10300H 39.6cm WIN10 Home GTX 1650Ti), 윈도우 포함, 256GB, 8GB, 가격 :977,510, 평점 : 5.0, 평점참여자수 :(13)
# 제품명 :레노버 노트북 미네랄 그레이 ThinkBook 15 IML-20RW00B2KR (i5-10210U 39.624cm), 윈도우 미포함, 256GB, 8GB, 가격 :649,000, 평점 : 3.0, 평점참여자수 :(4)
# 제품명 :레노버 노트북 Black ThinkPad E15-20T8S03600(라이젠5-4500U 39.6cm), 윈도우 미포함, 256GB, 8GB, 가격 :691,630, 평점 : 5.0, 평점참여자수 :(13)
# 제품명 :삼성전자 노트북 Pen NT930QBE-K37WD Crush White (i3-8145U 33.7cm Win10 Home), 포함, NVMe 256GB, 8GB, 가격 :1,099,000, 평점 : 4.5, 평점참여자수 :(30)
# 제품명 :삼성전자 갤럭시북 S Wi-Fi 노트북 얼씨 골드 NT767XCM-K38 (i3-L13G4 33.7cm WIN10 Home), 윈도우 포함, 256GB, 8GB, 가격 :998,000, 평점 : 5.0, 평점참여자수 :(8)
# 제품명 :레노버 아이디어패드 듀엣3 노트북 Graphite Grey 10IGL5-82T0029KR (셀러론N4020 26.16cm WIN10 Home S), 윈도우 포함, 64GB, 4GB, 가격 :429,550, 평점 : 4.5, 평점참여자수 :(6)
# 제품명 :레노버 IdeaPad Duet3 노트북 Graphite Grey 10IGL05-82AT0028KR (셀러론-N4020 26.162cm WIN10 Home S), 윈도우 포함, 64GB, 4GB, 가격 :488,260, 평점 : 4.5, 평점참여자수 :(2)
# 제품명 :에이수스 엑스퍼트북 노트북 P1504FA-BQ593 (i5-8265U 39.6cm WIN미포함), 윈도우 미포함, 128GB, 4GB, 가격 :633,270, 평점 : 5.0, 평점참여자수 :(10)
# 제품명 :아이뮤즈 스톰북14 노트북 로즈골드 APOLLO (듀얼코어 N3350 35.8cm WIN10 Home) + MS오피스 + 충전기 MX30PD + 보조배터리 PD2 + 키스킨, 윈도우 포함, 64GB, 4GB, 가격 :391,900, 평점 : 평점 없음, 평점참여자수 :(10)
# 제품명 :기가바이트 AORUS 5 게이밍 노트북 블랙 MB i5 C (i5-10200H 39.6cm GTX 1650Ti), 윈도우 미포함, 512GB, 16GB, 가격 :999,000, 평점 : 5.0, 평점참여자수 :(28)
# 제품명 :싱크패드 노트북 블랙 L14 20U5S01S00 (라이젠5 PRO 4650U 35.5cm), 윈도우 미포함, 256GB, 8GB, 가격 :774,630, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :레노버 아이디어패드 노트북 플래티넘그레이 S150-11 PRO (셀러론 N4020 29.5cm), 윈도우 미포함, 128GB, 4GB, 가격 :289,000, 평점 : 4.5, 평점참여자수 :(5)
# 제품명 :한성컴퓨터 아방가르드 노트북 TFG256XGW (i7-10875H 39.62cm WIN10 Home RTX 2060), 윈도우 포함, 500GB, 16GB, 가격 :1,679,000, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :[윈도우10프로] 주연테크 캐리북e 슬림노트북 J3GW_2S (Intel N4000/Win10 Pro/IPS pannel/M.2 SSD250GB), 4GB, M.2 SSD250GB(추가/파티션이동), Win10 Pro(포함), 가격 :358,000, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :한성컴퓨터 언더케이지 노트북 실버 TFX245SW (i5-10210U 35.56cm WIN10 MX250 2GB), 윈도우 포함, 500GB, 8GB, 가격 :860,090, 평점 : 4.5, 평점참여자수 :(12)
# 제품명 :LG전자 10세대 코어i7 윈10탑재 17형 LG 그램 2020년형 17Z90N 그레이 정품키스킨 증정, 16GB, SSD 512GB, 포함, 가격 :1,689,000, 평점 : 4.5, 평점참여자수 :(55)
# 제품명 :Apple 2020 맥북 에어 13, 스페이스 그레이, 코어i5, 256GB, 8GB, 가격 :1,200,920, 평점 : 5.0, 평점참여자수 :(954)
# 제품명 :삼성전자 노트북 Plus NT550XCR-AD5A 퓨어 화이트 (i5-10210U 39.6cm), NVMe 256GB, 8GB, WIN10 Home, 가격 :1,180,000, 평점 : 5.0, 평점참여자수 :(46)
# 제품명 :이그닉 바이북 14 2세대 IG-BYB14104(5405U 358mm WIN미포함 FHD Graphics 620 IPS), 윈도우 미포함, 128GB, 8GB, 가격 :451,700, 평점 : 4.5, 평점참여자수 :(26)
# 제품명 :HP 14s 노트북 14s-dq1004TU (i5-1035G1 35.6cm WIN10 Home), 포함, NVMe 128GB, 4GB, 가격 :686,180, 평점 : 평점 없음, 평점참여자수 :(26)
# 제품명 :LG전자 램14 노트북 14Z995-GR30K 14Z995 스노우화이트(10세대 i3-10110U 35.5cm WIN10 Home UHD Graphics), 윈도우 포함, 256GB, 8GB, 가격 :1,236,970, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :LG전자 울트라기어 노트북 15UD70N-PX70K (i7-10510U 39.6cm GTX1050), 256GB, 8GB, Free DOS, 가격 :1,499,000, 평점 : 4.5, 평점참여자수 :(11)
# 제품명 :마이크로스프트 서피스고2 노트북 STV-00009-G (Intel Pentium Gold 26.6cm WIN10 Home S HD Graphics615), 윈도우 포함, 64GB, 4GB, 가격 :535,530, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :LG노트북/LG전자 2019그램 노트북 14인치 (I5-8세대/8G/SSD256)/ 14Z990-GP5ML/ 사은품증정/본사직배송/당일출고/무료배송, 14Z990-GP5ML, 8GB, SSD256GB, 가격 :43,700, 평점 : 4.0, 평점참여자수 :(1)
# 제품명 :LG LG그램 LG노트북 i3-6세대 8G SSD256G 14인치 WIN10, 8GB, 256GB, 포함, 가격 :699,000, 평점 : 4.0, 평점참여자수 :(109)
# 제품명 :한성컴퓨터 게이밍 노트북 TFG256XS (i7-10875H 39.62cm WIN미포함 RTX 2060), 윈도우 미포함, 500GB, 8GB, 가격 :1,466,750, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :주연테크 라이트플라이 울트라북 967g 노트북 Cool Gray J7FCW (10세대 i5-10210U WIN10 Home), 8GB, 256GB, 포함, 가격 :898,000, 평점 : 5.0, 평점참여자수 :(7)
# 제품명 :삼성전자 2020 갤럭시북 플렉스 NT950QCG-X716A (i7-1065G7 39.6cm MX250), 1024GB, 16GB, WIN10 Home, 가격 :2,598,000, 평점 : 4.5, 평점참여자수 :(213)
# 제품명 :LG전자 울트라북 15U560 코어i5 윈도우10 탑재 15인치 노트북, 8GB, SSD 128G + HDD500G, 가격 :678,000, 평점 : 3.5, 평점참여자수 :(2)
# 제품명 :Apple 2019년 맥북 프로 16, 코어i9, 32GB, 1024GB, 실버, 라데온 Pro 5500M, 가격 :4,130,000, 평점 : 5.0, 평점참여자수 :(1562)
# 제품명 :HP ENVY X360 컨버터블 노트북 13-ar0152AU (라이젠5 3500U 33.7cm WIN10 Home 라데온 Vega8) + USB C TO MULTI 커넥터 + 스타일 액티브 펜, 윈도우 포함, 256GB, 8GB, 가격 :1,037,960, 평점 : 5.0, 평점참여자수 :(44)
# 제품명 :에이수스 노트북 블랙 S533FL-BQ503 (i5-10210U 39.62cm MX250), 윈도우 미포함, 512GB, 8GB, 가격 :849,000, 평점 : 5.0, 평점참여자수 :(11)
# 제품명 :LG전자 울트라 PC 노트북 17U790-GA36K (i3-8145U 43.1cm), 128GB, 8GB, WIN10 Home, 가격 :1,074,140, 평점 : 5.0, 평점참여자수 :(12)
# 제품명 :마이크로소프트 노트북 서피스 프로7 플래티넘 VDV-00010 (i5-1035G4 31.2cm WIN10 Home), 윈도우 포함, 128GB, 8GB, 가격 :972,260, 평점 : 5.0, 평점참여자수 :(11)
# 제품명 :LG전자 2020 그램 13 노트북 스노우 화이트 ZD990-VX50K (i5-8265U 33.7cm), 윈도우 미포함, 256GB, 8GB, 가격 :1,099,000, 평점 : 5.0, 평점참여자수 :(10)
# 제품명 :LG전자 그램14 노트북 14ZD990-GX56K (i5-8265U 35.5cm), 윈도우 미포함, 256GB, 8GB, 가격 :1,142,090, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :LG전자 2020 그램14 노트북 14ZD90N-VX5BK 다크 실버 (i5-1035G7 35.5cm), 256GB, 8GB, Free DOS, 가격 :1,315,940, 평점 : 5.0, 평점참여자수 :(17)
# 제품명 :에이수스 젠북플립14 라이트 그레이 UM462DA-AI082 (R5-3500U 35.56Cm WIN미포함 라데온 Vega8 Graphics), 윈도우 미포함, 512GB, 8GB, 가격 :879,000, 평점 : 5.0, 평점참여자수 :(7)
# 제품명 :한성컴퓨터 올데이롱 노트북 실버 TFX255SW (i5-10210U 39.49cm WIN10 MX250 2GB), 윈도우 포함, 500GB, 8GB, 가격 :909,010, 평점 : 4.5, 평점참여자수 :(6)
# 제품명 :에이서 니트로5 노트북 AN515-55-781T (i7-10750H 39.6cm GTX 1660 Ti ), 윈도우 미포함, 256GB, 8GB, 가격 :1,159,000, 평점 : 5.0, 평점참여자수 :(8)
# 제품명 :에이수스 엑스퍼트북 노트북 P1402FA-EB530 (i5-8265U 35.6cm WIN미포함), 윈도우 미포함, 256GB, 4GB, 가격 :573,400, 평점 : 3.5, 평점참여자수 :(2)
# 제품명 :Apple 2020년 맥북 프로 13, 코어i7, 16GB, 512GB, 실버, 가격 :2,760,000, 평점 : 5.0, 평점참여자수 :(838)
# 제품명 :이그닉 바이북 프로 14 리프레시 노트북 IG-BYB14109 (I5-10210U 35.5cm WIN미포함 UHD IPS), 윈도우 미포함, 256GB, 8GB, 가격 :631,700, 평점 : 4.5, 평점참여자수 :(34)
# 제품명 :LG전자 2020년 그램17 노트북 17ZD90N-VX5BK (i5-1035G7 43.1cm), 256GB, 8GB, Free DOS, 가격 :1,619,000, 평점 : 5.0, 평점참여자수 :(60)
# 제품명 :삼성전자 갤럭시북 S NT767XCM-K58S Mercury Gray (Wi-Fi전용 i5-L16G7 33.7cm Win10 Home), 윈도우 포함, 256GB, 8GB, 가격 :1,278,000, 평점 : 5.0, 평점참여자수 :(21)
# 제품명 :한성컴퓨터 노트북 올데이롱 TFX5450H (라이젠5-4600H 39.62cm), 윈도우 미포함, 250GB, 8GB, 가격 :799,000, 평점 : 5.0, 평점참여자수 :(35)
# 제품명 :레노버 노트북 ThinkBook 14 IIL 20SLA00MKR (i7-1065G7 35.56cm WIN10 Home), 윈도우 포함, 256GB, 8GB, 가격 :978,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :중고노트북 10만원대 삼성 LG HP 등, 단일색상, [A] 레노버EDGE, 가격 :109,000, 평점 : 4.0, 평점참여자수 :(44)
# 제품명 :에이서 스위프트3 노트북 퍼플 SF314-42 R5씬스틸러 (라이젠5-4500U 35.56cm), 윈도우 미포함, 256GB, 16GB, 가격 :799,000, 평점 : 4.0, 평점참여자수 :(10)
# 제품명 :MSI 모던 14 노트북 B10MW-i3 (i3-10110U 35.56cm), 윈도우 미포함, 256GB, 8GB, 가격 :599,000, 평점 : 4.0, 평점참여자수 :(2)
# 제품명 :삼성전자 노트북7 Force NT760XBV-G58A (i5-8265U 39.6cm GTX1650), 256GB, 8GB, WIN10 Home, 가격 :1,358,000, 평점 : 5.0, 평점참여자수 :(155)
# 제품명 :삼성전자 노트북7 NT750XBV-G517A 플래티넘 티탄 (i5-8265U 39.6cm MX250), 256GB, 16GB, Linux, 가격 :1,199,000, 평점 : 4.5, 평점참여자수 :(15)
# 제품명 :마이크로소프트 서피스 랩탑 고 노트북 플래티넘 (i5-1035G1 31.62cm WIN10 Home), 윈도우 포함, 64GB, 4GB, 가격 :788,000, 평점 : 평점 없음, 평점참여자수 :(15)
# 제품명 :삼성전자 시리즈3 NT301E5C i5 4G SSD256 Win10, 4GB, 가격 :299,000, 평점 : 4.5, 평점참여자수 :(2)
# 제품명 :Apple 2020년 맥북 에어 13 (M1 칩셋 8코어 CPU), 실버, SSD 256GB, 가격 :1,290,000, 평점 : 5.0, 평점참여자수 :(40)
# 제품명 :삼성전자 노트북 플러스2 블레이드블랙 노트북 NT560XDZ-G78A (i7-1165G7 39.6cm GTX 1650Ti), 미포함, NVMe 512GB, 8GB, 가격 :1,558,000, 평점 : 평점 없음, 평점참여자수 :(40)
# 제품명 :DeLL E5520 i7탑재 8G램 SSD 256G 윈도우10 무료 업그레이드, 8GB, SSD 256GB, 가격 :299,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :에이수스 ROG 게이밍 노트북 G512LU-AL043 (i7-10750H 39.6cm WIN미포함 GTX1660Ti), 윈도우 미포함, 512GB, 8GB, 가격 :1,399,000, 평점 : 4.5, 평점참여자수 :(29)
# 제품명 :Xnote 15N540 4세대 i7탑재 16G램 SSD 256G 지포스 윈도우10 무료업그레이드, 16GB, SSD 256GB, 가격 :559,000, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :LG전자 2020 그램15 노트북 15Z90N-VR56K (i5-1035G7 39.6cm), 512GB, 8GB, WIN10 Home, 가격 :1,720,690, 평점 : 5.0, 평점참여자수 :(101)
# 제품명 :삼성전자 노트북 7 Force 블레이드 블랙 NT760XBV-G58A(i5-8265U 39.6cm WIN 미포함 GTX 1650), 윈도우 미포함, 256GB, 16GB, 가격 :1,239,000, 평점 : 5.0, 평점참여자수 :(9)
# 제품명 :LG PC그램 14Z960 6세대 i5탑재 윈도우10 사은품 증정, 8GB, SSD 256GB, 윈도우 10, 가격 :699,000, 평점 : 3.5, 평점참여자수 :(3)
# 제품명 :에이수스 ZenBook14 UX434FLC-A6267T (i7-10510U 35.56cm WIN10 MX250), 윈도우 포함, 1024GB, 16GB, 가격 :1,499,000, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :LG전자 2020 그램17 노트북 17ZD90N-VX7BK (i7-1065G7 43.1cm), 256GB, 8GB, Free DOS, 가격 :1,722,630, 평점 : 5.0, 평점참여자수 :(68)
# 제품명 :LG전자 울트라PC 17UD790-GX36K (i3-8145U 43.1cm), 128GB, 8GB, Free DOS, 가격 :929,070, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :LG전자 2020 그램 2in1 노트북 14TD90N-VX30K (i3-10110U 35.5cm), 256GB, 8GB, Free DOS, 가격 :1,271,350, 평점 : 4.5, 평점참여자수 :(33)
# 제품명 :에이서 스위프트3 노트북 실버 SF314-42 R5씬스틸러 (라이젠5-4500U 35.56cm), 윈도우 미포함, 256GB, 16GB, 가격 :799,000, 평점 : 5.0, 평점참여자수 :(4)
# 제품명 :MSI 모던15 노트북 스페이스 그레이 A10M (264) (i5-10210U 39.624cm), 윈도우 미포함, 256GB, 8GB, 가격 :799,000, 평점 : 4.5, 평점참여자수 :(10)
# 제품명 :한성컴퓨터 BossMonster 노트북 RX5067 (R7-3700X 39.62cm WIN미포함 RTX 2060), 윈도우 미포함, 250GB, 8GB, 가격 :1,479,000, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :레노버 노트북 Gaming 3i-15IMH I7 LEGEND W10 (i7-10750H 39.6cm WIN10 Home GTX 1650), 윈도우 포함, 256GB, 8GB, 가격 :1,158,000, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :HP 파빌리온 게이밍 노트북 쉐도우 블랙 16-a0048TX (i7-10750H 40.9cm WIN미포함 GTX 1650 Ti), 윈도우 미포함, 512GB, 8GB, 가격 :1,199,000, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :LG전자 2020 그램 17 노트북 17Z90N-VA56K (i5-1035G7 43.1cm), 512GB, 8GB, WIN10 Home, 가격 :1,795,270, 평점 : 4.5, 평점참여자수 :(72)
# 제품명 :레노버 노트북 ThinkPad L490-9KD (i5-8265U 35.5cm 라데온535), 256GB, 8GB, Free DOS, 가격 :862,270, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :LG전자 그램15 노트북 15ZD995-VX70K 스노우 화이트 (i7-10510U 39.6cm), 256GB, 8GB, Free DOS, 가격 :1,587,720, 평점 : 4.5, 평점참여자수 :(11)
# 제품명 :레노버 Flex 5 노트북 Graphire Grey 14ARE R5 W10 (라이젠5-4500U 35.5cm WIN10 Home Radeon Graphics), 윈도우 포함, 256GB, 8GB, 가격 :829,000, 평점 : 4.5, 평점참여자수 :(3)
# 제품명 :에이수스 크레이터X 노트북 X571LH-BN019 (i5-10300H 39.6cm GTX 1650), 윈도우 미포함, 512GB, 8GB, 가격 :999,000, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :싱크패드 E15 20RDS00S00 노트북 TP00117A (i5-10210U 39.6cm WIN미포함), 윈도우 미포함, 256GB, 4GB, 가격 :797,990, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :에이수스 ROG 제피러스 GA401 노트북 GA401II-HE150T (라이젠7 4800HS 35.8cm WIN10 Home GTX1650TI), 윈도우 포함, 512GB, 8GB, 가격 :1,449,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :삼성전자 갤럭시북 플렉스 알파 노트북 머큐리 그레이 NT730QCR-A516A (i5-10210U 33.7cm), 미포함, NVMe 512GB, 16GB, 가격 :1,579,000, 평점 : 5.0, 평점참여자수 :(50)
# 제품명 :한성컴퓨터 노트북 실버 언더케이지 TFX245S (i5-10210U 35.56cm WIN미포함), 윈도우 미포함, 500GB, 8GB, 가격 :749,000, 평점 : 5.0, 평점참여자수 :(40)
# 제품명 :삼성전자 2020 갤럭시북 플렉스 NT950QCT-A58A 로얄블루 (i5-1035G4 39.6cm), 256GB, 8GB, WIN10 Home, 가격 :1,999,000, 평점 : 4.5, 평점참여자수 :(86)
# 제품명 :에이수스 젠북14 스크린패드 UX434FLC-A6210T (10세대 코어i5-10210U 35.56cm WIN10) 로얄 블루, 윈도우 포함, 512GB, 8GB, 가격 :1,349,000, 평점 : 4.0, 평점참여자수 :(14)
# 제품명 :HP 프로북 440 G7 9KZ07PA HSN-Q21C (10세대 i5-10210U 35.6cm WIN10), 윈도우 포함, 512GB, 8GB, 가격 :954,110, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :한성컴퓨터 노트북 올데이롱 TFX5450HW (라이젠5-4600H 39.62cm WIN10 Home), 윈도우 포함, 250GB, 8GB, 가격 :929,000, 평점 : 5.0, 평점참여자수 :(7)
# 제품명 :Apple 2020 맥북 에어 13, 골드, 코어i5, 512GB, 8GB, 가격 :1,474,110, 평점 : 5.0, 평점참여자수 :(954)
# 제품명 :LG 15N540 4세대 i5 지포스840M 15.6인치 윈도우10, 16GB, SSD 512GB, 포함, 가격 :539,000, 평점 : 3.5, 평점참여자수 :(3)
# 제품명 :에이수스 젠북14 스크린패드 UX434FLC-A6339T (10세대 코어i7-10510U 35.56cm WIN10) 아이시클 실버, 윈도우 포함, 1024GB, 16GB, 가격 :1,499,000, 평점 : 5.0, 평점참여자수 :(13)
# 제품명 :LG전자 울트라PC 15UD40N-GX36K 라이젠3 인강용 저렴함 가성비 노트북, NVMe 256GB, 8GB, 미포함, 가격 :719,000, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :LG전자 2020 그램14 노트북 14Z90N-VR56K (i5-1035G7 35.5cm), 512GB, 8GB, WIN10 Home, 가격 :1,639,000, 평점 : 4.5, 평점참여자수 :(41)
# 제품명 :한성컴퓨터 올데이롱 노트북 TFX5470HW (라이젠7-4800H 39.62cm WIN10 Home), 윈도우 포함, 500GB, 16GB, 가격 :1,065,570, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :LG전자 울트라PC 15U50N-GR36K 특별사은품 Win10탑재 인강용 서무용 사무용 학생 노트북, 8GB, SSD 128GB, 포함, 가격 :848,000, 평점 : 4.0, 평점참여자수 :(1)
# 제품명 :레노버 노트북 L540 리퍼 i5-4200/4G/SSD128G/Win10, 가격 :299,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :기가바이트 게이밍노트북 AORUS 7 SB i7 (i7-10750H 43.9cm GTX1660Ti), 윈도우 미포함, 1536GB, 16GB, 가격 :1,559,000, 평점 : 5.0, 평점참여자수 :(11)
# 제품명 :레노버 ThinkBook 14-IIL 20SLA00HKR 노트북 10세대 i3-1005G1 35.5cm WIN미포함, 윈도우 미포함, 128GB, 4GB, 가격 :507,830, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :Apple 2020년 맥북 프로 13 (M1 칩셋 8코어 CPU 8코어 GPU), 스페이스 그레이, 256GB, 가격 :1,690,000, 평점 : 4.5, 평점참여자수 :(84)
# 제품명 :Apple 2020년 맥북 에어 13 (M1 칩셋 8코어 CPU), 스페이스 그레이, SSD 256GB, 가격 :1,290,000, 평점 : 5.0, 평점참여자수 :(40)
# 제품명 :삼성전자 갤럭시북 플렉스 알파 노트북 NT750QCR-A58A-X16G (i5-10210U 39.6cm), 윈도우 미포함, 256GB, 16GB, 가격 :1,618,000, 평점 : 4.5, 평점참여자수 :(19)
# 제품명 :HP ENVY 게이밍 노트북 네추럴 실버 15-EP0093TX (i5-10300H 39.6cm WIN10 Home GTX 1650 Ti), 윈도우 포함, 256GB, 16GB, 가격 :1,384,280, 평점 : 평점 없음, 평점참여자수 :(19)
# 제품명 :에이수스 크리에이터X 노트북 X571LI-BN011 (i7-10750H 39.6cm GTX 1650Ti), 윈도우 미포함, 544GB, 8GB, 가격 :1,349,000, 평점 : 4.5, 평점참여자수 :(9)
# 제품명 :레노버 노트북 Platinum Grey ideapad S340-13IML 7D (인텔 10세대 i7-10510U 33.78cm WIN10 Intel UHD Graphics), 윈도우 포함, 256GB, 8GB, 가격 :909,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :삼성전자 갤럭시북 S NT767XCM-K58 Earth Gold (Wi-Fi전용 i5-L16G7 33.7cm Win10 Home), 포함, eUFS 256GB, 8GB, 가격 :1,278,000, 평점 : 4.5, 평점참여자수 :(19)
# 제품명 :HP 노트북 14s-dq1004TU TPN-Q221 (i5-1035G1 35.6cm WIN미포함), 윈도우 미포함, 128GB, 4GB, 가격 :554,350, 평점 : 4.0, 평점참여자수 :(6)
# 제품명 :LG전자 그램 14 노트북 14ZD90N-VX30K 스노우 화이트 (i3-1005G1 35.5cm), 256GB, 8GB, Free DOS, 가격 :1,228,000, 평점 : 4.5, 평점참여자수 :(48)
# 제품명 :주연테크 올데이 슈퍼플라이 울트라 캐리북 Cool Gray J7FC_5SUP (10세대 i5-10210U 35.56cm WIN미포함 intel UHD Graphics), 16GB, 512GB, 미포함, 가격 :949,000, 평점 : 5.0, 평점참여자수 :(13)
# 제품명 :한성컴퓨터 노트북 언더케이지 TFX4470HW (R7-4800H 35.56cm AMD Radeon graphic), 윈도우 포함, 500GB, 16GB, 가격 :1,029,000, 평점 : 평점 없음, 평점참여자수 :(13)
# 제품명 :HP 사무용노트북 840G3 i7-6600U 8G SSD256G 14인치 WIN10, 8GB, SSD 256GB, 포함, 가격 :499,000, 평점 : 4.0, 평점참여자수 :(23)
# 제품명 :MSI 노트북 Creator 17M A10SD (i7-10750H 43.942cm GTX1660Ti), 윈도우 미포함, 512GB, 16GB, 가격 :1,593,000, 평점 : 4.5, 평점참여자수 :(29)
# 제품명 :한성컴퓨터 아방가르드 노트북 실버 TFX255GS (i7-9750H 39.62cm WIN미포함 Graphics 630 + GTX 1650), 윈도우 미포함, 1024GB, 8GB, 가격 :1,371,020, 평점 : 4.5, 평점참여자수 :(31)
# 제품명 :한성컴퓨터 노트북 아방가르드 블랙 TFX5075G (i7-10750H 39.62cm GTX1650Ti), 윈도우 미포함, 500GB, 16GB, 가격 :1,249,000, 평점 : 5.0, 평점참여자수 :(32)
# 제품명 :HP 노트북 PAVILION GAMING 16-a0047tx (i5-10300H 40.9cm GTX 1650 Ti), 윈도우 미포함, 512GB, 8GB, 가격 :1,028,870, 평점 : 5.0, 평점참여자수 :(2)
# 제품명 :LG전자 2020 그램 2in1 노트북 14TD90N-VX50K (i5-10210U 35.5cm), NVMe 256GB, 8GB, Free DOS, 가격 :1,463,190, 평점 : 4.5, 평점참여자수 :(52)
# 제품명 :LG전자 2020 그램 2in1 노트북 14T90N-VR30K (i3-10110U 35.5cm), NVMe 256GB, 8GB, WIN10 Home, 가격 :1,395,260, 평점 : 5.0, 평점참여자수 :(4)
# 제품명 :Apple 2020년 맥북 에어 13 (M1 칩셋 8코어 CPU), 골드, SSD 512GB, 가격 :1,630,000, 평점 : 5.0, 평점참여자수 :(40)
# 제품명 :Apple 2019년 맥북 프로 16, 코어i7, 16GB, 512GB, 스페이스 그레이, 라데온 Pro 5300M, 가격 :3,107,000, 평점 : 5.0, 평점참여자수 :(1562)
# 제품명 :한성컴퓨터 노트북 TFG256XX (i7-10875H 39.62cm RTX2060), 윈도우 미포함, 500GB, 16GB, 가격 :1,449,000, 평점 : 4.5, 평점참여자수 :(12)
# 제품명 :LG전자 2020 그램15 노트북 (i7-1065G7 39.6cm), 8GB, 256GB, Free DOS, 미포함, 8GB, 가격 :1,678,000, 평점 : 5.0, 평점참여자수 :(39)
# 제품명 :LG전자 울트라 기어 노트북 15UD70N-PX50K (i5-10210U 39.6cm GTX 1050), 256GB, 8GB, Free DOS, 가격 :1,247,360, 평점 : 4.5, 평점참여자수 :(16)
# 제품명 :Apple 2020년 맥북 프로 13 (M1 칩셋 8코어 CPU 8코어 GPU), 실버, 512GB, 가격 :1,881,600, 평점 : 4.5, 평점참여자수 :(84)
# 제품명 :LG전자 2020 그램15 노트북 (i7-1065G7 39.6cm), 8GB, SSD 256GB, WIN10 Home, 포함, 8GB, 가격 :1,799,000, 평점 : 5.0, 평점참여자수 :(39)
# 제품명 :삼성전자 갤럭시북 S NT767XCL-KLTES Mercury Gray (LTE겸용 i5-L16G7 33.7cm Win10 Home), 윈도우 포함, 512GB, 8GB, 가격 :1,348,000, 평점 : 4.5, 평점참여자수 :(22)
# 제품명 :기가바이트 게이밍노트북 AORUS 5 SB i7 E (i7-10750H 39.6cm GTX1660Ti), 윈도우 미포함, 256GB, 8GB, 가격 :1,299,000, 평점 : 5.0, 평점참여자수 :(17)
# 제품명 :한성컴퓨터 노트북 아방가르드 블랙 TFX5075GW (i7-10750H 39.62cm GTX1650Ti), 윈도우 포함, 500GB, 16GB, 가격 :1,379,000, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :레노버 노트북 Legion 5i-17IMH Ultra(i7-10750H 43.9CM GTX 1660Ti), 미포함, NVMe 256GB, 8GB, 가격 :1,464,910, 평점 : 5.0, 평점참여자수 :(3)
# 제품명 :한성컴퓨터 노트북 올데이롱 실버 TFX255S (i5-10210U 39.62cm WIN미포함), 윈도우 미포함, 500GB, 8GB, 가격 :781,800, 평점 : 5.0, 평점참여자수 :(55)
# 제품명 :삼성전자 갤럭시북 플렉스 노트북 로얄 블루 NT930QCT-A38A (i3-1005G1 33.7cm), 윈도우 미포함, 256GB, 8GB, 가격 :1,498,000, 평점 : 4.0, 평점참여자수 :(37)
# 제품명 :레노버 노트북 Gaming 3i-15IMH I5 LEGEND DOS (i5-10300H 39.6cm WIN미포함 GTX 1650), 윈도우 미포함, 256GB, 8GB, 가격 :848,000, 평점 : 5.0, 평점참여자수 :(37)
# 제품명 :한성컴퓨터 BossMonster 노트북 X7067T (i7-10875H 43.94cm WIN미포함 GTX1660Ti), 윈도우 미포함, 250GB, 8GB, 가격 :1,271,060, 평점 : 4.5, 평점참여자수 :(17)
# 제품명 :한성컴퓨터 노트북 BossMonster X5067T (i7-10875H 39.62cm WIN미포함 GTX 1660Ti), 윈도우 미포함, 250GB, 8GB, 가격 :1,249,000, 평점 : 4.5, 평점참여자수 :(14)
# 제품명 :레노버 ThinkPad X13 노트북 18KR (라이젠7 Pro-4750U 33.78cm WIN10 Pro), 윈도우 포함, 256GB, 16GB, 가격 :1,499,000, 평점 : 평점 없음, 평점참여자수 :(14)
# 제품명 :레노버 아이디어패드 슬림 S340-14IWL 81N700AQKR 81N7 (I5-8265U 35.5cm WIN10 RAM 4GB SSD 128GB), 81N7, ONYX BLACK, 가격 :755,630, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :에이수스 Vivo 노트북 인디블랙 S433FA-EB452 (i5-10210U 35.5cm), 윈도우 미포함, 512GB, 8GB, 가격 :799,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :삼성전자 갤럭시북 플렉스 노트북 NT930QCG-K58A 로얄 블루 (i5-1035G4 33.7cm), 256GB, 8GB, WIN10 Home, 가격 :1,717,200, 평점 : 5.0, 평점참여자수 :(50)
# 제품명 :마이크로스프트 서피스고2 노트북 포피레드 (Intel Core m3 26.6cm WIN10 Home S HD Graphics615 LTE), 윈도우 포함, 128GB, 8GB, 가격 :1,103,090, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :레노버 노트북 Legion 5 15ARH ZEN PLUS PRO 2060 W10 (라이젠7-4800H 39.6cm WIN10 Pro RTX2060), 윈도우 포함, 256GB, 8GB, 가격 :1,509,000, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :레노버 노트북 Flex 5 14IIL i5 MX W10 (i5-1035G1 35.5cm WIN10 Home MX330), 윈도우 포함, 256GB, 8GB, 가격 :999,000, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :레노버 YOGA C740-14IML i5 Vibe 노트북 Iron Grey 81TC007BKR (i5-10210U 35.5cm WIN10 Intel UHD Grapics), 윈도우 포함, 256GB, 8GB, 가격 :999,000, 평점 : 4.5, 평점참여자수 :(8)
# 제품명 :LG전자 2020 울트라기어 노트북 17U70N-PA56K (i5-10210U 43.1cm GTX 1650), 256GB, 8GB, WIN10 Home, 가격 :1,739,000, 평점 : 4.5, 평점참여자수 :(9)
# 제품명 :LG전자 그램14 노트북 스노우 화이트 14Z990-GR56K (i5-8265U 35.5cm WIN10 Home), 윈도우 포함, 256GB, 8GB, 가격 :1,398,000, 평점 : 4.5, 평점참여자수 :(5)
# 제품명 :한성컴퓨터 노트북 아방가르드 실버 TFX5075GW (i7-10750H 39.62cm GTX1650Ti), 윈도우 포함, 500GB, 16GB, 가격 :1,379,000, 평점 : 5.0, 평점참여자수 :(7)
# 제품명 :LG전자 그램14 스노우화이트 14Z90N-EB36K (i3-1005G1 35.5cm WIN10S), 윈도우 포함, 128GB, 4GB, 가격 :1,053,080, 평점 : 5.0, 평점참여자수 :(5)
# 제품명 :델 노트북 LATITUDE 3300-58G25W (i5-8250U 33.78cm 8GB DDR4 256GB M.2 NVMe SSD UHD620 WIN 10 Home), 포함, 가격 :860,000, 평점 : 5.0, 평점참여자수 :(1)
# 제품명 :레노버 노트북 Legion 5-15ARH (라이젠7-4800H 39.6cm GTX 1650Ti), 미포함, NVMe 256GB, 8GB, 가격 :1,139,000, 평점 : 5.0, 평점참여자수 :(14)
# 제품명 :Apple 2020년 맥북 프로 13, 10세대 i5, 32GB, SSD 512GB, 실버, 가격 :3,030,000, 평점 : 5.0, 평점참여자수 :(838)
# 제품명 :에이서 니트로5 AN515-54-7078 노트북 (i7-9750H 39.6cm GTX1660Ti), 256GB, 4GB, Free DOS, 가격 :1,429,560, 평점 : 5.0, 평점참여자수 :(6)
# 제품명 :Apple 2019년 맥북 프로 16, 9세대 i9, 32GB, SSD 1TB, 스페이스 그레이, AMD Radeon Pro 5600M 8GB, 가격 :5,445,000, 평점 : 5.0, 평점참여자수 :(1562)
# 제품명 :레이저 BLADE Pro 17 게이밍 노트북 9Gen R80 512 Lite (i7-9750H 43.94cm WIN10 Home RTX2080 Max-Q), 윈도우 포함, 512GB, 16GB, 가격 :2,990,000, 평점 : 5.0, 평점참여자수 :(8)
# 제품명 :기가바이트 게이밍노트북 AORUS 5 SB i7 (i7-10750H 39.6cm GTX1660Ti), 윈도우 미포함, 1536GB, 16GB, 가격 :1,449,000, 평점 : 5.0, 평점참여자수 :(17)

# %%
items
# Out:
# []

# %%
for i in items:
    ad_badge = i.find("span",attrs={"class":"ad-badge-text"})
    if ad_badge:
        print("광고상품")
        continue
    #continue는 포문 다음으로 넘김 근데 pass는 계속 진행됨 차이 잘 알기
    name = i.find("div",attrs={"class":"name"}).get_text()
    price = i.find("strong",attrs={"class":"price-value"}).get_text()
    rating = i.find("em",attrs={"class":"rating"})
    if rating:
        rating2 = rating.get_text()
    else:
        rating2 ="평점 없음"
    rate_cnt = i.find("span",attrs={"class":"rating-total-count"})
    if rate_cnt:
        rate_cnt2 = rate_cnt.get_text()
    #else:
    #    rate_cnt2 ="평점 없음"
    print("제품명 :{0}, 가격 :{1}, 평점 : {2}, 평점참여자수 :{3}".format(name,price,rating2,rate_cnt2))
    link = i.find("a", attrs={"class":"search-product-link"})['href']
    
    print("바로가기 주소 :",link)
    print("-"*30)
# Out:
# 제품명 :LG전자 2020 그램 2in1 노트북 14T90N-VR30K (i3-10110U 35.5cm), NVMe 256GB, 8GB, WIN10 Home, 가격 :1,395,260, 평점 : 5.0, 평점참여자수 :(4)
# 바로가기 주소 : /vp/products/1662913924?itemId=2141682280&vendorItemId=70140052830
# ------------------------------
# 제품명 :Apple 2020년 맥북 에어 13 (M1 칩셋 8코어 CPU), 골드, SSD 512GB, 가격 :1,630,000, 평점 : 5.0, 평점참여자수 :(40)
# 바로가기 주소 : /vp/products/4322481134?itemId=5033261406&vendorItemId=72343056001
# ------------------------------
# 제품명 :Apple 2019년 맥북 프로 16, 코어i7, 16GB, 512GB, 스페이스 그레이, 라데온 Pro 5300M, 가격 :3,107,000, 평점 : 5.0, 평점참여자수 :(1562)
# 바로가기 주소 : /vp/products/1066005124?itemId=2012781732&vendorItemId=70012621958
# ------------------------------
# 제품명 :한성컴퓨터 노트북 TFG256XX (i7-10875H 39.62cm RTX2060), 윈도우 미포함, 500GB, 16GB, 가격 :1,449,000, 평점 : 4.5, 평점참여자수 :(12)
# 바로가기 주소 : /vp/products/1925746196?itemId=3269234218&vendorItemId=71256257364
# ------------------------------
# 제품명 :LG전자 2020 그램15 노트북 (i7-1065G7 39.6cm), 8GB, 256GB, Free DOS, 미포함, 8GB, 가격 :1,678,000, 평점 : 5.0, 평점참여자수 :(39)
# 바로가기 주소 : /vp/products/1176696379?itemId=2057705666&vendorItemId=70056980393
# ------------------------------
# 제품명 :LG전자 울트라 기어 노트북 15UD70N-PX50K (i5-10210U 39.6cm GTX 1050), 256GB, 8GB, Free DOS, 가격 :1,247,360, 평점 : 4.5, 평점참여자수 :(16)
# 바로가기 주소 : /vp/products/1448220475?itemId=2494787358&vendorItemId=70487978472
# ------------------------------
# 제품명 :Apple 2020년 맥북 프로 13 (M1 칩셋 8코어 CPU 8코어 GPU), 실버, 512GB, 가격 :1,881,600, 평점 : 4.5, 평점참여자수 :(84)
# 바로가기 주소 : /vp/products/4322481029?itemId=5033261144&vendorItemId=72343055857
# ------------------------------
# 제품명 :LG전자 2020 그램15 노트북 (i7-1065G7 39.6cm), 8GB, SSD 256GB, WIN10 Home, 포함, 8GB, 가격 :1,799,000, 평점 : 5.0, 평점참여자수 :(39)
# 바로가기 주소 : /vp/products/1176696379?itemId=2057719229&vendorItemId=70056993512
# ------------------------------
# 제품명 :삼성전자 갤럭시북 S NT767XCL-KLTES Mercury Gray (LTE겸용 i5-L16G7 33.7cm Win10 Home), 윈도우 포함, 512GB, 8GB, 가격 :1,348,000, 평점 : 4.5, 평점참여자수 :(22)
# 바로가기 주소 : /vp/products/1796301074?itemId=3055967871&vendorItemId=71043963626
# ------------------------------
# 제품명 :기가바이트 게이밍노트북 AORUS 5 SB i7 E (i7-10750H 39.6cm GTX1660Ti), 윈도우 미포함, 256GB, 8GB, 가격 :1,299,000, 평점 : 5.0, 평점참여자수 :(17)
# 바로가기 주소 : /vp/products/1863274464?itemId=3167221522&vendorItemId=71154753580
# ------------------------------
# 제품명 :한성컴퓨터 노트북 아방가르드 블랙 TFX5075GW (i7-10750H 39.62cm GTX1650Ti), 윈도우 포함, 500GB, 16GB, 가격 :1,379,000, 평점 : 5.0, 평점참여자수 :(6)
# 바로가기 주소 : /vp/products/1925746555?itemId=3269234792&vendorItemId=71256257921
# ------------------------------
# 제품명 :레노버 노트북 Legion 5i-17IMH Ultra(i7-10750H 43.9CM GTX 1660Ti), 미포함, NVMe 256GB, 8GB, 가격 :1,464,910, 평점 : 5.0, 평점참여자수 :(3)
# 바로가기 주소 : /vp/products/1731716493?itemId=2947783116&vendorItemId=70936347724
# ------------------------------
# 제품명 :한성컴퓨터 노트북 올데이롱 실버 TFX255S (i5-10210U 39.62cm WIN미포함), 윈도우 미포함, 500GB, 8GB, 가격 :781,800, 평점 : 5.0, 평점참여자수 :(55)
# 바로가기 주소 : /vp/products/1104994291?itemId=2066005044&vendorItemId=70065189835
# ------------------------------
# 제품명 :삼성전자 갤럭시북 플렉스 노트북 로얄 블루 NT930QCT-A38A (i3-1005G1 33.7cm), 윈도우 미포함, 256GB, 8GB, 가격 :1,498,000, 평점 : 4.0, 평점참여자수 :(37)
# 바로가기 주소 : /vp/products/1130293306?itemId=5129439162&vendorItemId=72438860274
# ------------------------------
# 제품명 :레노버 노트북 Gaming 3i-15IMH I5 LEGEND DOS (i5-10300H 39.6cm WIN미포함 GTX 1650), 윈도우 미포함, 256GB, 8GB, 가격 :848,000, 평점 : 5.0, 평점참여자수 :(37)
# 바로가기 주소 : /vp/products/1713327759?itemId=2915762073&vendorItemId=70904438224
# ------------------------------
# 제품명 :한성컴퓨터 BossMonster 노트북 X7067T (i7-10875H 43.94cm WIN미포함 GTX1660Ti), 윈도우 미포함, 250GB, 8GB, 가격 :1,271,060, 평점 : 4.5, 평점참여자수 :(17)
# 바로가기 주소 : /vp/products/1704365407?itemId=2900423076&vendorItemId=70889376394
# ------------------------------
# 제품명 :한성컴퓨터 노트북 BossMonster X5067T (i7-10875H 39.62cm WIN미포함 GTX 1660Ti), 윈도우 미포함, 250GB, 8GB, 가격 :1,249,000, 평점 : 4.5, 평점참여자수 :(14)
# 바로가기 주소 : /vp/products/1730400298?itemId=2945363284&vendorItemId=70933895639
# ------------------------------
# 제품명 :레노버 ThinkPad X13 노트북 18KR (라이젠7 Pro-4750U 33.78cm WIN10 Pro), 윈도우 포함, 256GB, 16GB, 가격 :1,499,000, 평점 : 평점 없음, 평점참여자수 :(14)
# 바로가기 주소 : /vp/products/1909798412?itemId=3242696574&vendorItemId=71229881112
# ------------------------------
# 제품명 :레노버 아이디어패드 슬림 S340-14IWL 81N700AQKR 81N7 (I5-8265U 35.5cm WIN10 RAM 4GB SSD 128GB), 81N7, ONYX BLACK, 가격 :755,630, 평점 : 5.0, 평점참여자수 :(1)
# 바로가기 주소 : /vp/products/310096302?itemId=977545335&vendorItemId=5392781931
# ------------------------------
# 제품명 :에이수스 Vivo 노트북 인디블랙 S433FA-EB452 (i5-10210U 35.5cm), 윈도우 미포함, 512GB, 8GB, 가격 :799,000, 평점 : 5.0, 평점참여자수 :(1)
# 바로가기 주소 : /vp/products/1722254839?itemId=2931364552&vendorItemId=70919983255
# ------------------------------
# 제품명 :삼성전자 갤럭시북 플렉스 노트북 NT930QCG-K58A 로얄 블루 (i5-1035G4 33.7cm), 256GB, 8GB, WIN10 Home, 가격 :1,717,200, 평점 : 5.0, 평점참여자수 :(50)
# 바로가기 주소 : /vp/products/1665310269?itemId=2098746465&vendorItemId=70097614774
# ------------------------------
# 제품명 :마이크로스프트 서피스고2 노트북 포피레드 (Intel Core m3 26.6cm WIN10 Home S HD Graphics615 LTE), 윈도우 포함, 128GB, 8GB, 가격 :1,103,090, 평점 : 5.0, 평점참여자수 :(5)
# 바로가기 주소 : /vp/products/1630863814?itemId=2781785476&vendorItemId=70771536625
# ------------------------------
# 제품명 :레노버 노트북 Legion 5 15ARH ZEN PLUS PRO 2060 W10 (라이젠7-4800H 39.6cm WIN10 Pro RTX2060), 윈도우 포함, 256GB, 8GB, 가격 :1,509,000, 평점 : 5.0, 평점참여자수 :(5)
# 바로가기 주소 : /vp/products/2373326140?itemId=4133129510&vendorItemId=72117048188
# ------------------------------
# 제품명 :레노버 노트북 Flex 5 14IIL i5 MX W10 (i5-1035G1 35.5cm WIN10 Home MX330), 윈도우 포함, 256GB, 8GB, 가격 :999,000, 평점 : 5.0, 평점참여자수 :(5)
# 바로가기 주소 : /vp/products/1731605240?itemId=2947601002&vendorItemId=70936159305
# ------------------------------
# 제품명 :레노버 YOGA C740-14IML i5 Vibe 노트북 Iron Grey 81TC007BKR (i5-10210U 35.5cm WIN10 Intel UHD Grapics), 윈도우 포함, 256GB, 8GB, 가격 :999,000, 평점 : 4.5, 평점참여자수 :(8)
# 바로가기 주소 : /vp/products/1149850378?itemId=2123558626&vendorItemId=70122150841
# ------------------------------
# 제품명 :LG전자 2020 울트라기어 노트북 17U70N-PA56K (i5-10210U 43.1cm GTX 1650), 256GB, 8GB, WIN10 Home, 가격 :1,739,000, 평점 : 4.5, 평점참여자수 :(9)
# 바로가기 주소 : /vp/products/1277987944?itemId=2285035724&vendorItemId=70231297542
# ------------------------------
# 제품명 :LG전자 그램14 노트북 스노우 화이트 14Z990-GR56K (i5-8265U 35.5cm WIN10 Home), 윈도우 포함, 256GB, 8GB, 가격 :1,398,000, 평점 : 4.5, 평점참여자수 :(5)
# 바로가기 주소 : /vp/products/2207712067?itemId=3757123558&vendorItemId=71742234688
# ------------------------------
# 제품명 :한성컴퓨터 노트북 아방가르드 실버 TFX5075GW (i7-10750H 39.62cm GTX1650Ti), 윈도우 포함, 500GB, 16GB, 가격 :1,379,000, 평점 : 5.0, 평점참여자수 :(7)
# 바로가기 주소 : /vp/products/1925746404?itemId=3269234552&vendorItemId=71256257490
# ------------------------------
# 제품명 :LG전자 그램14 스노우화이트 14Z90N-EB36K (i3-1005G1 35.5cm WIN10S), 윈도우 포함, 128GB, 4GB, 가격 :1,053,080, 평점 : 5.0, 평점참여자수 :(5)
# 바로가기 주소 : /vp/products/2087443046?itemId=3545758921&vendorItemId=71531713441
# ------------------------------
# 제품명 :델 노트북 LATITUDE 3300-58G25W (i5-8250U 33.78cm 8GB DDR4 256GB M.2 NVMe SSD UHD620 WIN 10 Home), 포함, 가격 :860,000, 평점 : 5.0, 평점참여자수 :(1)
# 바로가기 주소 : /vp/products/1061116488?itemId=2005466038&vendorItemId=70005393775
# ------------------------------
# 제품명 :레노버 노트북 Legion 5-15ARH (라이젠7-4800H 39.6cm GTX 1650Ti), 미포함, NVMe 256GB, 8GB, 가격 :1,139,000, 평점 : 5.0, 평점참여자수 :(14)
# 바로가기 주소 : /vp/products/1731126159?itemId=2946768019&vendorItemId=70935248549
# ------------------------------
# 제품명 :Apple 2020년 맥북 프로 13, 10세대 i5, 32GB, SSD 512GB, 실버, 가격 :3,030,000, 평점 : 5.0, 평점참여자수 :(838)
# 바로가기 주소 : /vp/products/1650206709?itemId=3370176909&vendorItemId=71356892761
# ------------------------------
# 제품명 :에이서 니트로5 AN515-54-7078 노트북 (i7-9750H 39.6cm GTX1660Ti), 256GB, 4GB, Free DOS, 가격 :1,429,560, 평점 : 5.0, 평점참여자수 :(6)
# 바로가기 주소 : /vp/products/241304780?itemId=767247677&vendorItemId=4936331538
# ------------------------------
# 제품명 :Apple 2019년 맥북 프로 16, 9세대 i9, 32GB, SSD 1TB, 스페이스 그레이, AMD Radeon Pro 5600M 8GB, 가격 :5,445,000, 평점 : 5.0, 평점참여자수 :(1562)
# 바로가기 주소 : /vp/products/1066005124?itemId=3370176418&vendorItemId=71356893039
# ------------------------------
# 제품명 :레이저 BLADE Pro 17 게이밍 노트북 9Gen R80 512 Lite (i7-9750H 43.94cm WIN10 Home RTX2080 Max-Q), 윈도우 포함, 512GB, 16GB, 가격 :2,990,000, 평점 : 5.0, 평점참여자수 :(8)
# 바로가기 주소 : /vp/products/2069223729?itemId=3515878868&vendorItemId=71502003232
# ------------------------------
# 제품명 :기가바이트 게이밍노트북 AORUS 5 SB i7 (i7-10750H 39.6cm GTX1660Ti), 윈도우 미포함, 1536GB, 16GB, 가격 :1,449,000, 평점 : 5.0, 평점참여자수 :(17)
# 바로가기 주소 : /vp/products/1863274464?itemId=3167221536&vendorItemId=71154753608
# ------------------------------
