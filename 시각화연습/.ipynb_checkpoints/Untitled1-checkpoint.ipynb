# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
df = pd.read_csv('해양경찰청_해상조난사고 상세데이터 현황_20191231.csv', encoding='euc-kr')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.xticks(rotation=90)
sns.countplot(x="기상상태",  data=df)
plt.show()

# %%
df
# Out:
#                   발생일시 관할해경서    발생해역            위도             경도 기상상태   발생원인  \
# 0     2019-12-31 22:04  포항    영해      0 | 0 | 0     0 | 0 | 0      양호   관리소홀
# 1     2019-12-31 15:13  포항    영해      35 | 52 | 3   129 | 45 | 55  양호   운항부주의
# 2     2019-12-31 15:13  포항    영해      35 | 52 | 3   129 | 45 | 55  양호   운항부주의
# 3     2019-12-31 9:33   통영    협수로     34 | 41 | 6   128 | 3 | 59   양호   운항부주의
# 4     2019-12-31 8:38   군산    항계 내    35 | 59 | 18  126 | 41 | 43  양호   관리소홀
# ...               ...   ..     ...             ...            ...  ..    ...
# 3815  2019-01-01 14:08  인천    영해      37 | 21 | 28  126 | 25 | 49  양호   운항부주의
# 3816  2019-01-01 9:14   인천    협수로     37 | 13 | 0   126 | 9 | 0    양호   운항부주의
# 3817  2019-01-01 7:59   완도    항계 내    34 | 28 | 52  126 | 56 | 41  양호   운항부주의
# 3818  2019-01-01 3:31   태안    영해      36 | 46 | 60  126 | 1 | 0    양호   운항부주의
# 3819  2019-01-01 0:10   서귀포   영해-EEZ  32 | 49 | 60  127 | 3 | 0    양호   정비불량
#
# ...

# %%
c_list=df.columns.tolist()

# %%
'''igure, [ax0,ax1] = plt.subplots(ncols=1,nrows=2) 
figure.set_size_inches(10,20)

sns.countplot(x='선 종',hue='발생원인',ax=ax0 , data=df)
sns.countplot(x='선 종',hue='발생원인',ax=ax1  ,data=df)



for ax in figure.axes:
       plt.sca(ax)
       plt.xticks(rotation=90)

plt.tight_layout()
'''
# Out:
# "igure, [ax0,ax1] = plt.subplots(ncols=1,nrows=2) \nfigure.set_size_inches(10,20)\n\nsns.countplot(x='선 종',hue='발생원인',ax=ax0 , data=df)\nsns.countplot(x='선 종',hue='발생원인',ax=ax1  ,data=df)\n\n\n\nfor ax in figure.axes:\n       plt.sca(ax)\n       plt.xticks(rotation=90)\n\nplt.tight_layout()\n"

# %%
figure, ax0 = plt.subplots(ncols=1) 
figure.set_size_inches(10,20)

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.xticks(rotation=90)
#sns.countplot(x='선 종',hue='발생원인',  data=df)
sns.countplot(x='발생인원', ax=ax0, data=df)

for ax in figure.axes:
       plt.sca(ax)
       plt.xticks(rotation=90)
plt.show()

# %%
df['발생인원'].describe()
# Out:
# count    3820.000000
# mean     5.346073
# std      17.369334
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      6.000000
# max      534.000000
# Name: 발생인원, dtype: float64

# %%
df['위험도'] = 0

# %%
df['위험도']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3815    0
# 3816    0
# 3817    0
# 3818    0
# 3819    0
# Name: 위험도, Length: 3820, dtype: int64

# %%
df.loc[(df['발생인원'] > 5),'위험도'] = 1

# %%
df.loc[(df['발생인원'] > 22),'위험도'] = 2

# %%
df['위험도'].value_counts()
# Out:
# 0    2845
# 1    928
# 2    47
# Name: 위험도, dtype: int64

# %%
df
# Out:
#                   발생일시 관할해경서    발생해역            위도             경도 기상상태   발생원인  \
# 0     2019-12-31 22:04  포항    영해      0 | 0 | 0     0 | 0 | 0      양호   관리소홀
# 1     2019-12-31 15:13  포항    영해      35 | 52 | 3   129 | 45 | 55  양호   운항부주의
# 2     2019-12-31 15:13  포항    영해      35 | 52 | 3   129 | 45 | 55  양호   운항부주의
# 3     2019-12-31 9:33   통영    협수로     34 | 41 | 6   128 | 3 | 59   양호   운항부주의
# 4     2019-12-31 8:38   군산    항계 내    35 | 59 | 18  126 | 41 | 43  양호   관리소홀
# ...               ...   ..     ...             ...            ...  ..    ...
# 3815  2019-01-01 14:08  인천    영해      37 | 21 | 28  126 | 25 | 49  양호   운항부주의
# 3816  2019-01-01 9:14   인천    협수로     37 | 13 | 0   126 | 9 | 0    양호   운항부주의
# 3817  2019-01-01 7:59   완도    항계 내    34 | 28 | 52  126 | 56 | 41  양호   운항부주의
# 3818  2019-01-01 3:31   태안    영해      36 | 46 | 60  126 | 1 | 0    양호   운항부주의
# 3819  2019-01-01 0:10   서귀포   영해-EEZ  32 | 49 | 60  127 | 3 | 0    양호   정비불량
#
# ...

# %%
df=df.drop(columns=['발생원인','기상상태','발생유형','구조','부상','사망','실종','발생인원','발생해역','관할해경서'])

# %%
df['사고선박수'].describe()
# Out:
# count    3820.0
# mean     1.0
# std      0.0
# min      1.0
# 25%      1.0
# 50%      1.0
# 75%      1.0
# max      1.0
# Name: 사고선박수, dtype: float64

# %%
df=df.drop(columns='사고선박수')

# %%
#df=df.drop(columns=['발생해역','관할해경서'])

#위도, 경도 -> 소해구별로 치환(?)

# %%
df['grp'] = df.위도.str.split(' | ').str[0]

# %%
df2=df

# %%
df2=df2.drop(columns=['grp'])

# %%
df2['위도'] = df.위도.str.split(' | ').str[0]
df2['경도'] = df.경도.str.split(' | ').str[0]

# %%
df2
# Out:
#                   발생일시  위도   경도   선 종       톤수  위험도
# 0     2019-12-31 22:04  0   0    모터보트  1.07     0
# 1     2019-12-31 15:13  35  129  어선    29.00    1
# 2     2019-12-31 15:13  35  129  화물선   1415.00  1
# 3     2019-12-31 9:33   34  128  어선    4.96     0
# 4     2019-12-31 8:38   35  126  어선    8.55     0
# ...               ...   ..  ...  ..     ...    ..
# 3815  2019-01-01 14:08  37  126  모터보트  19.50    1
# 3816  2019-01-01 9:14   37  126  어선    7.31     0
# 3817  2019-01-01 7:59   34  126  모터보트  1.33     0
# 3818  2019-01-01 3:31   36  126  기타    0.50     0
# 3819  2019-01-01 0:10   32  127  어선    22.00    1
#
# [3820 rows x 6 columns]

# %%
df2['톤수'].describe()
# 톤수도 범주형으로 바꾸는게 좋을듯
# Out:
# count    3820.000000
# mean     773.645581
# std      6612.734042
# min      0.000000
# 25%      1.957500
# 50%      6.305000
# 75%      29.000000
# max      190000.000000
# Name: 톤수, dtype: float64

# %%
figure, ax0 = plt.subplots(ncols=1) 
figure.set_size_inches(10,20)

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.xticks(rotation=90)
#sns.countplot(x='선 종',hue='발생원인',  data=df2)
sns.countplot(x='선 종', ax=ax0, data=df2)

for ax in figure.axes:
       plt.sca(ax)
       plt.xticks(rotation=90)
plt.show()

# %%
df2
# Out:
#                   발생일시  위도   경도   선 종       톤수  위험도
# 0     2019-12-31 22:04  0   0    모터보트  1.07     0
# 1     2019-12-31 15:13  35  129  어선    29.00    1
# 2     2019-12-31 15:13  35  129  화물선   1415.00  1
# 3     2019-12-31 9:33   34  128  어선    4.96     0
# 4     2019-12-31 8:38   35  126  어선    8.55     0
# ...               ...   ..  ...  ..     ...    ..
# 3815  2019-01-01 14:08  37  126  모터보트  19.50    1
# 3816  2019-01-01 9:14   37  126  어선    7.31     0
# 3817  2019-01-01 7:59   34  126  모터보트  1.33     0
# 3818  2019-01-01 3:31   36  126  기타    0.50     0
# 3819  2019-01-01 0:10   32  127  어선    22.00    1
#
# [3820 rows x 6 columns]

# %%
df3=df2

# %%
df4= df3[df3['톤수'] !=190000]
df4= df3[df3['톤수'] !=117600]

# %%
df4['톤수'].describe()
# Out:
# count    3819.000000
# mean     743.054758
# std      6337.508835
# min      0.000000
# 25%      1.955000
# 50%      6.300000
# 75%      29.000000
# max      190000.000000
# Name: 톤수, dtype: float64

# %%
df4.sort_values('톤수',ascending=False).head(100)
# Out:
#                   발생일시  위도   경도  선 종        톤수  위험도
# 2128  2019-07-05 17:21  35  129  기타   190000.0  2
# 3377  2019-03-02 7:50   35  128  화물선  114044.0  0
# 1735  2019-08-06 21:30  34  125  화물선  114044.0  0
# 2560  2019-05-27 12:40  35  128  화물선  94730.0   2
# 2741  2019-05-10 20:46  35  129  유조선  85030.0   0
# ...                ...  ..  ...  ...      ...  ..
# 3134  2019-03-30 22:08  34  128  화물선  4177.0    1
# 2073  2019-07-10 10:15  37  126  예부선  4008.0    0
# 1776  2019-08-04 13:00  35  128  유조선  3490.0    0
# 956   2019-10-02 18:50  35  128  화물선  3475.0    1
# 2743  2019-05-10 17:36  34  127  화물선  3435.0    1
#
# [100 rows x 6 columns]

# %%
pd.set_option('display.max_colwidth',-1)
# Out:
# c:\users\minisong\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
df4.sort_values('톤수',ascending=False).head(60)
# Out:
#                   발생일시  위도   경도  선 종        톤수  위험도
# 2128  2019-07-05 17:21  35  129  기타   190000.0  2
# 3377  2019-03-02 7:50   35  128  화물선  114044.0  0
# 1735  2019-08-06 21:30  34  125  화물선  114044.0  0
# 2560  2019-05-27 12:40  35  128  화물선  94730.0   2
# 2741  2019-05-10 20:46  35  129  유조선  85030.0   0
# 3695  2019-01-16 10:37  37  126  유조선  81479.0   2
# 3125  2019-04-01 21:48  34  128  유조선  75201.0   0
# 2144  2019-07-04 21:32  35  129  유조선  62508.0   2
# 431   2019-11-10 22:34  34  128  기타   61184.0   1
# 3212  2019-03-20 14:12  34  126  화물선  60876.0   0
# 432   2019-11-10 22:34  34  128  기타   60717.0   1
# 1179  2019-09-17 3:48   33  127  화물선  59516.0   1
# 1563  2019-08-23 5:20   35  129  유조선  57326.0   2
# 1896  2019-07-26 9:33   36  126  화물선  55729.0   0
# 2615  2019-05-24 0:16   35  126  화물선  51225.0   1
# 2437  2019-06-08 7:15   35  128  화물선  50757.0   0
# 3376  2019-03-02 7:50   35  128  화물선  50624.0   1
# 3679  2019-01-18 4:05   35  130  화물선  49625.0   1
# ...

# %%
df4['크기분류'] ='소형'
df4.loc[(df4['톤수'] > 30),'크기분류'] = '중형'
df4.loc[(df4['톤수'] > 6000),'크기분류'] = '대형'
# Out:
# c:\users\minisong\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\minisong\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:1719: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# ...

# %%
df4['크기분류'].value_counts()
# Out:
# 소형    2971
# 중형    779
# 대형    69
# Name: 크기분류, dtype: int64

# %%
df4=df4.drop(columns=['톤수'])

# %%
a=df4['위험도']
df4=df4.drop(columns='위험도')

# %%
df4['위험도'] = a

# %%
df4=df4.drop(axis=0,index=0)

# %%
df4
# Out:
#                   발생일시  위도   경도   선 종 크기분류  위험도
# 1     2019-12-31 15:13  35  129  어선    소형   1
# 2     2019-12-31 15:13  35  129  화물선   중형   1
# 3     2019-12-31 9:33   34  128  어선    소형   0
# 4     2019-12-31 8:38   35  126  어선    소형   0
# 5     2019-12-31 3:25   34  127  어선    중형   0
# ...               ...   ..  ...  ..    ..  ..
# 3815  2019-01-01 14:08  37  126  모터보트  소형   1
# 3816  2019-01-01 9:14   37  126  어선    소형   0
# 3817  2019-01-01 7:59   34  126  모터보트  소형   0
# 3818  2019-01-01 3:31   36  126  기타    소형   0
# 3819  2019-01-01 0:10   32  127  어선    소형   1
#
# [3818 rows x 6 columns]

# %%
df4['발생일시'] = pd.to_datetime(df['발생일시'], format='%Y-%m-%d %H:%M:%S', errors='raise')

# %%
#time serie 를 위해 date type 을 datetime64[ns]로 변경
df4.dtypes
# Out:
# 발생일시    datetime64[ns]
# 위도      object
# 경도      object
# 선 종     object
# 크기분류    object
# 위험도     int64
# dtype: object
